# %% [markdown]
# # Hello World

# %%
# first program
print('Hello World')
# Out:
# Hello World

# %%
message_1 = "I'm learning Python"

# %%
message_1
# Out:
# "I'm learning Python"

# %%
message_2 = "and it's fun"

# %%
message_2
# Out:
# "and it's fun"

# %%
message_1 + message_2
# Out:
# "I'm learning Python and it's fun"

# %%
f"{message_1} {message_2}"
# Out:
# "I'm learning Python and it's fun"

# %%
countries = ['United States', 'India', 'China', 'Brazil']

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil']

# %%
print(countries[0],
countries[1],
countries[2],
countries[3])
# Out:
# United States India China Brazil

# %%
print(countries[-1])
# Out:
# Brazil

# %%
countries[1:3]
# Out:
# ['India', 'China']

# %%
countries[1:]
# Out:
# ['India', 'China', 'Brazil']

# %%
countries.append("Canada")

# %%
countries
# Out:
# ['United States', 'India', 'China', 'Brazil', 'Canada', 'Canada']

# %%
countries.insert(1,"panama")

# %%
countries
# Out:
# ['United States', 'panama', 'India', 'China', 'Brazil', 'Canada', 'Canada']

# %%
countries_2 = ['UK', 'Germany', 'Austria']

# %%
countries + countries_2
# Out:
# ['United States',
#  'panama',
#  'India',
#  'China',
#  'Brazil',
#  'Canada',
#  'Canada',
#  'UK',
#  'Germany',
#  'Austria']

# %%
nested_list = [countries, countries_2]

# %%
nested_list
# Out:
# [['United States', 'panama', 'India', 'China', 'Brazil', 'Canada', 'Canada'],
#  ['UK', 'Germany', 'Austria']]

# %%
countries.remove('United States')

# %%
countries
# Out:
# ['panama', 'India', 'China', 'Brazil', 'Canada', 'Canada']

# %%
countries.pop(-1)
# Out:
# 'Canada'

# %%
del countries[0]

# %%
countries
# Out:
# ['India', 'China', 'Brazil', 'Canada']

# %%
numbers = [23,452,3,2,24353,5346645,2,45]

# %%
numbers
# Out:
# [23, 452, 3, 2, 24353, 5346645, 2, 45]

# %%
numbers.sort()

# %%
numbers
# Out:
# [2, 2, 3, 23, 45, 452, 24353, 5346645]

# %%
numbers.sort(reverse=True)

# %%
numbers
# Out:
# [5346645, 24353, 452, 45, 23, 3, 2, 2]

# %%
numbers[0] = 1000

# %%
numbers
# Out:
# [1000, 24353, 452, 45, 23, 3, 2, 2]

# %%
my_dict = {'key1':'vaue1', 'key2':'value2'}

# %%
my_data = {'name':'Frank', 'age':37}

# %%
my_data
# Out:
# {'name': 'Frank', 'age': 37}

# %%
my_data.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
my_data.values()
# Out:
# dict_values(['Frank', 37])

# %%
my_data.items()
# Out:
# dict_items([('name', 'Frank'), ('age', 37)])

# %%
my_data['height'] = 1

# %%
my_data
# Out:
# {'name': 'Frank', 'age': 37, 'height': 1}

# %%
my_data.update({'height':1.5})

# %%
my_data
# Out:
# {'name': 'Frank', 'age': 37, 'height': 1.7}

# %%
new_dict = my_data.copy()

# %%
new_dict
# Out:
# {'name': 'Frank', 'age': 37, 'height': 1.9}

# %%
new_dict2 = my_data

# %%
new_dict2
# Out:
# {'name': 'Frank', 'age': 37, 'height': 1.5}

# %%
my_data.pop('name')
# Out:
# 'Frank'

# %%
my_data
# Out:
# {'age': 37, 'height': 1.5}

# %%
del my_data['age']

# %%
my_data
# Out:
# {'name': 'Frank'}

# %%
my_data.clear()

# %%
my_data
# Out:
# {}

# %%
age = 19

if age >= 18:
    print("You're an adult")
elif age >= 13:
    print("You're a teenager")
else:
    print("You're a kid")
# Out:
# You're an adult

# %%
countries
# Out:
# ['India', 'China', 'Brazil', 'Canada']

# %%
for i, country in enumerate(countries):
    print(i, country)
# Out:
# 0 India
# 1 China
# 2 Brazil
# 3 Canada

# %%
my_data
# Out:
# {'name': 'Frank', 'age': 37}

# %%
for k, v in my_data.items():
    print(k, v)
# Out:
# name Frank
# age 37

# %%
def sum_values(a,b):
    x = a + b
    return x

# %%
a = 23
b = 32
sum_values(1,3)
# Out:
# 4

# %%
countries
# Out:
# ['India', 'China', 'Brazil', 'Canada']

# %%
len(countries)
# Out:
# 4

# %%
min([10,32,56,92,9,199])
# Out:
# 9

# %%
type(countries)
# Out:
# list

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/mm'

# %%
os.listdir()
# Out:
# ['.config',
#  'Music',
#  '.zprofile.pysave',
#  'New Folder',
#  '.th-client',
#  '.zcompdump-Marks-MacBook-Pro-5.9.zwc',
#  '.DS_Store',
#  '.qiskit',
#  '.CFUserTextEncoding',
#  '.xonshrc',
#  'anaconda_projects',
#  'Untitled.ipynb',
#  '.zshrc',
#  '.local',
#  'Pictures',
#  '.zprofile',
#  '.zsh_history',
#  '.ipython',
#  'Desktop',
#  'Library',
#  '.matplotlib',
#  'PycharmProjects',
#  'Public',
#  '.zcompdump-Marks-MacBook-Pro-5.9',
#  '.idlerc',
#  '.tcshrc',
#  '.anaconda',
#  '.ssh',
#  'Movies',
#  'pico.save',
#  '.Trash',
#  '.ipynb_checkpoints',
#  '.jupyter',
#  '.npm',
#  'Documents',
#  'venv',
#  '.pyenv',
#  '.vscode',
#  '.bash_profile',
#  '.oh-my-zsh',
#  'Downloads',
#  '.python_history',
#  '.continuum',
#  '.bash_history',
#  '.viminfo',
#  '.zsh_sessions',
#  '.zshrc_profile',
#  '.conda',
#  'PyCharmMiscProject']

# %%
os.makedirs("New Folder")

# %%
import pandas as pd
import numpy as np

# %%
data = np.array([[1,4], [2,5], [3,6]])

# %%
df = pd.DataFrame(data, index=['row1', 'row2', 'row3'], columns=['col1','col2'])

# %%
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %%
states
# Out:
# ['California', 'Texas', 'Florida', 'New York']

# %%
population
# Out:
# [23425354234, 234234254, 2342342342, 2342342423]

# %%
dict_states = {'States':states, 'Population':population}

# %%
dict_states
# Out:
# {'States': ['California', 'Texas', 'Florida', 'New York'],
#  'Population': [23425354234, 234234254, 2342342342, 2342342423]}

# %%
df_population = pd.DataFrame(dict_states)

# %%
df_population
# Out:
#        States   Population
# 0  California  23425354234
# 1       Texas    234234254
# 2     Florida   2342342342
# 3    New York   2342342423

# %%
os.chdir('Downloads')

# %%
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df_exams.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78
# 6               completed          88             95             92
# 7                    none          40             43             39
# 8               completed          64             64             67
# 9                    none          38             60             50

# %%
df_exams.shape
# Out:
# (1000, 8)

# %%
pd.set_option('display.max_rows', 5)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# ..      ...            ...                         ...           ...
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ..                      ...         ...            ...            ...
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %%
df_exams.shape
# Out:
# (1000, 8)

# %%
df_exams.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
df_exams.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
print(len(df_exams))
# Out:
# 1000

# %%
max(df_exams)
# Out:
# 'writing score'

# %%
len(df_exams)
# Out:
# 1000

# %%
max(df_exams.index)
# Out:
# 999

# %%
min(df_exams.index)
# Out:
# 0

# %%
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
round(df_exams, 2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# 13     male        group A                some college      standard
# 14   female        group A             master's degree      standard
# 15   female        group C            some high school      standard
# 16     male        group C                 high school      standard
# 17   female        group B            some high school  free/reduced
# 18     male        group C             master's degree  free/reduced
# 19   female        group C          associate's degree  free/reduced
# 20     male        group D                 high school      standard
# 21   female        group B                some college  free/reduced
# 22     male        group D                some college      standard
# 23   female        group C            some high school      standard
# 24     male        group D           bachelor's degree  free/reduced
# 25     male        group A             master's degree  free/reduced
# 26     male        group B                some college      standard
# 27   female        group C           bachelor's degree      standard
# 28     male        group C                 high school      standard
# 29   female        group D             master's degree      standard
# 30   female        group D                some college      standard
# 31   female        group B                some college      standard
# 32   female        group E             master's degree  free/reduced
# 33     male        group D                some college      standard
# 34     male        group E                some college      standard
# 35     male        group E          associate's degree      standard
# 36   female        group D          associate's degree      standard
# 37   female        group D            some high school  free/reduced
# 38   female        group D          associate's degree  free/reduced
# 39     male        group B          associate's degree  free/reduced
# 40     male        group C          associate's degree  free/reduced
# 41   female        group C          associate's degree      standard
# 42   female        group B          associate's degree      standard
# 43     male        group B                some college  free/reduced
# 44   female        group E          associate's degree  free/reduced
# 45     male        group B          associate's degree      standard
# 46   female        group A          associate's degree      standard
# 47   female        group C                 high school      standard
# 48   female        group D          associate's degree  free/reduced
# 49     male        group C                 high school      standard
# 50     male        group E                some college      standard
# 51     male        group E          associate's degree  free/reduced
# 52     male        group C                some college      standard
# 53     male        group D                 high school      standard
# 54   female        group C            some high school  free/reduced
# 55   female        group C                 high school  free/reduced
# 56   female        group E          associate's degree      standard
# 57     male        group D          associate's degree      standard
# 58     male        group D                some college      standard
# 59   female        group C            some high school  free/reduced
# 60     male        group E           bachelor's degree  free/reduced
# 61     male        group A            some high school  free/reduced
# 62     male        group A          associate's degree  free/reduced
# 63   female        group C          associate's degree      standard
# 64   female        group D            some high school      standard
# 65     male        group B            some high school      standard
# 66     male        group D            some high school  free/reduced
# 67   female        group C                some college      standard
# 68     male        group B          associate's degree  free/reduced
# 69   female        group C          associate's degree      standard
# 70   female        group D                some college  free/reduced
# 71     male        group D                some college      standard
# 72   female        group A          associate's degree  free/reduced
# 73     male        group C            some high school  free/reduced
# 74     male        group C            some high school      standard
# 75     male        group B          associate's degree  free/reduced
# 76     male        group E            some high school      standard
# 77     male        group A           bachelor's degree      standard
# 78   female        group D            some high school      standard
# 79   female        group E             master's degree      standard
# 80   female        group B          associate's degree      standard
# 81     male        group B                 high school  free/reduced
# 82     male        group A                some college  free/reduced
# 83     male        group E          associate's degree      standard
# 84     male        group D                 high school  free/reduced
# 85   female        group C                some college      standard
# 86   female        group C                some college  free/reduced
# 87   female        group D          associate's degree      standard
# 88   female        group A                some college      standard
# 89   female        group D            some high school      standard
# 90   female        group C           bachelor's degree      standard
# 91     male        group C                 high school  free/reduced
# 92     male        group C                 high school      standard
# 93     male        group C          associate's degree  free/reduced
# 94   female        group B                some college      standard
# 95     male        group C          associate's degree  free/reduced
# 96     male        group B            some high school      standard
# 97   female        group E                some college      standard
# 98   female        group D                some college  free/reduced
# 99   female        group D           bachelor's degree      standard
# 100    male        group B                some college      standard
# 101    male        group D           bachelor's degree      standard
# 102  female        group D          associate's degree      standard
# 103    male        group B                 high school      standard
# 104    male        group C                some college      standard
# 105  female        group C                some college      standard
# 106  female        group D             master's degree      standard
# 107    male        group E          associate's degree      standard
# 108  female        group B          associate's degree  free/reduced
# 109  female        group B            some high school      standard
# 110  female        group D          associate's degree  free/reduced
# 111    male        group C                 high school      standard
# 112    male        group A          associate's degree      standard
# 113  female        group D                some college      standard
# 114  female        group E           bachelor's degree      standard
# 115    male        group C                 high school      standard
# 116  female        group B           bachelor's degree  free/reduced
# 117  female        group D           bachelor's degree      standard
# 118  female        group D            some high school      standard
# 119  female        group C                some college      standard
# 120  female        group C           bachelor's degree      standard
# 121    male        group B          associate's degree      standard
# 122  female        group C                some college      standard
# 123    male        group D                 high school  free/reduced
# 124    male        group E                some college      standard
# 125  female        group B                 high school      standard
# 126    male        group B            some high school      standard
# 127    male        group D                some college      standard
# 128    male        group D             master's degree      standard
# 129  female        group A           bachelor's degree      standard
# 130    male        group D             master's degree      standard
# 131    male        group C            some high school  free/reduced
# 132    male        group E                some college  free/reduced
# 133  female        group C                some college      standard
# 134    male        group D           bachelor's degree  free/reduced
# 135    male        group C           bachelor's degree      standard
# 136    male        group B            some high school      standard
# 137    male        group E                 high school      standard
# 138  female        group C          associate's degree      standard
# 139    male        group D                some college      standard
# 140  female        group D            some high school      standard
# 141  female        group C                some college  free/reduced
# 142  female        group E                some college  free/reduced
# 143    male        group A                 high school      standard
# 144    male        group D                some college      standard
# 145  female        group C                some college  free/reduced
# 146    male        group B            some high school      standard
# 147    male        group C          associate's degree  free/reduced
# 148  female        group D           bachelor's degree      standard
# 149    male        group E          associate's degree  free/reduced
# 150    male        group A            some high school      standard
# 151    male        group A           bachelor's degree      standard
# 152  female        group B          associate's degree      standard
# 153    male        group D           bachelor's degree      standard
# 154    male        group D            some high school      standard
# 155  female        group C                some college      standard
# 156  female        group E                 high school  free/reduced
# 157    male        group B                some college  free/reduced
# 158  female        group B          associate's degree      standard
# 159    male        group D          associate's degree  free/reduced
# 160    male        group B          associate's degree  free/reduced
# 161  female        group E                some college  free/reduced
# 162    male        group B             master's degree  free/reduced
# 163    male        group C                 high school      standard
# 164  female        group E             master's degree      standard
# 165  female        group C           bachelor's degree      standard
# 166    male        group C                 high school  free/reduced
# 167  female        group B             master's degree  free/reduced
# 168  female        group B                 high school      standard
# 169  female        group C                some college  free/reduced
# 170    male        group A                 high school      standard
# 171    male        group E            some high school      standard
# 172  female        group D                some college      standard
# 173  female        group C          associate's degree      standard
# 174  female        group C           bachelor's degree  free/reduced
# 175  female        group C             master's degree      standard
# 176  female        group B                 high school  free/reduced
# 177  female        group C          associate's degree      standard
# 178  female        group B             master's degree  free/reduced
# 179  female        group D            some high school      standard
# 180    male        group C             master's degree  free/reduced
# 181  female        group C                some college  free/reduced
# 182  female        group E                 high school      standard
# 183  female        group D          associate's degree      standard
# 184    male        group C            some high school  free/reduced
# 185    male        group C          associate's degree  free/reduced
# 186    male        group E                 high school      standard
# 187    male        group D            some high school      standard
# 188    male        group B            some high school  free/reduced
# 189  female        group C           bachelor's degree      standard
# 190  female        group E          associate's degree      standard
# 191    male        group D                some college      standard
# 192  female        group B            some high school      standard
# 193    male        group D                some college      standard
# 194  female        group C             master's degree      standard
# 195    male        group D          associate's degree      standard
# 196    male        group C            some high school  free/reduced
# 197    male        group E                 high school  free/reduced
# 198  female        group B                some college  free/reduced
# 199  female        group B           bachelor's degree  free/reduced
# 200  female        group C          associate's degree      standard
# 201  female        group D                some college  free/reduced
# 202    male        group C          associate's degree      standard
# 203  female        group B          associate's degree      standard
# 204    male        group C                some college      standard
# 205    male        group D            some high school      standard
# 206    male        group E           bachelor's degree      standard
# 207    male        group E                 high school      standard
# 208  female        group B                some college  free/reduced
# 209  female        group B                some college  free/reduced
# 210    male        group D            some high school  free/reduced
# 211    male        group C                some college  free/reduced
# 212  female        group C                 high school  free/reduced
# 213    male        group C          associate's degree  free/reduced
# 214    male        group E                 high school      standard
# 215    male        group B            some high school      standard
# 216  female        group E          associate's degree  free/reduced
# 217  female        group C                 high school  free/reduced
# 218    male        group B                 high school  free/reduced
# 219    male        group B            some high school      standard
# 220  female        group D                 high school      standard
# 221    male        group B          associate's degree      standard
# 222  female        group C            some high school  free/reduced
# 223    male        group D            some high school      standard
# 224  female        group B          associate's degree      standard
# 225  female        group E             master's degree  free/reduced
# 226  female        group C                some college      standard
# 227    male        group D                 high school      standard
# 228    male        group A            some high school  free/reduced
# 229  female        group C                some college      standard
# 230    male        group D                some college      standard
# 231    male        group C          associate's degree      standard
# 232  female        group B           bachelor's degree      standard
# 233    male        group E            some high school      standard
# 234    male        group C           bachelor's degree      standard
# 235    male        group D          associate's degree      standard
# 236    male        group D           bachelor's degree  free/reduced
# 237  female        group D            some high school      standard
# 238    male        group B                some college      standard
# 239    male        group C          associate's degree      standard
# 240    male        group D                 high school  free/reduced
# 241  female        group E           bachelor's degree      standard
# 242  female        group D                 high school      standard
# 243    male        group E                some college      standard
# 244    male        group D            some high school      standard
# 245    male        group C          associate's degree      standard
# 246    male        group E          associate's degree      standard
# 247  female        group B                 high school      standard
# 248  female        group B                 high school      standard
# 249    male        group C                 high school      standard
# 250    male        group A            some high school      standard
# 251  female        group D                some college  free/reduced
# 252  female        group B            some high school      standard
# 253    male        group D             master's degree      standard
# 254    male        group D                 high school      standard
# 255  female        group E                some college      standard
# 256  female        group C          associate's degree  free/reduced
# 257    male        group C          associate's degree      standard
# 258  female        group B                some college      standard
# 259  female        group C             master's degree  free/reduced
# 260  female        group C            some high school  free/reduced
# 261    male        group C                some college      standard
# 262  female        group C            some high school  free/reduced
# 263  female        group E                 high school      standard
# 264    male        group D                 high school      standard
# 265    male        group D            some high school  free/reduced
# 266  female        group C           bachelor's degree      standard
# 267  female        group D                 high school      standard
# 268  female        group D          associate's degree      standard
# 269  female        group E                some college  free/reduced
# 270    male        group C           bachelor's degree      standard
# 271    male        group C                some college      standard
# 272  female        group D          associate's degree  free/reduced
# 273  female        group D                some college      standard
# 274    male        group B                some college      standard
# 275    male        group C           bachelor's degree      standard
# 276  female        group C            some high school      standard
# 277  female        group E                 high school      standard
# 278  female        group C            some high school  free/reduced
# 279    male        group B           bachelor's degree  free/reduced
# 280    male        group D                 high school      standard
# 281    male        group D                 high school      standard
# 282  female        group D           bachelor's degree  free/reduced
# 283  female        group D                some college  free/reduced
# 284  female        group B            some high school      standard
# 285    male        group B          associate's degree      standard
# 286    male        group E          associate's degree      standard
# 287  female        group B            some high school      standard
# 288    male        group B           bachelor's degree  free/reduced
# 289    male        group E            some high school      standard
# 290    male        group C          associate's degree      standard
# 291    male        group D            some high school      standard
# 292    male        group C            some high school      standard
# 293  female        group E           bachelor's degree      standard
# 294    male        group D                 high school  free/reduced
# 295    male        group B          associate's degree  free/reduced
# 296    male        group A            some high school      standard
# 297    male        group E          associate's degree      standard
# 298    male        group C                 high school  free/reduced
# 299    male        group D          associate's degree  free/reduced
# 300    male        group A                some college  free/reduced
# 301    male        group D            some high school  free/reduced
# 302  female        group C          associate's degree      standard
# 303    male        group B          associate's degree      standard
# 304  female        group C          associate's degree      standard
# 305    male        group A                some college      standard
# 306    male        group E                some college      standard
# 307    male        group C            some high school      standard
# 308  female        group B          associate's degree  free/reduced
# 309  female        group D                 high school  free/reduced
# 310  female        group B          associate's degree      standard
# 311    male        group B           bachelor's degree      standard
# 312    male        group D           bachelor's degree      standard
# 313  female        group C          associate's degree  free/reduced
# 314  female        group C           bachelor's degree      standard
# 315    male        group C                 high school      standard
# 316  female        group D             master's degree      standard
# 317    male        group C          associate's degree      standard
# 318    male        group B           bachelor's degree      standard
# 319  female        group D          associate's degree  free/reduced
# 320  female        group C                 high school  free/reduced
# 321  female        group E                 high school      standard
# 322  female        group C                some college      standard
# 323  female        group C            some high school  free/reduced
# 324  female        group C                 high school  free/reduced
# 325  female        group C                some college      standard
# 326    male        group C                some college      standard
# 327    male        group A                some college  free/reduced
# 328    male        group C          associate's degree      standard
# 329  female        group B            some high school      standard
# 330    male        group C                 high school      standard
# 331    male        group C          associate's degree      standard
# 332    male        group E          associate's degree      standard
# 333    male        group B          associate's degree      standard
# 334  female        group C           bachelor's degree      standard
# 335  female        group B                some college  free/reduced
# 336    male        group D            some high school      standard
# 337    male        group C          associate's degree      standard
# 338  female        group B            some high school  free/reduced
# 339  female        group D            some high school  free/reduced
# 340    male        group C                 high school  free/reduced
# 341  female        group C                 high school      standard
# 342  female        group B                 high school      standard
# 343    male        group D          associate's degree      standard
# 344    male        group D                some college      standard
# 345  female        group C                 high school      standard
# 346    male        group B                some college      standard
# 347  female        group C           bachelor's degree      standard
# 348    male        group D                 high school  free/reduced
# 349    male        group E          associate's degree      standard
# 350  female        group B           bachelor's degree      standard
# 351    male        group E                some college      standard
# 352  female        group C                some college      standard
# 353  female        group C          associate's degree      standard
# 354  female        group C                some college      standard
# 355  female        group B           bachelor's degree      standard
# 356    male        group A          associate's degree      standard
# 357  female        group C                some college  free/reduced
# 358    male        group D                some college  free/reduced
# 359  female        group D                some college      standard
# 360  female        group B                 high school      standard
# 361    male        group B            some high school      standard
# 362  female        group C                some college      standard
# 363  female        group D            some high school  free/reduced
# 364    male        group C                some college      standard
# 365    male        group A           bachelor's degree  free/reduced
# 366    male        group C                 high school      standard
# 367    male        group C           bachelor's degree  free/reduced
# 368  female        group A            some high school  free/reduced
# 369  female        group D            some high school      standard
# 370    male        group E                some college      standard
# 371  female        group C                some college  free/reduced
# 372    male        group D            some high school      standard
# 373  female        group D                some college      standard
# 374  female        group D           bachelor's degree      standard
# 375    male        group E          associate's degree  free/reduced
# 376  female        group D            some high school      standard
# 377  female        group D             master's degree  free/reduced
# 378  female        group A            some high school      standard
# 379    male        group A           bachelor's degree      standard
# 380  female        group B          associate's degree      standard
# 381    male        group C          associate's degree      standard
# 382    male        group C             master's degree  free/reduced
# 383  female        group E            some high school  free/reduced
# 384  female        group A            some high school  free/reduced
# 385  female        group E                some college      standard
# 386  female        group E           bachelor's degree      standard
# 387  female        group C          associate's degree  free/reduced
# 388  female        group D                 high school      standard
# 389    male        group D             master's degree      standard
# 390    male        group E            some high school  free/reduced
# 391  female        group D                some college      standard
# 392    male        group E                some college      standard
# 393    male        group C          associate's degree      standard
# 394  female        group C            some high school      standard
# 395    male        group A                 high school  free/reduced
# 396  female        group B                 high school  free/reduced
# 397  female        group C          associate's degree      standard
# 398    male        group B            some high school      standard
# 399    male        group D            some high school      standard
# 400  female        group C            some high school      standard
# 401    male        group A                some college      standard
# 402  female        group A                some college  free/reduced
# 403  female        group D                 high school      standard
# 404  female        group C                 high school      standard
# 405  female        group C            some high school      standard
# 406    male        group B          associate's degree      standard
# 407  female        group B          associate's degree      standard
# 408  female        group D                 high school  free/reduced
# 409    male        group D          associate's degree      standard
# 410  female        group D             master's degree      standard
# 411    male        group E                some college      standard
# 412    male        group D          associate's degree      standard
# 413    male        group B            some high school      standard
# 414  female        group C           bachelor's degree  free/reduced
# 415    male        group E                 high school      standard
# 416    male        group C           bachelor's degree      standard
# 417    male        group C          associate's degree      standard
# 418    male        group D                some college      standard
# 419    male        group E                 high school  free/reduced
# 420  female        group C          associate's degree  free/reduced
# 421  female        group D                 high school      standard
# 422  female        group D             master's degree  free/reduced
# 423  female        group A            some high school      standard
# 424    male        group B                some college  free/reduced
# 425  female        group C                some college  free/reduced
# 426    male        group C           bachelor's degree      standard
# 427    male        group C            some high school  free/reduced
# 428    male        group A            some high school  free/reduced
# 429    male        group C            some high school  free/reduced
# 430    male        group C          associate's degree  free/reduced
# 431  female        group C                 high school      standard
# 432    male        group C                 high school      standard
# 433  female        group A            some high school  free/reduced
# 434    male        group C            some high school      standard
# 435    male        group C                some college  free/reduced
# 436    male        group D          associate's degree      standard
# 437    male        group D          associate's degree  free/reduced
# 438    male        group C                 high school      standard
# 439    male        group D            some high school      standard
# 440  female        group C                some college      standard
# 441  female        group D                 high school      standard
# 442  female        group A            some high school  free/reduced
# 443  female        group B          associate's degree      standard
# 444    male        group A            some high school  free/reduced
# 445  female        group C            some high school      standard
# 446    male        group D                some college  free/reduced
# 447    male        group C                 high school      standard
# 448    male        group B                 high school      standard
# 449    male        group B          associate's degree      standard
# 450  female        group C                some college  free/reduced
# 451  female        group E                some college      standard
# 452  female        group C          associate's degree  free/reduced
# 453    male        group C                some college  free/reduced
# 454  female        group C          associate's degree  free/reduced
# 455    male        group C           bachelor's degree  free/reduced
# 456  female        group D           bachelor's degree      standard
# 457    male        group D          associate's degree  free/reduced
# 458  female        group E           bachelor's degree      standard
# 459    male        group B                 high school      standard
# 460    male        group C           bachelor's degree  free/reduced
# 461    male        group B                some college  free/reduced
# 462  female        group E                some college      standard
# 463  female        group C                some college  free/reduced
# 464    male        group A           bachelor's degree      standard
# 465  female        group C                some college      standard
# 466  female        group D          associate's degree  free/reduced
# 467    male        group A                 high school  free/reduced
# 468  female        group A                 high school  free/reduced
# 469    male        group C                some college      standard
# 470  female        group C          associate's degree      standard
# 471  female        group C                 high school      standard
# 472  female        group C          associate's degree      standard
# 473  female        group D            some high school      standard
# 474  female        group B          associate's degree      standard
# 475  female        group D           bachelor's degree      standard
# 476    male        group E           bachelor's degree      standard
# 477    male        group D          associate's degree      standard
# 478  female        group D             master's degree      standard
# 479    male        group E          associate's degree      standard
# 480    male        group B                 high school      standard
# 481  female        group D          associate's degree  free/reduced
# 482    male        group C                some college  free/reduced
# 483    male        group A                 high school      standard
# 484  female        group B          associate's degree      standard
# 485    male        group C                 high school      standard
# 486    male        group D                some college  free/reduced
# 487  female        group C          associate's degree  free/reduced
# 488    male        group B            some high school      standard
# 489    male        group A          associate's degree  free/reduced
# 490  female        group A          associate's degree  free/reduced
# 491  female        group C          associate's degree      standard
# 492  female        group C                some college      standard
# 493  female        group C           bachelor's degree      standard
# 494  female        group B                 high school      standard
# 495    male        group D                 high school      standard
# 496  female        group C                some college      standard
# 497  female        group D                some college  free/reduced
# 498  female        group B            some high school      standard
# 499    male        group E                some college      standard
# 500  female        group D             master's degree      standard
# 501  female        group B          associate's degree      standard
# 502    male        group C                some college  free/reduced
# 503  female        group E          associate's degree      standard
# 504  female        group D             master's degree  free/reduced
# 505  female        group B            some high school      standard
# 506    male        group A                 high school      standard
# 507    male        group B           bachelor's degree  free/reduced
# 508    male        group C             master's degree      standard
# 509  female        group C           bachelor's degree      standard
# 510    male        group D                some college      standard
# 511    male        group A            some high school      standard
# 512    male        group D            some high school  free/reduced
# 513  female        group B            some high school      standard
# 514  female        group B             master's degree  free/reduced
# 515  female        group C            some high school      standard
# 516  female        group D                some college      standard
# 517  female        group E                some college      standard
# 518  female        group D            some high school      standard
# 519  female        group B                 high school  free/reduced
# 520    male        group D                some college      standard
# 521  female        group C          associate's degree      standard
# 522    male        group D           bachelor's degree      standard
# 523    male        group C             master's degree  free/reduced
# 524    male        group C                 high school      standard
# 525    male        group E                some college      standard
# 526    male        group C            some high school  free/reduced
# 527  female        group C                 high school  free/reduced
# 528  female        group D           bachelor's degree  free/reduced
# 529  female        group C          associate's degree      standard
# 530  female        group C          associate's degree      standard
# 531  female        group C            some high school      standard
# 532    male        group E          associate's degree      standard
# 533  female        group E          associate's degree      standard
# 534    male        group B                 high school      standard
# 535  female        group C           bachelor's degree  free/reduced
# 536    male        group C          associate's degree      standard
# 537  female        group D                 high school      standard
# 538    male        group E           bachelor's degree      standard
# 539    male        group A          associate's degree      standard
# 540    male        group C                 high school      standard
# 541    male        group D          associate's degree  free/reduced
# 542  female        group C          associate's degree      standard
# 543  female        group D          associate's degree      standard
# 544  female        group D             master's degree      standard
# 545    male        group E            some high school  free/reduced
# 546  female        group A            some high school      standard
# 547    male        group C                 high school      standard
# 548  female        group C                 high school  free/reduced
# 549    male        group C             master's degree      standard
# 550    male        group C            some high school  free/reduced
# 551    male        group B           bachelor's degree  free/reduced
# 552  female        group B          associate's degree      standard
# 553    male        group D                some college  free/reduced
# 554    male        group E          associate's degree      standard
# 555  female        group C                some college  free/reduced
# 556  female        group C          associate's degree      standard
# 557    male        group C             master's degree  free/reduced
# 558  female        group B          associate's degree  free/reduced
# 559    male        group D            some high school      standard
# 560  female        group D                some college      standard
# 561  female        group C                some college      standard
# 562    male        group C           bachelor's degree      standard
# 563  female        group D                some college  free/reduced
# 564    male        group B           bachelor's degree  free/reduced
# 565    male        group B          associate's degree      standard
# 566  female        group E           bachelor's degree  free/reduced
# 567  female        group D             master's degree  free/reduced
# 568    male        group B                 high school  free/reduced
# 569    male        group D           bachelor's degree  free/reduced
# 570    male        group B                some college      standard
# 571    male        group A           bachelor's degree      standard
# 572  female        group C                some college      standard
# 573  female        group C                 high school  free/reduced
# 574  female        group E                 high school      standard
# 575    male        group A          associate's degree  free/reduced
# 576    male        group A                some college      standard
# 577  female        group B                 high school      standard
# 578  female        group B                some college  free/reduced
# 579  female        group D             master's degree      standard
# 580  female        group D            some high school      standard
# 581  female        group E            some high school      standard
# 582  female        group D           bachelor's degree  free/reduced
# 583  female        group D          associate's degree      standard
# 584  female        group D                some college      standard
# 585  female        group C          associate's degree      standard
# 586  female        group A                 high school      standard
# 587  female        group C           bachelor's degree  free/reduced
# 588  female        group C                some college      standard
# 589  female        group A            some high school      standard
# 590    male        group C                some college  free/reduced
# 591    male        group A            some high school      standard
# 592    male        group E           bachelor's degree      standard
# 593  female        group E                 high school      standard
# 594  female        group C           bachelor's degree      standard
# 595  female        group C           bachelor's degree      standard
# 596    male        group B                 high school  free/reduced
# 597    male        group A            some high school      standard
# 598  female        group D                 high school      standard
# 599  female        group D            some high school      standard
# 600  female        group D             master's degree      standard
# 601  female        group C                 high school      standard
# 602  female        group E                some college      standard
# 603    male        group D                 high school  free/reduced
# 604    male        group D             master's degree  free/reduced
# 605    male        group C            some high school      standard
# 606  female        group C          associate's degree      standard
# 607  female        group C             master's degree  free/reduced
# 608  female        group E                some college      standard
# 609  female        group B          associate's degree      standard
# 610    male        group D                some college  free/reduced
# 611  female        group C                some college      standard
# 612    male        group C           bachelor's degree      standard
# 613  female        group C          associate's degree      standard
# 614  female        group A          associate's degree      standard
# 615  female        group C                 high school      standard
# 616  female        group E           bachelor's degree      standard
# 617    male        group D           bachelor's degree      standard
# 618    male        group D             master's degree      standard
# 619    male        group C          associate's degree  free/reduced
# 620  female        group C                 high school  free/reduced
# 621    male        group B           bachelor's degree  free/reduced
# 622    male        group C                 high school  free/reduced
# 623    male        group A                some college      standard
# 624  female        group E           bachelor's degree  free/reduced
# 625    male        group D                some college      standard
# 626    male        group B          associate's degree  free/reduced
# 627    male        group D          associate's degree      standard
# 628    male        group D                some college  free/reduced
# 629  female        group C            some high school      standard
# 630    male        group D                some college      standard
# 631    male        group B                 high school      standard
# 632  female        group B           bachelor's degree      standard
# 633  female        group C                 high school      standard
# 634    male        group D            some high school      standard
# 635    male        group A                 high school      standard
# 636  female        group B                 high school  free/reduced
# 637  female        group D            some high school      standard
# 638    male        group E                some college      standard
# 639  female        group D          associate's degree      standard
# 640    male        group D                 high school      standard
# 641  female        group D          associate's degree  free/reduced
# 642  female        group B            some high school  free/reduced
# 643  female        group E                 high school      standard
# 644    male        group B                 high school      standard
# 645  female        group B           bachelor's degree      standard
# 646  female        group D          associate's degree      standard
# 647  female        group E                 high school  free/reduced
# 648  female        group B                 high school      standard
# 649  female        group D                some college      standard
# 650    male        group C            some high school  free/reduced
# 651  female        group A                 high school      standard
# 652  female        group D                some college      standard
# 653  female        group A          associate's degree      standard
# 654  female        group B            some high school      standard
# 655  female        group B                some college      standard
# 656    male        group C          associate's degree  free/reduced
# 657    male        group D            some high school      standard
# 658  female        group D          associate's degree  free/reduced
# 659    male        group D          associate's degree      standard
# 660    male        group C                some college  free/reduced
# 661    male        group C            some high school      standard
# 662  female        group D                some college  free/reduced
# 663  female        group C                 high school      standard
# 664    male        group D          associate's degree      standard
# ...
# 778               completed          72             79             82
# 779               completed          94             85             82
# 780                    none          46             56             57
# 781                    none          77             90             84
# 782               completed          76             85             82
# 783               completed          52             59             62
# 784               completed          91             81             79
# 785               completed          32             51             44
# 786                    none          72             79             77
# 787                    none          19             38             32
# 788                    none          68             65             61
# 789                    none          52             65             61
# 790                    none          48             62             60
# 791                    none          60             66             70
# 792                    none          66             74             69
# 793               completed          89             84             77
# 794                    none          42             52             51
# 795               completed          57             68             73
# 796                    none          70             70             70
# 797                    none          70             84             81
# 798                    none          69             60             54
# 799                    none          52             55             57
# 800               completed          67             73             68
# 801               completed          76             80             73
# 802                    none          87             94             95
# 803                    none          82             85             87
# 804                    none          73             76             78
# 805                    none          75             81             74
# 806                    none          64             74             75
# 807                    none          41             45             40
# 808                    none          90             75             69
# 809                    none          59             54             51
# 810                    none          51             31             36
# 811                    none          45             47             49
# 812               completed          54             64             67
# 813               completed          87             84             76
# 814                    none          72             80             83
# 815               completed          94             86             87
# 816                    none          45             59             64
# 817               completed          61             70             76
# 818                    none          60             72             68
# 819                    none          77             91             88
# 820               completed          85             90             92
# 821                    none          78             90             93
# 822               completed          49             52             51
# 823                    none          71             87             82
# 824                    none          48             58             52
# 825                    none          62             67             58
# 826               completed          56             68             70
# 827                    none          65             69             76
# 828               completed          69             86             81
# 829                    none          68             54             53
# 830                    none          61             60             57
# 831               completed          74             86             89
# 832                    none          64             60             58
# 833               completed          77             82             89
# 834                    none          58             50             45
# 835               completed          60             64             74
# 836                    none          73             64             57
# 837               completed          75             82             79
# 838               completed          58             57             53
# 839                    none          66             77             73
# 840                    none          39             52             46
# 841                    none          64             58             51
# 842               completed          23             44             36
# 843               completed          74             77             76
# 844               completed          40             65             64
# 845                    none          90             85             84
# 846               completed          91             85             85
# 847                    none          64             54             50
# 848                    none          59             72             68
# 849                    none          80             75             69
# 850                    none          71             67             67
# 851                    none          61             68             63
# 852                    none          87             85             93
# 853                    none          82             67             61
# 854                    none          62             64             55
# 855                    none          97             97             96
# 856                    none          75             68             65
# 857                    none          65             79             81
# 858               completed          52             49             46
# 859                    none          87             73             72
# 860                    none          53             62             53
# 861                    none          81             86             87
# 862               completed          39             42             38
# 863               completed          71             71             80
# 864                    none          97             93             91
# 865               completed          82             82             88
# 866                    none          59             53             52
# 867                    none          61             42             41
# 868               completed          78             74             72
# 869                    none          49             51             51
# 870                    none          59             58             47
# 871               completed          70             72             76
# 872               completed          82             84             78
# 873                    none          90             90             82
# 874                    none          43             62             61
# 875                    none          80             64             66
# 876                    none          81             82             84
# 877                    none          57             61             54
# 878                    none          59             72             80
# 879                    none          64             76             74
# 880               completed          63             64             66
# 881               completed          71             70             70
# 882                    none          64             73             71
# 883                    none          55             46             44
# 884                    none          51             51             54
# 885               completed          62             76             80
# 886               completed          93            100             95
# 887                    none          54             72             59
# 888                    none          69             65             74
# 889                    none          44             51             48
# 890               completed          86             85             91
# 891                    none          85             92             85
# 892                    none          50             67             73
# 893               completed          88             74             75
# 894                    none          59             62             69
# 895                    none          32             34             38
# 896                    none          36             29             27
# 897               completed          63             78             79
# 898               completed          67             54             63
# 899               completed          65             78             82
# 900                    none          85             84             89
# 901                    none          73             78             74
# 902               completed          34             48             41
# 903               completed          93            100            100
# 904                    none          67             84             84
# 905                    none          88             77             77
# 906                    none          57             48             51
# 907               completed          79             84             91
# 908                    none          67             75             72
# 909               completed          70             64             70
# 910                    none          50             42             48
# 911                    none          69             84             82
# 912               completed          52             61             66
# 913               completed          47             62             66
# 914                    none          46             61             55
# 915                    none          68             70             66
# 916               completed         100            100            100
# 917                    none          44             61             52
# 918               completed          57             77             80
# 919               completed          91             96             91
# 920                    none          69             70             67
# 921                    none          35             53             46
# 922                    none          72             66             66
# 923                    none          54             65             65
# 924                    none          74             70             69
# 925               completed          74             64             60
# 926                    none          64             56             52
# 927               completed          65             61             71
# 928               completed          46             43             44
# 929                    none          48             56             51
# 930               completed          67             74             70
# 931                    none          62             57             62
# 932               completed          61             71             73
# 933               completed          70             75             74
# 934               completed          98             87             90
# 935                    none          70             63             58
# 936                    none          67             57             53
# 937                    none          57             58             57
# 938               completed          85             81             85
# 939               completed          77             68             69
# 940               completed          72             66             72
# 941                    none          78             91             96
# 942                    none          81             66             64
# 943               completed          61             62             61
# 944                    none          58             68             61
# 945                    none          54             61             58
# 946                    none          82             82             80
# 947                    none          49             58             60
# 948               completed          49             50             52
# 949               completed          57             75             73
# 950                    none          94             73             71
# 951               completed          75             77             83
# 952                    none          74             74             72
# 953               completed          58             52             54
# 954                    none          62             69             69
# 955                    none          72             57             62
# 956                    none          84             87             81
# 957                    none          92            100            100
# 958                    none          45             63             59
# 959                    none          75             81             71
# 960                    none          56             58             64
# 961                    none          48             54             53
# 962                    none         100            100            100
# 963               completed          65             76             75
# 964                    none          72             57             58
# 965                    none          62             70             72
# 966               completed          66             68             64
# 967                    none          63             63             60
# 968                    none          68             76             67
# 969                    none          75             84             80
# 970                    none          89            100            100
# 971               completed          78             72             69
# 972               completed          53             50             60
# 973                    none          49             65             61
# 974                    none          54             63             67
# 975               completed          64             82             77
# 976               completed          60             62             60
# 977                    none          62             65             58
# 978               completed          55             41             48
# 979                    none          91             95             94
# 980                    none           8             24             23
# 981                    none          81             78             78
# 982               completed          79             85             86
# 983               completed          78             87             91
# 984                    none          74             75             82
# 985                    none          57             51             54
# 986                    none          40             59             51
# 987               completed          81             75             76
# 988                    none          44             45             45
# 989               completed          67             86             83
# 990               completed          86             81             75
# 991               completed          65             82             78
# 992                    none          55             76             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
df_exams['gender']
# Out:
# 0      female
# 1      female
#         ...
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
df_exams['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams['gender'].head(5)
# Out:
# 0    female
# 1    female
# 2    female
# 3      male
# 4      male
# Name: gender, dtype: object

# %%
df_exams.gender
# Out:
# 0      female
# 1      female
#         ...
# 998    female
# 999    female
# Name: gender, Length: 1000, dtype: object

# %%
df_exams['math score']
# Out:
# 0      72
# 1      69
#        ..
# 998    68
# 999    77
# Name: math score, Length: 1000, dtype: int64

# %%
df_exams['math score'][0]
# Out:
# np.int64(72)

# %%
df_exams['math score'][0] - df_exams['math score'][2]
# Out:
# np.int64(-18)

# %%
df_exams[['gender', 'math score']]
# Out:
#      gender  math score
# 0    female          72
# 1    female          69
# ..      ...         ...
# 998  female          68
# 999  female          77
#
# [1000 rows x 2 columns]

# %%
df_exams[['gender', 'writing score', 'math score', 'reading score']]
# Out:
#      gender  writing score  math score  reading score
# 0    female             74          72             72
# 1    female             88          69             90
# ..      ...            ...         ...            ...
# 998  female             77          68             78
# 999  female             86          77             86
#
# [1000 rows x 4 columns]

# %%
df_exams['language score'] = 70
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# ..      ...            ...                         ...           ...
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ..                      ...         ...            ...            ...
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                70
# 1                70
# ..              ...
# 998              70
# 999              70
#
# [1000 rows x 9 columns]

# %%
language_score = np.arange(0,1000)

# %%
len(language_score)
# Out:
# 1000

# %%
df_exams['language score'] = language_score

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# ..      ...            ...                         ...           ...
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ..                      ...         ...            ...            ...
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 0
# 1                 1
# ..              ...
# 998             998
# 999             999
#
# [1000 rows x 9 columns]

# %%
int_language_score = np.random.randint(1, 101, size=1000)

# %%
max(int_language_score)
# Out:
# np.int64(100)

# %%
df_exams['language score'] = int_language_score

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# ..      ...            ...                         ...           ...
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ..                      ...         ...            ...            ...
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score
# 0                 3
# 1                47
# ..              ...
# 998              74
# 999               4
#
# [1000 rows x 9 columns]

# %%
np.random.uniform(1, 100, size=1000)
# Out:
# array([34.72418671, 23.08240141, 80.51967695, 65.83900166, 10.31420915,
#        98.43193544, 47.89078145, 32.66397612, 38.24776396, 84.6769027 ,
#        69.70585369, 30.85405197, 17.9680932 , 44.87904919, 45.01986819,
#        20.39219251, 98.97399236, 52.68304794, 76.92773284, 34.1533849 ,
#        53.78451858, 54.9903832 , 71.36391152, 19.02299276, 44.35601399,
#        45.59236169, 14.31211068, 63.82586852,  3.54599866, 46.77121774,
#        40.65571593, 78.05668155, 14.23103991, 15.49068149,  3.95057712,
#        88.1610206 , 22.6700406 , 22.95972476, 34.73087898, 64.81977493,
#        23.74956564, 18.20768146, 34.56999131, 14.84546545, 68.68926588,
#        21.18185085, 63.56168311, 60.71031271, 26.92735078, 51.46795864,
#        43.17794593, 36.20009797, 73.63808064, 68.62640873, 50.64401308,
#         8.60976765, 98.33078899, 65.18275496,  5.47933926, 44.45829057,
#        73.21208534, 22.36353146, 64.0431409 ,  4.77459321, 81.14750291,
#        74.10081032, 49.32679466, 37.06803599, 15.41330711, 56.68249575,
#        33.55278882, 86.54779131,  7.23628179, 10.57783511, 98.83540903,
#        22.25603008, 34.28592041, 31.62655654,  5.14117053,  1.48745851,
#        26.82574685,  4.91657418, 67.95827731, 86.18875723, 39.26416472,
#        48.31377678, 40.26941461, 13.3302029 , 54.96466098, 45.69887269,
#        84.8270009 , 41.38892613, 35.2588249 , 66.01776384,  4.71748818,
#        52.76265867, 24.1036397 , 30.39735739,  9.03074135, 15.67473204,
#        81.46531127,  8.16642678, 48.91301674, 50.64129136, 85.08053867,
#        65.8666208 , 26.63862666, 40.01835172, 25.84232281,  2.79528879,
#        70.50327347, 31.42824695, 14.70657645, 34.82932523, 97.03801131,
#        94.85630157, 56.38574204, 96.62528208, 28.23217662, 77.16062616,
#        54.0886874 , 10.79565335, 23.27463949, 23.24280832, 75.71851327,
#        51.18941015, 33.75704913, 87.81456339, 38.86519604, 99.74082905,
#        95.37511624, 16.58082914, 87.29811332, 55.11761256, 82.47445598,
#        13.39204202, 76.85343731, 32.22412454, 69.176374  , 28.27541493,
#        24.64059935, 97.81021792, 75.17955664, 76.88581342, 94.60517275,
#        97.77530867, 86.20764451, 19.51188523, 89.31903147, 22.83823378,
#        51.39664959,  5.40848798, 67.03370338, 52.03905031, 60.32351637,
#        76.97779491, 50.31369338, 63.43157252, 11.83113633, 90.02949448,
#        18.96393145, 61.89740291, 11.58584893, 43.16723873, 81.65817855,
#        61.04798639, 14.83182989,  9.80112567, 81.18065665, 88.5807763 ,
#        79.6173583 , 28.89905387, 83.64901165, 61.06264217, 45.03396617,
#        70.69016656, 50.79101039, 15.57751184, 89.11174798, 53.61418129,
#        63.28051534,  8.39503378, 79.18368271, 29.31639799, 32.78164034,
#        73.8316128 , 43.93600075, 90.0716344 , 13.99042255, 76.84566417,
#        98.83053581, 53.89538316, 16.91642893, 89.41613426, 42.97240266,
#        17.12023176, 30.40932026,  4.2413293 ,  6.46509146, 26.30655329,
#        15.0298625 , 83.68344923, 17.28160169, 61.96637928, 73.12399948,
#        86.36892893, 46.53554275, 26.94303615, 28.88641101, 18.71885022,
#        84.5362669 , 45.8594192 , 12.65457725, 34.92478447, 87.59248645,
#        27.81915806, 54.45504937, 32.94768492, 83.95474433, 23.38568369,
#        69.8825946 , 89.85184445, 45.79213549, 59.79763208, 87.38446456,
#        67.35273903, 39.4615907 , 18.93474537, 78.18279301, 37.54773846,
#        32.9658964 , 36.75891167, 32.64972781, 55.89775024, 92.62900137,
#         1.02720882, 55.63100898, 18.55424718, 88.50373971, 55.23152117,
#        42.85924673, 86.69815449, 46.09235545, 90.25509821, 58.192113  ,
#         2.49316989,  9.11519799, 17.92093962, 59.70972963, 79.46897196,
#        14.77578442, 75.1411106 , 52.2601227 , 53.69254313, 63.38458669,
#        59.8018628 , 76.82688091, 24.65628663, 25.83977083, 74.20879168,
#        66.92738114,  3.24038253, 50.60541066, 99.14579683, 66.27784115,
#        78.33995691, 65.02000413, 45.79468653, 44.19901151, 62.93989289,
#         4.69830644, 68.67894474, 67.92694635, 66.06296744, 61.33531765,
#        19.01401835, 70.03226944, 89.04456632, 20.70081161, 39.96466756,
#        63.50909572, 39.32749233, 37.76912161, 61.19765784, 27.4918872 ,
#        65.50990074,  2.23761487,  3.45662872, 43.55906463, 29.82577183,
#        88.63042638, 13.27856169, 84.51753534, 46.16690126,  6.15219623,
#        76.14876353,  7.56957518, 33.26859784, 28.91643062, 44.93554903,
#        49.6712507 , 37.95188051, 46.69309735, 20.56765002, 53.2493508 ,
#        62.52826382, 54.90687896, 67.80258738, 32.37904617, 74.78364039,
#        52.2558687 , 76.04235838, 34.98499684,  4.00183421, 63.77122901,
#        78.4579107 , 66.05424321,  3.87682588,  5.28671725, 88.09121442,
#        67.30393404, 49.85926909, 58.56742921, 74.50712352, 70.81205477,
#        72.56586243, 54.01564339, 51.17834795, 55.49675246,  2.39812861,
#        80.21680766, 47.50169126, 14.39803192,  2.2796045 , 83.94348675,
#        31.29786037, 87.26998741, 82.82360533, 83.97453096, 78.4768935 ,
#        41.285473  , 68.26434038,  7.99192028, 44.77440838, 68.67089022,
#         6.55629609,  1.85535523, 76.00140435, 51.98173968, 58.59666434,
#        28.42798344, 69.32609084, 93.0576847 , 11.16703771, 57.23201512,
#        41.81437186, 89.79070983,  1.62541578, 99.62270499, 62.9082196 ,
#        40.41735903, 59.35630898, 28.07373466, 63.3268943 , 51.82333914,
#        65.95730702, 57.02716052, 27.15076894, 62.73740636, 15.47905408,
#        71.39966609, 94.21547084, 36.86589894, 73.95878648, 16.63072685,
#        38.66710418, 26.40750264, 29.08998359, 39.85878174, 13.49293499,
#        99.97514292,  1.56443313, 48.89449197, 74.91139376, 74.98584226,
#        41.69196364, 88.41552062, 28.63146053, 58.56625583, 40.69565248,
#        76.26181929, 51.11166581, 65.73332474, 82.33367965, 13.21856541,
#        34.58746753, 49.20088403, 87.45272955, 39.11428701, 95.92151206,
#        38.95674976, 86.56737011, 50.92738673, 77.98196003,  2.1733883 ,
#        94.18209217, 17.05766861, 87.05213213, 11.72852513, 79.53039828,
#        47.16998542,  2.13120935, 99.39973181, 75.024449  , 74.83289126,
#         6.52250227, 62.43199477, 39.17637308, 92.01949202, 52.08783647,
#        68.08824338, 58.85562408, 23.28037667, 34.34408546, 11.1959005 ,
#        98.25691044, 51.76413331, 17.17419752, 91.31918371, 72.77444138,
#        73.00311224, 31.78519272, 19.50153971, 73.12429804, 74.80352416,
#         3.46711729, 53.93632217, 54.91643077, 27.26357139, 67.589881  ,
#        92.20470829, 60.36246702, 56.12523401,  5.26761572, 19.39088947,
#        12.73471153, 39.55398892, 27.60443323, 49.51209651, 68.42770025,
#        37.53166289, 15.79949087, 22.97929347,  8.77122679, 38.06559938,
#        68.6460916 , 25.36167315, 84.35306165, 88.16791149, 14.38013444,
#        35.75793616, 22.36836825, 26.76876428, 62.75096026, 24.69484467,
#        94.26308879, 87.39437565, 47.28386652, 39.71684039, 29.82231902,
#        70.63067987,  3.17631283, 56.79554292, 14.1472825 ,  5.34645209,
#        67.37885702, 24.15072733,  1.19648605, 38.61667485, 51.31023067,
#        12.26208698, 21.34302523, 73.29257027,  2.92276261, 17.37591593,
#        57.57232816, 96.12101041, 79.056242  , 87.77391874, 91.13394885,
#        27.87952759, 33.18153366, 93.71860811, 92.21088265, 76.65750292,
#        80.38621124, 78.47617585, 73.26841372, 67.74033   , 20.66217717,
#        50.52263157, 72.14309232, 39.80651921, 97.90562505, 45.2514137 ,
#        75.80144194, 64.07470912, 82.06494762, 80.16115069, 47.87071928,
#        93.70991176, 39.70795447, 60.3876181 , 72.9005856 , 21.81127459,
#        30.50191939, 61.82090112, 74.70897806, 17.8406587 , 92.86092528,
#        50.91543999,  5.45039388, 52.71415991, 88.05536025, 87.86441088,
#        24.25173898, 84.28693514, 46.22733871,  4.84541584, 86.14391316,
#        29.66383515, 92.05078637, 93.96198741, 39.26783879, 31.50883387,
#        90.69771916,  6.38313673, 34.10180831, 42.45356661, 61.72039707,
#        57.28512805, 49.28533944, 38.02490443,  8.23638371, 59.00387258,
#        76.13930872, 31.32864405, 68.76895661, 68.33322839, 13.23863178,
#        59.47507552,  8.03199312, 68.28653063, 60.41605266,  1.96165074,
#        28.29478378, 96.20043175, 34.60293114, 32.52093252, 99.78902781,
#        38.08787546, 93.4098145 , 78.562957  , 49.86989755, 70.88111096,
#        43.53464226, 45.6524088 ,  2.66283713, 47.95666008, 51.24431594,
#        75.50678329, 16.01591855, 65.96167872,  4.62875323, 30.66670936,
#        84.89940656, 39.98675565, 47.001706  , 63.75711888, 59.82601866,
#        69.00983034, 98.35364965, 22.77031448, 43.10830506, 54.15312414,
#        95.89405338, 42.58124621,  8.63498454, 10.76605659, 59.28019978,
#        47.30537261,  2.77501118, 18.25248792, 15.31925225, 23.79010582,
#        47.84933726,  1.03924284, 87.46918536, 78.62446432, 66.52192521,
#        52.95333209, 35.22153652, 86.50327576, 33.874482  , 84.73406788,
#        11.1755673 , 33.83682031, 29.08537131, 75.50526933, 43.72031243,
#        92.48296203, 72.7314756 , 35.27821185, 92.71344745, 97.89598338,
#        28.47424798, 44.31610647, 74.38197918, 57.56222875, 86.312627  ,
#        39.81978134, 89.07853371, 92.83747582, 91.93756798, 52.78884807,
#        99.69603064, 84.30364826, 49.62759631, 33.82737618, 53.56470153,
#        90.46756106,  9.29227108,  2.82151451, 32.28639159, 88.05351084,
#        73.96561024, 96.25680966, 62.34950531, 55.38334434, 42.9793122 ,
#        38.78066474, 27.53022474, 13.4696635 , 64.42449626, 72.88804308,
#        85.4513885 , 97.72647252, 51.41569142, 45.82900568, 74.81953307,
#        33.88058662,  6.58883067, 20.12910499, 70.0138937 , 54.25223458,
#        11.14867147, 72.85083193, 74.80563188, 43.15699074,  5.31420741,
#        92.07026963, 23.60648588, 55.7910109 ,  4.37522135, 93.9172408 ,
#        63.46409091, 38.73953014, 97.10391081, 71.29740229, 57.22861303,
#        47.55710961, 34.25165135, 26.33048656, 53.77121385, 74.13533121,
#        24.17662494, 94.03569721,  3.04600157, 37.58052121,  2.73696059,
#        49.7626052 , 96.47276533, 90.24963619, 19.39070289, 12.27516573,
#        46.27820007,  9.83381004, 21.68197919, 18.21871529, 62.41541253,
#        20.50821491, 73.92771489, 76.52155866, 61.4456199 , 42.51155624,
#        91.10654717, 52.41275393,  2.58071317, 94.18086867, 25.34037647,
#        49.29738553, 99.0634037 , 47.29133345, 81.87315286, 58.86816872,
#        22.2195218 ,  6.04166041, 52.14161627, 13.3218978 , 10.54204354,
#        28.4986359 , 65.43754072, 27.8168879 , 18.65069942, 60.0724636 ,
#        58.73575696, 84.97432088, 57.48504984, 94.43832833, 91.05201589,
#        13.71438183, 17.42239389, 54.49952557,  5.00101864, 52.18429522,
#        67.38117984, 79.03557733, 68.76807418, 82.02679535, 97.30175969,
#        83.5123774 , 28.65120602, 10.84996786, 21.5670076 , 54.17669929,
#        88.77360746, 63.56955579, 67.44292347, 91.91622213, 51.19977656,
#         1.39959889, 48.00328292, 12.95772424, 34.58243502, 61.80810683,
#        50.71453789, 70.29339607, 98.8089601 , 20.51579251, 57.88028212,
#        98.28533134,  2.45120502, 39.78738143, 47.96662619, 19.63467216,
#        94.4961737 , 28.09565408, 25.34093188, 28.10844779, 73.5867797 ,
#        74.78171027, 66.63799938, 55.92574821, 84.40105201,  1.50678309,
#        51.30787108, 18.80669646, 70.17390185, 87.40488253, 33.36319065,
#        99.49386867, 66.81834418, 36.57941273, 51.93039084, 69.88680054,
#        40.25040291, 27.42307864,  9.94142848, 46.01189712, 77.11477157,
#        80.07632359, 73.22922211,  7.62513438, 38.63346632, 97.04888898,
#        35.87726116, 15.09795748, 52.46764544, 25.55248089,  5.16437411,
#        21.01568219, 14.42447781, 10.77466372, 88.34566405, 39.44963709,
#        27.29330324, 18.93236229, 87.71488254, 18.23872929, 72.60676674,
#        70.76846947, 47.60958173, 32.52803012, 53.36909265,  9.20629131,
#        81.7833908 , 74.02124579, 74.75840536, 67.29616883, 82.90742147,
#        12.53731604, 92.14336118,  7.63813441, 85.13573815, 17.44285676,
#        26.04605566, 65.79261617, 38.57682536, 22.43267824, 56.88567549,
#        41.07436107, 80.63613358,  6.22867914, 31.91592851, 81.64885101,
#        99.13192987, 18.70176655, 69.75645516, 83.38873718, 31.02114222,
#        36.04007885, 32.70022901, 77.45643738, 24.67143025, 81.80010616,
#        63.1234206 , 48.0252495 , 75.96500833, 50.30518244, 21.97486067,
#        40.28621569,  5.66294768, 53.79424175, 83.0749477 , 30.7121587 ,
#        34.67272631, 93.5214568 , 10.76219115, 30.924321  , 89.45202817,
#         9.47334857, 57.19271919, 87.22606554, 50.52187227, 17.32005199,
#        82.51898934,  8.12468285, 24.91346912, 48.53057932, 43.25577236,
#         1.70369524, 12.29442741, 94.43115868, 34.6530076 , 31.71887442,
#        70.57677228, 81.84088637,  6.36890359, 62.82977847, 10.62220399,
#        97.44919396,  6.04691933, 94.42084637, 80.5299842 , 25.25333198,
#        67.901387  , 68.4504372 , 70.24979695, 32.9190845 , 68.06931089,
#        52.34634385, 56.00466898, 23.68354772, 60.77372527, 61.26016559,
#        92.37557104, 15.514555  , 39.81369528, 72.38757011, 60.84462   ,
#        80.63483943, 23.58265442, 46.86579254, 17.54147117, 81.49306468,
#        27.24102041,  9.44748428, 30.97672682, 70.27248508, 14.61936873,
#        66.03830162, 82.38576899, 84.43682894, 40.59195486, 27.47125783,
#        16.64287507, 42.47590002, 67.02566643, 84.63435307,  3.08748602,
#        59.19727088, 63.65416057, 62.58630139, 23.76689289, 48.23305748,
#        28.85290925,  6.82687343, 23.78314191, 16.78851425, 99.11790537,
#        86.43847911,  4.36241617, 16.05463668, 42.26956982, 39.27491532,
#        73.14983095, 21.62872983, 76.92498041, 65.30319985, 43.40529309,
#        62.75348333, 67.25581066, 86.88151202,  5.25793124, 45.21686054,
#        55.22850488, 96.35581465, 15.90545878, 22.03251222, 74.46630984,
#        59.08716016, 89.88401545, 49.19692127, 34.03434815, 50.27565998,
#        72.36888088, 82.49319059, 16.41359987, 37.25610034, 12.49914126,
#        10.85801319, 24.94407119, 75.32814394, 17.48687897, 71.46179623,
#         2.44221491, 68.83188051, 15.4341326 , 18.5398065 , 32.32611076,
#        90.00904063, 78.14540843,  5.07662514, 68.78397385, 73.83663148,
#        84.70386405, 68.92655504, 34.44775148, 91.99410634,  9.21633273,
#        47.74973009, 86.10504689, 37.2025299 , 14.39257154, 49.23444501,
#        29.41180586, 82.294071  , 77.68161015, 46.85703193, 83.85320866,
#        75.14844236, 36.78141491, 33.27072362,  1.05717151, 78.24928881,
#        43.1628575 , 88.82815499, 60.60468655, 31.2841023 , 68.1455858 ,
#        87.35958212, 37.6772806 , 79.53975281, 25.29593576, 76.81999989,
#        60.56660846, 76.34021371, 12.80707145, 88.49177222, 70.39287342])

# %%
score1 = np.random.randint(1, 100, 1000)
score2 = np.random.randint(1, 100, 1000)

# %%
series1 = pd.Series(score1, index=np.arange(0,1000))
series2 = pd.Series(score2, index=np.arange(0,1000))

# %%
df_exams = df_exams.assign(score1=series1, score2=series2)

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# ..      ...            ...                         ...           ...
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ..                      ...         ...            ...            ...
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                 3       4      89
# 1                47      61      38
# ..              ...     ...     ...
# 998              74      26      43
# 999               4      18      15
#
# [1000 rows x 11 columns]

# %%
df_exams.insert(1, 'test', series1)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female     4        group B           bachelor's degree      standard
# 1    female    61        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 998  female    26        group D                some college      standard
# 999  female    18        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ..                      ...         ...            ...            ...
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2
# 0                 3       4      89
# 1                47      61      38
# ..              ...     ...     ...
# 998              74      26      43
# 999               4      18      15
#
# [1000 rows x 12 columns]

# %%
df_exams['math score'].sum()
# Out:
# np.int64(66089)

# %%
df_exams['math score'].count()
# Out:
# np.int64(1000)

# %%
df_exams['math score'].mean()
# Out:
# np.float64(66.089)

# %%
df_exams['math score'].std()
# Out:
# 15.163080096009468

# %%
df_exams['math score'].max()
# Out:
# 100

# %%
df_exams['math score'].min()
# Out:
# 0

# %%
df_exams.describe()
# Out:
#           test  math score  reading score  writing score  language score  \
# count  1000.00    1000.000       1000.000       1000.000        1000.000
# mean     51.19      66.089         69.169         68.054          52.297
# ...        ...         ...            ...            ...             ...
# 75%      76.00      77.000         79.000         79.000          77.000
# max      99.00     100.000        100.000        100.000         100.000
#
#         score1    score2
# count  1000.00  1000.000
# mean     51.19    48.763
# ...        ...       ...
# 75%      76.00    72.000
# max      99.00    99.000
#
# [8 rows x 7 columns]

# %%
df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']
# Out:
# 0      218
# 1      247
#       ...
# 998    223
# 999    249
# Length: 1000, dtype: int64

# %%
df_exams['average'] = (df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']) / 3

# %%
df_exams.round(2)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female     4        group B           bachelor's degree      standard
# 1    female    61        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 998  female    26        group D                some college      standard
# 999  female    18        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ..                      ...         ...            ...            ...
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2  average
# 0                 3       4      89    72.67
# 1                47      61      38    82.33
# ..              ...     ...     ...      ...
# 998              74      26      43    74.33
# 999               4      18      15    83.00
#
# [1000 rows x 13 columns]

# %%
df_exams['gender'].value_counts()
# Out:
# gender
# female    518
# male      482
# Name: count, dtype: int64

# %%
df_exams['gender'].value_counts(normalize=True)
# Out:
# gender
# female    0.518
# male      0.482
# Name: proportion, dtype: float64

# %%
df_exams['parental level of education'].value_counts()
# Out:
# parental level of education
# some college          226
# associate's degree    222
#                      ...
# bachelor's degree     118
# master's degree        59
# Name: count, Length: 6, dtype: int64

# %%
df_exams['parental level of education'].value_counts(normalize = True).round(2)
# Out:
# parental level of education
# some college          0.23
# associate's degree    0.22
#                       ...
# bachelor's degree     0.12
# master's degree       0.06
# Name: proportion, Length: 6, dtype: float64

# %%
df_exams.sort_values('math score')
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 59   female    44        group C            some high school  free/reduced
# 980  female    89        group B                 high school  free/reduced
# ..      ...   ...            ...                         ...           ...
# 962  female    59        group E          associate's degree      standard
# 149    male    88        group E          associate's degree  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 59                     none           0             17             10
# 980                    none           8             24             23
# ..                      ...         ...            ...            ...
# 962                    none         100            100            100
# 149               completed         100            100             93
#
#      language score  score1  score2     average
# 59               41      44      97    9.000000
# 980              45      89       1   18.333333
# ..              ...     ...     ...         ...
# 962              97      59      34  100.000000
# 149              32      88       2   97.666667
#
# [1000 rows x 13 columns]

# %%
df_exams.sort_values('math score', ascending=False)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 962  female    59        group E          associate's degree      standard
# 625    male    22        group D                some college      standard
# ..      ...   ...            ...                         ...           ...
# 980  female    89        group B                 high school  free/reduced
# 59   female    44        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 962                    none         100            100            100
# 625               completed         100             97             99
# ..                      ...         ...            ...            ...
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  score1  score2     average
# 962              97      59      34  100.000000
# 625              10      22      75   98.666667
# ..              ...     ...     ...         ...
# 980              45      89       1   18.333333
# 59               41      44      97    9.000000
#
# [1000 rows x 13 columns]

# %%
df_exams.sort_values(['math score', 'reading score'], ascending=False)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 149    male    88        group E          associate's degree  free/reduced
# 458  female    74        group E           bachelor's degree      standard
# ..      ...   ...            ...                         ...           ...
# 980  female    89        group B                 high school  free/reduced
# 59   female    44        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# ..                      ...         ...            ...            ...
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  score1  score2     average
# 149              32      88       2   97.666667
# 458              97      74       5  100.000000
# ..              ...     ...     ...         ...
# 980              45      89       1   18.333333
# 59               41      44      97    9.000000
#
# [1000 rows x 13 columns]

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 0    female     4        group B           bachelor's degree      standard
# 1    female    61        group C                some college      standard
# ..      ...   ...            ...                         ...           ...
# 998  female    26        group D                some college      standard
# 999  female    18        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# ..                      ...         ...            ...            ...
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      language score  score1  score2    average
# 0                 3       4      89  72.666667
# 1                47      61      38  82.333333
# ..              ...     ...     ...        ...
# 998              74      26      43  74.333333
# 999               4      18      15  83.000000
#
# [1000 rows x 13 columns]

# %%
df_exams.sort_values(['math score', 'reading score'], ascending=False, inplace=True)

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 149    male    88        group E          associate's degree  free/reduced
# 458  female    74        group E           bachelor's degree      standard
# ..      ...   ...            ...                         ...           ...
# 980  female    89        group B                 high school  free/reduced
# 59   female    44        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# ..                      ...         ...            ...            ...
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  score1  score2     average
# 149              32      88       2   97.666667
# 458              97      74       5  100.000000
# ..              ...     ...     ...         ...
# 980              45      89       1   18.333333
# 59               41      44      97    9.000000
#
# [1000 rows x 13 columns]

# %%
df_exams.sort_values('race/ethnicity', ascending=True)
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 741  female    13        group A          associate's degree  free/reduced
# 151    male    45        group A           bachelor's degree      standard
# ..      ...   ...            ...                         ...           ...
# 479    male    55        group E          associate's degree      standard
# 517  female    74        group E                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# 741                    none          37             57             56
# 151                    none          77             67             68
# ..                      ...         ...            ...            ...
# 479                    none          76             71             67
# 517               completed          66             74             73
#
#      language score  score1  score2    average
# 741              81      13      12  50.000000
# 151              31      45      40  70.666667
# ..              ...     ...     ...        ...
# 479               6      55      66  71.333333
# 517               7      74      62  71.000000
#
# [1000 rows x 13 columns]

# %%
import random

# %%
new_index = np.arange(0, 1000)

# %%
random.shuffle(new_index)

# %%
df_exams['new_index'] = new_index

# %%
df_exams
# Out:
#      gender  test race/ethnicity parental level of education         lunch  \
# 149    male    88        group E          associate's degree  free/reduced
# 458  female    74        group E           bachelor's degree      standard
# ..      ...   ...            ...                         ...           ...
# 980  female    89        group B                 high school  free/reduced
# 59   female    44        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 149               completed         100            100             93
# 458                    none         100            100            100
# ..                      ...         ...            ...            ...
# 980                    none           8             24             23
# 59                     none           0             17             10
#
#      language score  score1  score2     average  new_index
# 149              32      88       2   97.666667        330
# 458              97      74       5  100.000000        944
# ..              ...     ...     ...         ...        ...
# 980              45      89       1   18.333333        267
# 59               41      44      97    9.000000        483
#
# [1000 rows x 14 columns]

# %%
df_exams.set_index('new_index', inplace=True)

# %%
df_exams
# Out:
#            gender  test race/ethnicity parental level of education  \
# new_index
# 330          male    88        group E          associate's degree
# 944        female    74        group E           bachelor's degree
# ...           ...   ...            ...                         ...
# 267        female    89        group B                 high school
# 483        female    44        group C            some high school
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# 330        free/reduced               completed         100            100
# 944            standard                    none         100            100
# ...                 ...                     ...         ...            ...
# 267        free/reduced                    none           8             24
# 483        free/reduced                    none           0             17
#
#            writing score  language score  score1  score2     average
# new_index
# 330                   93              32      88       2   97.666667
# 944                  100              97      74       5  100.000000
# ...                  ...             ...     ...     ...         ...
# 267                   23              45      89       1   18.333333
# 483                   10              41      44      97    9.000000
#
# [1000 rows x 13 columns]

# %%
df_exams.sort_index(ascending=False, inplace=True)

# %%
df_exams
# Out:
#            gender  test race/ethnicity parental level of education  \
# new_index
# 999          male    68        group D                some college
# 998        female    89        group D             master's degree
# ...           ...   ...            ...                         ...
# 1          female    57        group A                 high school
# 0          female    16        group A                some college
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# 999            standard                    none          68             59
# 998            standard                    none          64             63
# ...                 ...                     ...         ...            ...
# 1          free/reduced               completed          53             50
# 0              standard               completed          78             87
#
#            writing score  language score  score1  score2    average
# new_index
# 999                   62              55      68      53  63.000000
# 998                   66              72      89      85  64.333333
# ...                  ...             ...     ...     ...        ...
# 1                     60              76      57      98  54.333333
# 0                     91              31      16      29  85.333333
#
# [1000 rows x 13 columns]

# %%
df_exams = df_exams.rename(columns={'gender':'Gender'})

# %%
df_exams
# Out:
#            Gender  test race/ethnicity parental level of education  \
# new_index
# 999          male    68        group D                some college
# 998        female    89        group D             master's degree
# ...           ...   ...            ...                         ...
# 1          female    57        group A                 high school
# 0          female    16        group A                some college
#
#                   lunch test preparation course  math score  reading score  \
# new_index
# 999            standard                    none          68             59
# 998            standard                    none          64             63
# ...                 ...                     ...         ...            ...
# 1          free/reduced               completed          53             50
# 0              standard               completed          78             87
#
#            writing score  language score  score1  score2    average
# new_index
# 999                   62              55      68      53  63.000000
# 998                   66              72      89      85  64.333333
# ...                  ...             ...     ...     ...        ...
# 1                     60              76      57      98  54.333333
# 0                     91              31      16      29  85.333333
#
# [1000 rows x 13 columns]

# %%
df_exams.rename(columns={'math score':'MS', 'reading score':'RS', 'writing score':'WS'}, inplace=True)

# %%
df_exams
# Out:
#            Gender  test race/ethnicity parental level of education  \
# new_index
# 999          male    68        group D                some college
# 998        female    89        group D             master's degree
# ...           ...   ...            ...                         ...
# 1          female    57        group A                 high school
# 0          female    16        group A                some college
#
#                   lunch test preparation course  MS  RS  WS  language score  \
# new_index
# 999            standard                    none  68  59  62              55
# 998            standard                    none  64  63  66              72
# ...                 ...                     ...  ..  ..  ..             ...
# 1          free/reduced               completed  53  50  60              76
# 0              standard               completed  78  87  91              31
#
#            score1  score2    average
# new_index
# 999            68      53  63.000000
# 998            89      85  64.333333
# ...           ...     ...        ...
# 1              57      98  54.333333
# 0              16      29  85.333333
#
# [1000 rows x 13 columns]

# %%
df_exams.rename(index={0:'A', 1:'B', 2:'C'}, inplace=True)

# %%
df_exams
# Out:
#            Gender  test race/ethnicity parental level of education  \
# new_index
# 999          male    68        group D                some college
# 998        female    89        group D             master's degree
# ...           ...   ...            ...                         ...
# B          female    57        group A                 high school
# A          female    16        group A                some college
#
#                   lunch test preparation course  MS  RS  WS  language score  \
# new_index
# 999            standard                    none  68  59  62              55
# 998            standard                    none  64  63  66              72
# ...                 ...                     ...  ..  ..  ..             ...
# B          free/reduced               completed  53  50  60              76
# A              standard               completed  78  87  91              31
#
#            score1  score2    average
# new_index
# 999            68      53  63.000000
# 998            89      85  64.333333
# ...           ...     ...        ...
# B              57      98  54.333333
# A              16      29  85.333333
#
# [1000 rows x 13 columns]

# %%
df_exams.head(3)
# Out:
#            Gender  test race/ethnicity parental level of education  \
# new_index
# 999          male    68        group D                some college
# 998        female    89        group D             master's degree
# 997        female    41        group C            some high school
#
#                   lunch test preparation course  MS  RS  WS  language score  \
# new_index
# 999            standard                    none  68  59  62              55
# 998            standard                    none  64  63  66              72
# 997        free/reduced               completed  29  40  44              96
#
#            score1  score2    average
# new_index
# 999            68      53  63.000000
# 998            89      85  64.333333
# 997            41      53  37.666667

# %%
df_premier21 = pd.read_csv('https://www.football-data.co.uk/mmz4281/2122/E0.csv')

# %%
df_premier21
# Out:
#     Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  13/08/2021  20:00   Brentford      Arsenal     2     0   H     1
# 1    E0  14/08/2021  12:30  Man United        Leeds     5     1   H     1
# ..   ..         ...    ...         ...          ...   ...   ...  ..   ...
# 378  E0  22/05/2022  16:00    Man City  Aston Villa     3     2   H     0
# 379  E0  22/05/2022  16:00     Norwich    Tottenham     0     5   A     0
#
#      HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0       0  ...     1.62  0.50      1.75      2.05   1.81   2.13     2.05
# 1       0  ...     2.25 -1.00      2.05      1.75   2.17   1.77     2.19
# ..    ...  ...      ...   ...       ...       ...    ...    ...      ...
# 378     1  ...     3.36 -2.25      2.06      1.84   2.05   1.86     2.09
# 379     2  ...     2.40  1.50      1.95      1.95   1.96   1.94     2.16
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       2.17     1.80     2.09
# 1       1.93     2.10     1.79
# ..       ...      ...      ...
# 378     2.03     2.01     1.87
# 379     1.98     1.99     1.89
#
# [380 rows x 106 columns]

# %%
df_premier21.rename(columns={'FTHG':'home_goals','FTAG':'away_goals'}, inplace=True)

# %%
df_premier21
# Out:
#     Div        Date   Time    HomeTeam     AwayTeam  home_goals  away_goals  \
# 0    E0  13/08/2021  20:00   Brentford      Arsenal           2           0
# 1    E0  14/08/2021  12:30  Man United        Leeds           5           1
# ..   ..         ...    ...         ...          ...         ...         ...
# 378  E0  22/05/2022  16:00    Man City  Aston Villa           3           2
# 379  E0  22/05/2022  16:00     Norwich    Tottenham           0           5
#
#     FTR  HTHG  HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  \
# 0     H     1     0  ...     1.62  0.50      1.75      2.05   1.81   2.13
# 1     H     1     0  ...     2.25 -1.00      2.05      1.75   2.17   1.77
# ..   ..   ...   ...  ...      ...   ...       ...       ...    ...    ...
# 378   H     0     1  ...     3.36 -2.25      2.06      1.84   2.05   1.86
# 379   A     0     2  ...     2.40  1.50      1.95      1.95   1.96   1.94
#
#      MaxCAHH  MaxCAHA  AvgCAHH  AvgCAHA
# 0       2.05     2.17     1.80     2.09
# 1       2.19     1.93     2.10     1.79
# ..       ...      ...      ...      ...
# 378     2.09     2.03     2.01     1.87
# 379     2.16     1.98     1.99     1.89
#
# [380 rows x 106 columns]

# %%
root = "https://www.football-data.co.uk/mmz4281/"

# %%
leagues = ['E0', 'E1', 'E2', 'E3', 'EC']
frames = []
for league in leagues:
    df = pd.read_csv(f"{root}2122/{league}.csv", encoding='unicode_escape')
    frames.append(df)

# %%
len(frames)
# Out:
# 5

# %%
frames[0]
# Out:
#     Div        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0  13/08/2021  20:00   Brentford      Arsenal     2     0   H     1
# 1    E0  14/08/2021  12:30  Man United        Leeds     5     1   H     1
# ..   ..         ...    ...         ...          ...   ...   ...  ..   ...
# 378  E0  22/05/2022  16:00    Man City  Aston Villa     3     2   H     0
# 379  E0  22/05/2022  16:00     Norwich    Tottenham     0     5   A     0
#
#      HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0       0  ...     1.62  0.50      1.75      2.05   1.81   2.13     2.05
# 1       0  ...     2.25 -1.00      2.05      1.75   2.17   1.77     2.19
# ..    ...  ...      ...   ...       ...       ...    ...    ...      ...
# 378     1  ...     3.36 -2.25      2.06      1.84   2.05   1.86     2.09
# 379     2  ...     2.40  1.50      1.95      1.95   1.96   1.94     2.16
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       2.17     1.80     2.09
# 1       1.93     2.10     1.79
# ..       ...      ...      ...
# 378     2.03     2.01     1.87
# 379     1.98     1.99     1.89
#
# [380 rows x 106 columns]

# %%
frames[-1]
# Out:
#     Div        Date   Time   HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    EC  21/08/2021  15:00  Aldershot  Chesterfield     0     2   A     0
# 1    EC  21/08/2021  15:00     Barnet  Notts County     0     5   A     0
# ..   ..         ...    ...        ...           ...   ...   ...  ..   ...
# 504  EC  15/05/2022  15:00   Southend       Torquay     1     1   D     0
# 505  EC  15/05/2022  15:00  Stockport       Halifax     2     0   H     1
#
#      HTAG  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0       0  ...     1.93  0.50      1.98      1.83   2.03   1.83     2.05
# 1       0  ...     2.06  0.75      1.88      1.93   1.90   1.95     2.00
# ..    ...  ...      ...   ...       ...       ...    ...    ...      ...
# 504     1  ...     2.01 -0.25      2.02      1.77   2.03   1.83     2.07
# 505     0  ...     1.97 -0.75      1.80      2.00   1.79   2.08     1.93
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       1.90     1.97     1.80
# 1       1.95     1.90     1.88
# ..       ...      ...      ...
# 504     1.85     2.00     1.80
# 505     2.08     1.84     1.95
#
# [506 rows x 98 columns]

# %%
for season in range(15, 21):
    print(str(season) + str(season + 1))
# Out:
# 1516
# 1617
# 1718
# 1819
# 1920
# 2021

# %%
leagues = ['E0', 'E1', 'E2', 'E3', 'EC']
frames = []

for league in leagues:
    for season in range(15, 21):
        df = pd.read_csv(f"{root}{str(season) + str(season + 1)}/{league}.csv", encoding='unicode_escape')
        df.insert(1, 'season', season)
        frames.append(df)

# %%
frames
# Out:
# [    Div  season        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    E0      15  08/08/2015  Bournemouth  Aston Villa     0     1   A     0
#  1    E0      15  08/08/2015      Chelsea      Swansea     2     2   D     2
#  ..   ..     ...         ...          ...          ...   ...   ...  ..   ...
#  378  E0      15  15/05/2016    West Brom    Liverpool     1     1   D     1
#  379  E0      15  17/05/2016   Man United  Bournemouth     3     1   H     1
#
#       HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
#  0       0  ...     1.79   26  -0.50     1.98     1.93     1.99     1.92  1.82
#  1       1  ...     1.99   27  -1.50     2.24     2.16     1.80     1.73  1.37
#  ..    ...  ...      ...  ...    ...      ...      ...      ...      ...   ...
#  378     1  ...     2.09   30  -0.25     2.10     2.05     1.86     1.81  2.61
#  379     0  ...     2.20   29  -0.75     1.88     1.84     2.08     2.02  1.50
#
#       PSCD   PSCA
#  0    3.88   4.70
#  1    5.04  10.88
#  ..    ...    ...
#  378  3.75   2.70
#  379  4.60   7.03
#
#  [380 rows x 66 columns],
#      Div  season      Date        HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    E0      16  13/08/16         Burnley    Swansea     0     1   A     0
#  1    E0      16  13/08/16  Crystal Palace  West Brom     0     1   A     0
#  ..   ..     ...       ...             ...        ...   ...   ...  ..   ...
#  378  E0      16  21/05/17         Swansea  West Brom     2     1   H     0
#  379  E0      16  21/05/17         Watford   Man City     0     5   A     0
#
#       HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  \
#  0       0  ...     1.61   32  -0.25     2.13     2.06     1.86     1.81
#  1       0  ...     1.52   33  -0.50     2.07     2.00     1.90     1.85
#  ..    ...  ...      ...  ...    ...      ...      ...      ...      ...
#  378     1  ...     1.98   19  -0.50     2.11     2.06     1.86     1.82
#  379     4  ...     2.80   18   1.75     1.99     1.94     2.00     1.93
#
#        PSCH  PSCD  PSCA
#  0     2.79  3.16  2.89
#  1     2.25  3.15  3.86
#  ..     ...   ...   ...
#  378   2.29  3.45  3.40
#  379  18.00  9.70  1.16
#
#  [380 rows x 66 columns],
#      Div  season        Date   HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
#  0    E0      17  11/08/2017    Arsenal  Leicester     4     3   H     2     2
#  1    E0      17  12/08/2017   Brighton   Man City     0     2   A     0     0
#  ..   ..     ...         ...        ...        ...   ...   ...  ..   ...   ...
#  378  E0      17  13/05/2018  Tottenham  Leicester     5     4   H     1     2
#  379  E0      17  13/05/2018   West Ham    Everton     3     1   H     1     0
#
#       ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA   PSCH  \
#  0    ...     2.32   21  -1.00     1.91     1.85     2.10     2.02   1.49
#  1    ...     2.27   20   1.50     1.95     1.91     2.01     1.96  11.75
#  ..   ...      ...  ...    ...      ...      ...      ...      ...    ...
#  378  ...     2.84   20  -1.50     1.96     1.86     2.05     2.00   1.38
#  379  ...     1.97   21  -0.25     2.09     2.03     1.88     1.84   2.35
#
#       PSCD  PSCA
#  0    4.73  7.25
#  1    6.15  1.29
#  ..    ...   ...
#  378  5.50  8.15
#  379  3.40  3.28
#
#  [380 rows x 66 columns],
#      Div  season        Date     HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    E0      18  10/08/2018   Man United  Leicester     2     1   H     1
#  1    E0      18  11/08/2018  Bournemouth    Cardiff     2     0   H     1
#  ..   ..     ...         ...          ...        ...   ...   ...  ..   ...
#  378  E0      18  12/05/2019    Tottenham    Everton     2     2   D     1
#  379  E0      18  12/05/2019      Watford   West Ham     1     4   A     0
#
#       HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
#  0       0  ...     1.79   17  -0.75     1.75     1.70     2.29     2.21  1.55
#  1       0  ...     1.83   20  -0.75     2.20     2.13     1.80     1.75  1.88
#  ..    ...  ...      ...  ...    ...      ...      ...      ...      ...   ...
#  378     0  ...     2.07   19  -0.50     2.13     2.08     1.85     1.80  1.91
#  379     2  ...     2.44   19  -0.50     2.25     2.19     1.78     1.72  2.11
#
#       PSCD  PSCA
#  0    4.07  7.69
#  1    3.61  4.70
#  ..    ...   ...
#  378  3.81  4.15
#  379  3.86  3.41
#
#  [380 rows x 63 columns],
#      Div  season        Date   Time     HomeTeam          AwayTeam  FTHG  FTAG  \
#  0    E0      19  09/08/2019  20:00    Liverpool           Norwich     4     1
#  1    E0      19  10/08/2019  12:30     West Ham          Man City     0     5
#  ..   ..     ...         ...    ...          ...               ...   ...   ...
#  378  E0      19  26/07/2020  16:00  Southampton  Sheffield United     3     1
#  379  E0      19  26/07/2020  16:00     West Ham       Aston Villa     1     1
#
#      FTR  HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
#  0     H     4  ...      3.43 -2.25     1.91      1.99   1.94   1.98     1.99
#  1     A     0  ...      2.91  1.75     1.95      1.95   1.96   1.97     2.07
#  ..   ..   ...  ...       ...   ...      ...       ...    ...    ...      ...
#  378   H     0  ...      2.01 -0.50     1.97      1.93   2.00   1.93     2.03
#  379   D     0  ...      2.03  0.00     1.93      1.97   1.95   1.98     1.99
#
#       MaxCAHA  AvgCAHH  AvgCAHA
#  0       2.07     1.90     1.99
#  1       1.98     1.97     1.92
#  ..       ...      ...      ...
#  378     1.96     1.98     1.89
#  379     2.00     1.93     1.95
#
#  [380 rows x 107 columns],
#      Div  season        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG  \
#  0    E0      20  12/09/2020  12:30          Fulham      Arsenal     0     3
#  1    E0      20  12/09/2020  15:00  Crystal Palace  Southampton     1     0
#  ..   ..     ...         ...    ...             ...          ...   ...   ...
#  378  E0      20  23/05/2021  16:00        West Ham  Southampton     3     0
#  379  E0      20  23/05/2021  16:00          Wolves   Man United     1     2
#
#      FTR  HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
#  0     A     0  ...      1.84  0.75     2.01      1.89   2.02   1.91     2.13
#  1     H     1  ...      1.70  0.25     1.78      2.13   1.79   2.17     1.85
#  ..   ..   ...  ...       ...   ...      ...       ...    ...    ...      ...
#  378   H     2  ...      2.14 -0.75     2.00      1.90   2.02   1.91     2.06
#  379   A     1  ...      1.62 -0.25     2.04      1.86   2.10   1.84     2.10
#
#       MaxCAHA  AvgCAHH  AvgCAHA
#  0       1.92     2.02     1.87
#  1       2.18     1.79     2.12
#  ..       ...      ...      ...
#  378     2.01     1.99     1.89
#  379     1.94     2.00     1.88
#
#  [380 rows x 107 columns],
#      Div  season      Date    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    E1      15  07/08/15    Brighton   Nott'm Forest     1     0   H     0
#  1    E1      15  08/08/15  Birmingham         Reading     2     1   H     1
#  ..   ..     ...       ...         ...             ...   ...   ...  ..   ...
#  550  E1      15  07/05/16         QPR    Bristol City     1     0   H     0
#  551  E1      15  07/05/16      Wolves  Sheffield Weds     2     1   H     2
#
#       HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
#  0       0  ...     1.65   24   0.00     1.75     1.65     2.34     2.25  2.24
#  1       0  ...     1.69   25  -0.25     2.14     2.07     1.81     1.77  2.53
#  ..    ...  ...      ...  ...    ...      ...      ...      ...      ...   ...
#  550     0  ...     1.95   29  -0.25     2.09     2.03     1.87     1.80  2.47
#  551     0  ...     1.84   30  -0.25     2.06     2.01     1.88     1.83  2.37
#
#       PSCD  PSCA
#  0    3.42  3.55
#  1    3.28  3.08
#  ..    ...   ...
#  550  3.59  2.92
#  551  3.53  3.13
#
#  [552 rows x 66 columns],
#      Div  season      Date    HomeTeam   AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
#  0    E1      16  05/08/16      Fulham  Newcastle     1     0   H     1     0
#  1    E1      16  06/08/16  Birmingham    Cardiff     0     0   D     0     0
#  ..   ..     ...       ...         ...        ...   ...   ...  ..   ...   ...
#  550  E1      16  07/05/17       Wigan      Leeds     1     1   D     1     0
#  551  E1      16  07/05/17      Wolves    Preston     1     0   H     1     0
#
#       ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  PSCD  \
#  0    ...     1.91   32   0.25     2.21     2.14     1.76     1.72  4.39  3.42
#  1    ...     1.65   32  -0.25     2.06     1.98     1.94     1.84  2.53  3.26
#  ..   ...      ...  ...    ...      ...      ...      ...      ...   ...   ...
#  550  ...     1.90   18   0.25     1.85     1.82     2.08     2.03  2.55  3.54
#  551  ...     2.03   19  -0.50     2.11     2.05     1.85     1.81  2.11  3.70
#
#       PSCA
#  0    2.00
#  1    3.14
#  ..    ...
#  550  2.86
#  551  3.57
#
#  [552 rows x 66 columns],
#      Div  season      Date        HomeTeam  AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    E1      17  04/08/17   Nott'm Forest  Millwall     1     0   H     1
#  1    E1      17  04/08/17      Sunderland     Derby     1     1   D     1
#  ..   ..     ...       ...             ...       ...   ...   ...  ..   ...
#  550  E1      17  06/05/18  Sheffield Weds   Norwich     5     1   H     2
#  551  E1      17  06/05/18      Sunderland    Wolves     3     0   H     2
#
#       HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
#  0       0  ...     1.76   20   -0.5     2.06     2.01     1.90     1.86  1.98
#  1       1  ...     1.66   19    0.0     1.91     1.84     2.07     2.02  2.77
#  ..    ...  ...      ...  ...    ...      ...      ...      ...      ...   ...
#  550     0  ...     2.21   17    0.0     1.98     1.94     1.95     1.91  3.13
#  551     0  ...     2.18   21    1.0     1.99     1.93     1.95     1.90  6.43
#
#       PSCD  PSCA
#  0    3.50  4.25
#  1    3.16  2.84
#  ..    ...   ...
#  550  3.58  2.35
#  551  4.50  1.55
#
#  [552 rows x 66 columns],
#      Div  season        Date    HomeTeam          AwayTeam  FTHG  FTAG FTR  \
#  0    E1      18  03/08/2018     Reading             Derby     1     2   A
#  1    E1      18  04/08/2018  Birmingham           Norwich     2     2   D
#  ..   ..     ...         ...         ...               ...   ...   ...  ..
#  550  E1      18  05/05/2019       Stoke  Sheffield United     2     2   D
#  551  E1      18  05/05/2019       Wigan          Millwall     1     0   H
#
#       HTHG  HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  \
#  0     0.0   0.0  ...     1.67   20   0.25     2.01     1.96     1.95     1.88
#  1     0.0   0.0  ...     1.64   19  -0.25     2.23     2.15     1.77     1.72
#  ..    ...   ...  ...      ...  ...    ...      ...      ...      ...      ...
#  550   1.0   0.0  ...     1.83   17   0.50     1.75     1.69     2.25     2.19
#  551   1.0   0.0  ...     1.95   17  -0.50     2.20     2.12     1.79     1.73
#
#       PSCH  PSCD  PSCA
#  0    3.78  3.29  2.19
#  1    2.86  3.14  2.79
#  ..    ...   ...   ...
#  550  3.36  3.45  2.28
#  551  2.17  3.57  3.52
#
#  [552 rows x 63 columns],
#      Div  season        Date   Time   HomeTeam       AwayTeam  FTHG  FTAG FTR  \
#  0    E1      19  02/08/2019  19:45      Luton  Middlesbrough     3     3   D
#  1    E1      19  03/08/2019  15:00   Barnsley         Fulham     1     0   H
#  ..   ..     ...         ...    ...        ...            ...   ...   ...  ..
#  550  E1      19  22/07/2020  19:30  West Brom            QPR     2     2   D
#  551  E1      19  22/07/2020  19:30      Wigan         Fulham     1     1   D
#
#       HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
#  0       2  ...      1.79 -0.25     1.94      1.96   1.96   1.96     1.98
#  1       1  ...      2.13  0.25     2.04      1.86   2.05   1.87     2.07
#  ..    ...  ...       ...   ...      ...       ...    ...    ...      ...
#  550     1  ...      2.61 -1.75     1.93      1.97   1.93   1.97     1.95
#  551     1  ...      2.25  0.00     1.98      1.92   1.97   1.93     2.07
#
#       MaxCAHA  AvgCAHH  AvgCAHA
#  0       1.98     1.94     1.93
#  1       1.88     2.02     1.84
#  ..       ...      ...      ...
#  550     2.00     1.92     1.94
#  551     1.96     1.99     1.86
#
#  [552 rows x 107 columns],
#      Div  season        Date   Time    HomeTeam       AwayTeam  FTHG  FTAG FTR  \
#  0    E1      20  11/09/2020  19:45     Watford  Middlesbrough     1     0   H
#  1    E1      20  12/09/2020  12:30  Birmingham      Brentford     1     0   H
#  ..   ..     ...         ...    ...         ...            ...   ...   ...  ..
#  550  E1      20  08/05/2021  12:30     Reading   Huddersfield     2     2   D
#  551  E1      20  08/05/2021  12:30     Watford        Swansea     2     0   H
#
#       HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
#  0       1  ...      1.65 -0.50     2.05      1.85   2.04   1.85     2.09
#  1       1  ...      1.67  0.50     1.97      1.93   1.96   1.93     1.97
#  ..    ...  ...       ...   ...      ...       ...    ...    ...      ...
#  550     2  ...      2.11 -0.50     1.85      2.05   1.86   2.05     1.88
#  551     0  ...      1.80 -0.25     2.08      1.82   2.07   1.85     2.14
#
#       MaxCAHA  AvgCAHH  AvgCAHA
#  0       1.88     2.02     1.82
#  1       1.99     1.91     1.93
#  ..       ...      ...      ...
#  550     2.08     1.84     2.01
#  551     1.90     2.04     1.82
#
#  [552 rows x 107 columns],
#       Div  season      Date      HomeTeam    AwayTeam  FTHG  FTAG  FTR  HTHG  \
#  0     E2      15  08/08/15        Burton  Scunthorpe   2.0   1.0    H   0.0
#  1     E2      15  08/08/15  Chesterfield    Barnsley   3.0   1.0    H   0.0
#  ..   ...     ...       ...           ...         ...   ...   ...  ...   ...
#  551   E2      15  08/05/16         Wigan    Barnsley   1.0   4.0    A   1.0
#  552  NaN      15       NaN           NaN         NaN   NaN   NaN  NaN   NaN
#
#       HTAG  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  \
#  0     0.0  ...     1.74  25.0  -0.25     1.99     1.93     1.94     1.88
#  1     1.0  ...     1.75  25.0  -0.25     1.93     1.87     2.02     1.94
#  ..    ...  ...      ...   ...    ...      ...      ...      ...      ...
#  551   2.0  ...     2.00  27.0  -0.25     2.08     2.01     1.87     1.82
#  552   NaN  ...      NaN   NaN    NaN      NaN      NaN      NaN      NaN
#
#       PSCH  PSCD  PSCA
#  0    2.40  3.38  3.19
#  1    2.02  3.60  3.96
#  ..    ...   ...   ...
#  551  2.32  3.85  2.99
#  552   NaN   NaN   NaN
#
#  [553 rows x 66 columns],
#      Div  season      Date  HomeTeam            AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    E2      16  06/08/16    Bolton    Sheffield United     1     0   H     1
#  1    E2      16  06/08/16  Bradford           Port Vale     0     0   D     0
#  ..   ..     ...       ...       ...                 ...   ...   ...  ..   ...
#  550  E2      16  30/04/17  Southend                Bury     1     0   H     1
#  551  E2      16  30/04/17   Walsall  Milton Keynes Dons     1     4   A     0
#
#       HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
#  0       0  ...     1.68   28   0.00     2.08     2.00     1.87     1.81  3.20
#  1       0  ...     1.68   29  -0.75     1.97     1.91     1.96     1.91  1.78
#  ..    ...  ...      ...  ...    ...      ...      ...      ...      ...   ...
#  550     0  ...     2.03   18  -0.75     2.01     1.96     1.95     1.88  1.78
#  551     2  ...     1.90   16   0.00     2.10     2.06     1.84     1.81  3.21
#
#       PSCD  PSCA
#  0    3.35  2.41
#  1    3.59  5.45
#  ..    ...   ...
#  550  3.89  4.86
#  551  3.66  2.27
#
#  [552 rows x 66 columns],
#      Div  season      Date    HomeTeam            AwayTeam  FTHG  FTAG FTR  \
#  0    E2      17  05/08/17    Bradford           Blackpool     2     1   H
#  1    E2      17  05/08/17        Bury             Walsall     1     0   H
#  ..   ..     ...       ...         ...                 ...   ...   ...  ..
#  550  E2      17  05/05/18  Shrewsbury  Milton Keynes Dons     0     1   A
#  551  E2      17  05/05/18    Southend         Bristol Rvs     0     0   D
#
#       HTHG  HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  \
#  0       1     1  ...     1.64   16  -0.75     1.86     1.81     2.08     2.04
#  1       1     0  ...     1.79   16  -0.50     2.09     2.03     1.87     1.82
#  ..    ...   ...  ...      ...  ...    ...      ...      ...      ...      ...
#  550     0     0  ...     1.77   17  -0.75     2.12     2.03     1.84     1.80
#  551     0     0  ...     1.98   19  -0.25     2.03     1.95     1.95     1.87
#
#       PSCH  PSCD  PSCA
#  0    1.69  3.97  5.50
#  1    2.02  3.55  4.03
#  ..    ...   ...   ...
#  550  1.76  3.84  4.98
#  551  2.23  3.78  3.16
#
#  [552 rows x 66 columns],
#      Div  season        Date    HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    E2      18  04/08/2018  Accrington      Gillingham     0     2   A     0
#  1    E2      18  04/08/2018    Barnsley          Oxford     4     0   H     2
#  ..   ..     ...         ...         ...             ...   ...   ...  ..   ...
#  550  E2      18  04/05/2019    Southend      Sunderland     2     1   H     1
#  551  E2      18  04/05/2019     Wycombe  Fleetwood Town     1     0   H     0
#
#       HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
#  0       2  ...     1.77   19  -0.25     2.02     1.96     1.90     1.86  2.38
#  1       0  ...     1.92   18  -0.50     2.02     1.95     1.95     1.87  1.83
#  ..    ...  ...      ...  ...    ...      ...      ...      ...      ...   ...
#  550     0  ...     1.84   16   0.00     2.06     2.01     1.87     1.82  2.97
#  551     0  ...     1.71   18  -0.50     2.20     2.11     1.79     1.73  2.39
#
#       PSCD  PSCA
#  0    3.36  3.17
#  1    3.82  4.44
#  ..    ...   ...
#  550  3.71  2.35
#  551  3.34  3.20
#
#  [552 rows x 63 columns],
#      Div  season        Date   Time       HomeTeam        AwayTeam  FTHG  FTAG  \
#  0    E2      19  03/08/2019  15:00  AFC Wimbledon       Rotherham     1     2
#  1    E2      19  03/08/2019  15:00      Blackpool     Bristol Rvs     2     0
#  ..   ..     ...         ...    ...            ...             ...   ...   ...
#  398  E2      19  10/03/2020  19:45         Burton          Bolton     2     2
#  399  E2      19  10/03/2020  19:45     Portsmouth  Fleetwood Town     2     2
#
#      FTR  HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
#  0     A     0  ...      1.72  0.25     1.88      1.98   1.84   2.06     1.95
#  1     H     1  ...      1.65 -0.50     2.02      1.83   2.06   1.84     2.09
#  ..   ..   ...  ...       ...   ...      ...       ...    ...    ...      ...
#  398   D     1  ...      2.08 -1.00     2.02      1.83   2.04   1.86     2.07
#  399   D     1  ...      1.62 -0.25     1.75      2.05   1.77   2.15     1.83
#
#       MaxCAHA  AvgCAHH  AvgCAHA
#  0       2.04     1.88     1.96
#  1       1.87     2.03     1.82
#  ..       ...      ...      ...
#  398     1.98     1.98     1.84
#  399     2.16     1.76     2.09
#
#  [400 rows x 107 columns],
#      Div  season        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  \
#  0    E2      20  12/09/2020  15:00  Accrington    Peterboro     2     0   H
#  1    E2      20  12/09/2020  15:00       Crewe     Charlton     0     2   A
#  ..   ..     ...         ...    ...         ...          ...   ...   ...  ..
#  550  E2      20  09/05/2021  12:00  Sunderland  Northampton     1     1   D
#  551  E2      20  09/05/2021  12:00       Wigan      Swindon     3     4   A
#
#       HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
#  0       1  ...      2.03  0.25     2.02      1.83   2.08   1.83     2.09
#  1       0  ...      1.88  0.00     1.95      1.90   1.96   1.94     2.00
#  ..    ...  ...       ...   ...      ...       ...    ...    ...      ...
#  550     0  ...      2.13 -1.25     1.98      1.88   2.02   1.88     2.10
#  551     1  ...      2.28 -0.75     1.93      1.93   2.00   1.88     2.01
#
#       MaxCAHA  AvgCAHH  AvgCAHA
#  0       1.87     2.02     1.81
#  1       1.95     1.94     1.89
#  ..       ...      ...      ...
#  550     1.91     2.01     1.83
#  551     1.97     1.93     1.90
#
#  [552 rows x 107 columns],
#       Div  season      Date       HomeTeam       AwayTeam  FTHG  FTAG  FTR  \
#  0     E3      15  08/08/15     Accrington          Luton   1.0   1.0    D
#  1     E3      15  08/08/15  AFC Wimbledon       Plymouth   0.0   2.0    A
#  ..   ...     ...       ...            ...            ...   ...   ...  ...
#  551   E3      15  07/05/16         Yeovil  Leyton Orient   0.0   1.0    A
#  552  NaN      15       NaN            NaN            NaN   NaN   NaN  NaN
#
#       HTHG  HTAG  ... BbAv<2.5  BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  \
#  0     0.0   0.0  ...     1.65  25.0   0.25     1.82     1.77     2.14
#  1     0.0   1.0  ...     1.61  27.0   0.00     1.86     1.80     2.11
#  ..    ...   ...  ...      ...   ...    ...      ...      ...      ...
#  551   0.0   0.0  ...     1.72  27.0   0.25     1.83     1.80     2.12
#  552   NaN   NaN  ...      NaN   NaN    NaN      NaN      NaN      NaN
#
#       BbAvAHA  PSCH  PSCD  PSCA
#  0       2.06  3.71  3.37  2.18
#  1       2.01  2.58  3.28  3.01
#  ..       ...   ...   ...   ...
#  551     2.04  3.06  3.45  2.45
#  552      NaN   NaN   NaN   NaN
#
#  [553 rows x 66 columns],
#      Div  season      Date    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  HTAG  \
#  0    E3      16  06/08/16  Accrington   Doncaster     3     2   H     2     1
#  1    E3      16  06/08/16   Blackpool      Exeter     2     0   H     1     0
#  ..   ..     ...       ...         ...         ...   ...   ...  ..   ...   ...
#  550  E3      16  06/05/17   Stevenage  Accrington     0     3   A     0     0
#  551  E3      16  06/05/17     Wycombe   Cambridge     1     0   H     0     0
#
#       ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  PSCD  \
#  0    ...     1.79   28   0.00     1.93     1.88     2.03     1.94  2.57  3.19
#  1    ...     1.76   28  -0.50     2.28     2.21     1.71     1.67  2.47  3.44
#  ..   ...      ...  ...    ...      ...      ...      ...      ...   ...   ...
#  550  ...     1.88   19  -0.50     1.84     1.80     2.10     2.04  1.99  4.07
#  551  ...     1.78   17  -0.25     2.15     2.10     1.80     1.75  2.43  3.58
#
#       PSCA
#  0    3.11
#  1    3.03
#  ..    ...
#  550  3.61
#  551  2.99
#
#  [552 rows x 66 columns],
#      Div  season        Date    HomeTeam    AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    E3      17  05/08/2017  Accrington  Colchester     3     1   H     2
#  1    E3      17  05/08/2017    Carlisle     Swindon     1     2   A     0
#  ..   ..     ...         ...         ...         ...   ...   ...  ..   ...
#  550  E3      17  05/05/2018     Swindon  Accrington     3     0   H     2
#  551  E3      17  05/05/2018     Wycombe   Stevenage     1     0   H     1
#
#       HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
#  0       0  ...     1.80   15  -0.25     1.86     1.83     2.08     2.02  1.97
#  1       1  ...     1.86   13  -0.25     2.18     2.11     1.80     1.77  2.06
#  ..    ...  ...      ...  ...    ...      ...      ...      ...      ...   ...
#  550     0  ...     1.93   19   0.25     1.95     1.88     2.01     1.93  2.96
#  551     0  ...     2.10   16  -1.00     2.11     2.04     1.83     1.75  1.68
#
#       PSCD  PSCA
#  0    3.65  4.10
#  1    3.82  3.60
#  ..    ...   ...
#  550  3.58  2.42
#  551  4.27  4.98
#
#  [552 rows x 66 columns],
#      Div  season        Date    HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    E3      18  04/08/2018        Bury        Yeovil     1     0   H     0
#  1    E3      18  04/08/2018  Cheltenham  Crawley Town     0     1   A     0
#  ..   ..     ...         ...         ...           ...   ...   ...  ..   ...
#  550  E3      18  04/05/2019     Swindon  Notts County     3     1   H     0
#  551  E3      18  04/05/2019      Yeovil      Carlisle     0     0   D     0
#
#       HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
#  0       0  ...     1.84   17  -0.50     1.87     1.82     2.07     1.99  1.82
#  1       0  ...     1.85   18  -0.25     1.73     1.68     2.23     2.16  2.22
#  ..    ...  ...      ...  ...    ...      ...      ...      ...      ...   ...
#  550     0  ...     1.93   17  -0.25     2.15     2.06     1.84     1.78  2.41
#  551     0  ...     1.72   18   0.50     2.02     1.95     1.95     1.87  4.07
#
#       PSCD  PSCA
#  0    3.78  4.59
#  1    3.32  3.55
#  ..    ...   ...
#  550  3.74  2.86
#  551  3.53  1.98
#
#  [552 rows x 63 columns],
#      Div  season        Date   Time  HomeTeam        AwayTeam  FTHG  FTAG FTR  \
#  0    E3      19  03/08/2019  12:30   Salford       Stevenage     2     0   H
#  1    E3      19  03/08/2019  15:00  Bradford       Cambridge     0     0   D
#  ..   ..     ...         ...    ...       ...             ...   ...   ...  ..
#  438  E3      19  07/03/2020  15:00   Walsall          Exeter     3     1   H
#  439  E3      19  10/03/2020  19:45  Carlisle  Newport County     2     0   H
#
#       HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
#  0       1  ...      1.79 -0.50     1.95      1.90   1.95   1.95     2.01
#  1       0  ...      1.84 -0.75     1.95      1.85   1.99   1.91     2.00
#  ..    ...  ...       ...   ...      ...       ...    ...    ...      ...
#  438     1  ...      1.76  0.25     1.80      2.05   1.83   2.06     1.85
#  439     2  ...      1.56  0.00     1.98      1.88   1.99   1.91     2.03
#
#       MaxCAHA  AvgCAHH  AvgCAHA
#  0       1.97     1.92     1.91
#  1       1.95     1.94     1.88
#  ..       ...      ...      ...
#  438     2.12     1.78     2.06
#  439     1.93     1.96     1.87
#
#  [440 rows x 107 columns],
#      Div  season        Date   Time  HomeTeam       AwayTeam  FTHG  FTAG FTR  \
#  0    E3      20  12/09/2020  15:00    Barrow      Stevenage     1     1   D
#  1    E3      20  12/09/2020  15:00    Bolton   Forest Green     0     1   A
#  ..   ..     ...         ...    ...       ...            ...   ...   ...  ..
#  550  E3      20  08/05/2021  15:00  Tranmere     Colchester     0     0   D
#  551  E3      20  08/05/2021  16:00   Salford  Leyton Orient     3     0   H
#
#       HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
#  0       1  ...      1.76 -0.25     1.95      1.90   1.93   1.98     1.98
#  1       0  ...      1.79 -0.25     2.02      1.83   2.04   1.87     2.09
#  ..    ...  ...       ...   ...      ...       ...    ...    ...      ...
#  550     0  ...      1.59 -0.75     2.05      1.80   2.05   1.85     2.08
#  551     1  ...      1.87 -1.00     1.98      1.88   1.99   1.90     2.01
#
#       MaxCAHA  AvgCAHH  AvgCAHA
#  0       1.99     1.91     1.92
#  1       1.90     2.00     1.83
#  ..       ...      ...      ...
#  550     1.89     2.01     1.82
#  551     1.96     1.96     1.86
#
#  [552 rows x 107 columns],
#      Div  season      Date        HomeTeam      AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    EC      15  08/08/15       Aldershot     Gateshead     1     2   A     1
#  1    EC      15  08/08/15      Altrincham  Forest Green     0     1   A     0
#  ..   ..     ...       ...             ...           ...   ...   ...  ..   ...
#  550  EC      15  30/04/16  Welling United  Boreham Wood     0     3   A     0
#  551  EC      15  30/04/16          Woking     Eastleigh     2     1   H     2
#
#       HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
#  0       0  ...     1.75   22   0.00     2.13     2.04     1.84     1.78  2.68
#  1       0  ...     1.87   23   0.50     1.93     1.87     2.02     1.96  3.36
#  ..    ...  ...      ...  ...    ...      ...      ...      ...      ...   ...
#  550     2  ...     1.89   20   0.75     2.09     2.00     1.87     1.81  5.76
#  551     0  ...     2.11   22   0.50     1.94     1.86     2.02     1.95  3.60
#
#       PSCD  PSCA
#  0    3.39  2.80
#  1    3.59  2.23
#  ..    ...   ...
#  550  4.29  1.62
#  551  3.83  2.06
#
#  [552 rows x 66 columns],
#      Div  season      Date      HomeTeam       AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    EC      16  06/08/16        Barrow      Aldershot     1     0   H     1
#  1    EC      16  06/08/16  Boreham Wood   Forest Green     1     0   H     1
#  ..   ..     ...       ...           ...            ...   ...   ...  ..   ...
#  550  EC      16  29/04/17       Torquay  North Ferriby     2     0   H     0
#  551  EC      16  29/04/17          York   Forest Green     2     2   D     1
#
#       HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
#  0       0  ...     1.77   26  -0.50     1.99     1.91     1.96     1.88  1.97
#  1       0  ...     1.68   23   0.50     1.82     1.72     2.19     2.08  3.56
#  ..    ...  ...      ...  ...    ...      ...      ...      ...      ...   ...
#  550     0  ...     2.37    7  -1.50     2.05     1.94     1.96     1.83   NaN
#  551     2  ...     1.90    7  -0.25     1.97     1.93     1.90     1.84  1.90
#
#       PSCD  PSCA
#  0    3.60  4.15
#  1    3.31  2.27
#  ..    ...   ...
#  550   NaN   NaN
#  551  3.92  4.10
#
#  [552 rows x 58 columns],
#      Div  season      Date     HomeTeam        AwayTeam  FTHG  FTAG FTR  HTHG  \
#  0    EC      17  05/08/17      Bromley       Eastleigh     0     0   D     0
#  1    EC      17  05/08/17  Dag and Red          Barrow     2     1   H     2
#  ..   ..     ...       ...          ...             ...   ...   ...  ..   ...
#  550  EC      17  28/04/18       Woking  Dover Athletic     1     2   A     1
#  551  EC      17  28/04/18      Wrexham           Fylde     0     0   D     0
#
#       HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
#  0       0  ...     1.88   13   0.25     1.80     1.76     2.17     2.09  2.84
#  1       0  ...     1.84   14  -0.50     2.07     2.02     1.85     1.82  1.85
#  ..    ...  ...      ...  ...    ...      ...      ...      ...      ...   ...
#  550     1  ...     2.27   14   0.25     1.81     1.74     2.14     2.05  2.74
#  551     0  ...     1.83   14   0.25     1.86     1.76     2.09     2.01  2.67
#
#       PSCD  PSCA
#  0    3.40  2.64
#  1    3.77  4.53
#  ..    ...   ...
#  550  3.67  2.54
#  551  3.54  2.69
#
#  [552 rows x 58 columns],
#      Div  season        Date   HomeTeam                AwayTeam  FTHG  FTAG  \
#  0    EC      18  04/08/2018  Aldershot                  Barnet     0     0
#  1    EC      18  04/08/2018     Barrow  Havant & Waterlooville     3     0
#  ..   ..     ...         ...        ...                     ...   ...   ...
#  550  EC      18  27/04/2019  Maidstone               Aldershot     0     2
#  551  EC      18  27/04/2019    Wrexham               Harrogate     2     1
#
#      FTR  HTHG  HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  \
#  0     D     0     0  ...     1.83    7    0.0     1.92     1.86     1.99
#  1     H     1     0  ...     1.72   10    0.0     1.98     1.91     1.95
#  ..   ..   ...   ...  ...      ...  ...    ...      ...      ...      ...
#  550   A     0     0  ...     1.91    7    0.0     2.05     1.96     1.90
#  551   H     1     1  ...     1.77    7    0.0     1.55     1.50     2.65
#
#       BbAvAHA  PSCH  PSCD  PSCA
#  0       1.95  2.60  3.42  2.82
#  1       1.89  2.85  3.31  2.63
#  ..       ...   ...   ...   ...
#  550     1.82  2.61  3.55  2.69
#  551     2.54  2.18  3.55  3.36
#
#  [552 rows x 55 columns],
#      Div  season        Date   Time   HomeTeam    AwayTeam  FTHG  FTAG FTR  \
#  0    EC      19  03/08/2019  12:30  Stockport  Maidenhead     0     1   A
#  1    EC      19  03/08/2019  15:00  Aldershot       Fylde     1     2   A
#  ..   ..     ...         ...    ...        ...         ...   ...   ...  ..
#  449  EC      19  14/03/2020  15:00     Sutton  Hartlepool     1     1   D
#  450  EC      19  14/03/2020  17:20    Halifax   Ebbsfleet     0     1   A
#
#       HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
#  0       0  ...      1.77 -0.50     1.90      1.90   1.92   1.97     1.98
#  1       0  ...      1.72  0.50     1.90      1.90   2.04   1.85     2.04
#  ..    ...  ...       ...   ...      ...       ...    ...    ...      ...
#  449     1  ...      1.76 -0.25     2.02      1.77   2.08   1.81     2.11
#  450     0  ...      1.91 -0.75     1.83      1.98   1.86   2.02     1.91
#
#       MaxCAHA  AvgCAHH  AvgCAHA
#  0       1.97     1.91     1.91
#  1       1.95     1.94     1.88
#  ..       ...      ...      ...
#  449     1.81     2.05     1.78
#  450     2.03     1.84     1.99
#
#  [451 rows x 99 columns],
#      Div  season        Date   Time    HomeTeam    AwayTeam  FTHG  FTAG FTR  \
#  0    EC      20  03/10/2020  15:00  Altrincham    Weymouth     0     0   D
#  1    EC      20  03/10/2020  15:00      Barnet   Eastleigh     1     5   A
#  ..   ..     ...         ...    ...         ...         ...   ...   ...  ..
#  475  EC      20  29/05/2021  12:30      Woking  Wealdstone     2     4   A
#  476  EC      20  29/05/2021  12:30      Yeovil   Stockport     0     1   A
#
#       HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
#  0       0  ...      1.87 -0.50     1.88      1.93   1.93   1.95     1.94
#  1       1  ...      1.81  0.00     1.83      1.98   1.84   2.06     1.88
#  ..    ...  ...       ...   ...      ...       ...    ...    ...      ...
#  475     1  ...      2.68 -0.75     1.85      1.95   1.91   1.94     1.93
#  476     0  ...      2.38  1.25     1.85      1.95   1.89   1.96     1.97
#
#       MaxCAHA  AvgCAHH  AvgCAHA
#  0       1.95     1.90     1.90
#  1       2.10     1.80     2.03
#  ..       ...      ...      ...
#  475     2.02     1.87     1.91
#  476     2.00     1.88     1.89
#
#  [477 rows x 99 columns]]

# %%
len(frames)
# Out:
# 30

# %%
frames[0]
# Out:
#     Div  season        Date     HomeTeam     AwayTeam  FTHG  FTAG FTR  HTHG  \
# 0    E0      15  08/08/2015  Bournemouth  Aston Villa     0     1   A     0
# 1    E0      15  08/08/2015      Chelsea      Swansea     2     2   D     2
# ..   ..     ...         ...          ...          ...   ...   ...  ..   ...
# 378  E0      15  15/05/2016    West Brom    Liverpool     1     1   D     1
# 379  E0      15  17/05/2016   Man United  Bournemouth     3     1   H     1
#
#      HTAG  ... BbAv<2.5 BbAH  BbAHh  BbMxAHH  BbAvAHH  BbMxAHA  BbAvAHA  PSCH  \
# 0       0  ...     1.79   26  -0.50     1.98     1.93     1.99     1.92  1.82
# 1       1  ...     1.99   27  -1.50     2.24     2.16     1.80     1.73  1.37
# ..    ...  ...      ...  ...    ...      ...      ...      ...      ...   ...
# 378     1  ...     2.09   30  -0.25     2.10     2.05     1.86     1.81  2.61
# 379     0  ...     2.20   29  -0.75     1.88     1.84     2.08     2.02  1.50
#
#      PSCD   PSCA
# 0    3.88   4.70
# 1    5.04  10.88
# ..    ...    ...
# 378  3.75   2.70
# 379  4.60   7.03
#
# [380 rows x 66 columns]

# %%
frames[-1]
# Out:
#     Div  season        Date   Time    HomeTeam    AwayTeam  FTHG  FTAG FTR  \
# 0    EC      20  03/10/2020  15:00  Altrincham    Weymouth     0     0   D
# 1    EC      20  03/10/2020  15:00      Barnet   Eastleigh     1     5   A
# ..   ..     ...         ...    ...         ...         ...   ...   ...  ..
# 475  EC      20  29/05/2021  12:30      Woking  Wealdstone     2     4   A
# 476  EC      20  29/05/2021  12:30      Yeovil   Stockport     0     1   A
#
#      HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0       0  ...      1.87 -0.50     1.88      1.93   1.93   1.95     1.94
# 1       1  ...      1.81  0.00     1.83      1.98   1.84   2.06     1.88
# ..    ...  ...       ...   ...      ...       ...    ...    ...      ...
# 475     1  ...      2.68 -0.75     1.85      1.95   1.91   1.94     1.93
# 476     0  ...      2.38  1.25     1.85      1.95   1.89   1.96     1.97
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       1.95     1.90     1.90
# 1       2.10     1.80     2.03
# ..       ...      ...      ...
# 475     2.02     1.87     1.91
# 476     2.00     1.88     1.89
#
# [477 rows x 99 columns]

# %%
dict_countries = {'Spanish La Liga':'SP1', 'Spanish Segunda Division':'SP2', 'German Bundesliga':'D1', 'English Premier League': 'E0', 'English League 1':'E2', 'English League 2':'E3', 
                  'English Conference':'EC'}

# %%
dict_countries['Spanish La Liga']
# Out:
# 'SP1'

# %%
dict_historical_data = {}
leagues = ['E0', 'E2', 'E3']


for league in dict_countries:
    for season in range(15,21):
        frames = []
        df = pd.read_csv(root + str(season) + str(season+1) + '/' + dict_countries[league] + '.csv')
        df.insert(1, 'season', season)
        frames.append(df)
    df_concat = pd.concat(frames)
    dict_historical_data[league] = df_concat

# %%
dict_historical_data.keys()
# Out:
# dict_keys(['Spanish La Liga', 'Spanish Segunda Division', 'German Bundesliga', 'English Premier League', 'English League 1', 'English League 2'])

# %%
dict_historical_data.values()
# Out:
# dict_values([     Div  season        Date   Time HomeTeam    AwayTeam  FTHG  FTAG FTR  \
# 0    SP1      20  12/09/2020  15:00    Eibar       Celta     0     0   D
# 1    SP1      20  12/09/2020  17:30  Granada  Ath Bilbao     2     0   H
# ..   ...     ...         ...    ...      ...         ...   ...   ...  ..
# 378  SP1      20  23/05/2021  17:30  Granada      Getafe     0     0   D
# 379  SP1      20  23/05/2021  20:00  Sevilla      Alaves     1     0   H
#
#      HTHG  ...  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0       0  ...      1.51  0.00      1.94      1.96   1.96   1.96     1.98
# 1       0  ...      1.38  0.00      1.74      2.19   1.77   2.20     1.93
# ..    ...  ...       ...   ...       ...       ...    ...    ...      ...
# 378     0  ...      1.80  0.25      1.73      2.08   1.77   2.18     1.84
# 379     0  ...      2.40 -1.50      1.97      1.96   1.93   1.99     2.13
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       2.01     1.92     1.96
# 1       2.23     1.78     2.11
# ..       ...      ...      ...
# 378     2.23     1.77     2.12
# 379     2.03     1.99     1.88
#
# [380 rows x 106 columns],      Div  season        Date   Time      HomeTeam    AwayTeam  FTHG  FTAG FTR  \
# 0    SP2      20  12/09/2020  15:00  Ponferradina   Castellon     1     2   A
# 1    SP2      20  12/09/2020  17:15       Leganes  Las Palmas     1     0   H
# ..   ...     ...         ...    ...           ...         ...   ...   ...  ..
# 460  SP2      20  30/05/2021  20:00     Vallecano        Lugo     0     1   A
# 461  SP2      20  30/05/2021  20:00      Zaragoza     Leganes     0     5   A
#
#      HTHG  ...  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0       1  ...      1.46 -0.25      2.13      1.75   2.16   1.78     2.17
# 1       0  ...      1.43 -0.50      1.88      1.98   1.90   2.00     1.92
# ..    ...  ...       ...   ...       ...       ...    ...    ...      ...
# 460     0  ...      1.87 -1.00      1.95      1.90   1.97   1.93     2.02
# 461     0  ...      1.64  0.50      1.83      2.02   1.85   2.07     1.87
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       1.82     2.09     1.77
# 1       2.02     1.87     1.97
# ..       ...      ...      ...
# 460     1.94     1.96     1.88
# 461     2.08     1.80     2.04
#
# [462 rows x 106 columns],     Div  season        Date   Time       HomeTeam    AwayTeam  FTHG  FTAG FTR  \
# 0    D1      20  18/09/2020  19:30  Bayern Munich  Schalke 04     8     0   H
# 1    D1      20  19/09/2020  14:30  Ein Frankfurt   Bielefeld     1     1   D
# ..   ..     ...         ...    ...            ...         ...   ...   ...  ..
# 304  D1      20  22/05/2021  14:30  Werder Bremen  M'gladbach     2     4   A
# 305  D1      20  22/05/2021  14:30      Wolfsburg       Mainz     2     3   A
#
#      HTHG  ...  AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0       3  ...      4.34 -2.50      1.89      2.04   1.87   2.02     1.95
# 1       0  ...      2.33 -0.75      1.96      1.97   1.96   1.96     2.02
# ..    ...  ...       ...   ...       ...       ...    ...    ...      ...
# 304     0  ...      2.52  0.25      2.04      1.89   2.03   1.90     2.07
# 305     0  ...      2.97 -0.75      2.05      1.75   2.09   1.83     2.13
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       2.18     1.85     2.02
# 1       1.98     1.94     1.93
# ..       ...      ...      ...
# 304     1.91     2.00     1.87
# 305     1.89     2.04     1.83
#
# [306 rows x 106 columns],     Div  season        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG  \
# 0    E0      20  12/09/2020  12:30          Fulham      Arsenal     0     3
# 1    E0      20  12/09/2020  15:00  Crystal Palace  Southampton     1     0
# ..   ..     ...         ...    ...             ...          ...   ...   ...
# 378  E0      20  23/05/2021  16:00        West Ham  Southampton     3     0
# 379  E0      20  23/05/2021  16:00          Wolves   Man United     1     2
#
#     FTR  HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     A     0  ...      1.84  0.75     2.01      1.89   2.02   1.91     2.13
# 1     H     1  ...      1.70  0.25     1.78      2.13   1.79   2.17     1.85
# ..   ..   ...  ...       ...   ...      ...       ...    ...    ...      ...
# 378   H     2  ...      2.14 -0.75     2.00      1.90   2.02   1.91     2.06
# 379   A     1  ...      1.62 -0.25     2.04      1.86   2.10   1.84     2.10
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       1.92     2.02     1.87
# 1       2.18     1.79     2.12
# ..       ...      ...      ...
# 378     2.01     1.99     1.89
# 379     1.94     2.00     1.88
#
# [380 rows x 107 columns],     Div  season        Date   Time    HomeTeam     AwayTeam  FTHG  FTAG FTR  \
# 0    E2      20  12/09/2020  15:00  Accrington    Peterboro     2     0   H
# 1    E2      20  12/09/2020  15:00       Crewe     Charlton     0     2   A
# ..   ..     ...         ...    ...         ...          ...   ...   ...  ..
# 550  E2      20  09/05/2021  12:00  Sunderland  Northampton     1     1   D
# 551  E2      20  09/05/2021  12:00       Wigan      Swindon     3     4   A
#
#      HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0       1  ...      2.03  0.25     2.02      1.83   2.08   1.83     2.09
# 1       0  ...      1.88  0.00     1.95      1.90   1.96   1.94     2.00
# ..    ...  ...       ...   ...      ...       ...    ...    ...      ...
# 550     0  ...      2.13 -1.25     1.98      1.88   2.02   1.88     2.10
# 551     1  ...      2.28 -0.75     1.93      1.93   2.00   1.88     2.01
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       1.87     2.02     1.81
# 1       1.95     1.94     1.89
# ..       ...      ...      ...
# 550     1.91     2.01     1.83
# 551     1.97     1.93     1.90
#
# [552 rows x 107 columns],     Div  season        Date   Time  HomeTeam       AwayTeam  FTHG  FTAG FTR  \
# 0    E3      20  12/09/2020  15:00    Barrow      Stevenage     1     1   D
# 1    E3      20  12/09/2020  15:00    Bolton   Forest Green     0     1   A
# ..   ..     ...         ...    ...       ...            ...   ...   ...  ..
# 550  E3      20  08/05/2021  15:00  Tranmere     Colchester     0     0   D
# 551  E3      20  08/05/2021  16:00   Salford  Leyton Orient     3     0   H
#
#      HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0       1  ...      1.76 -0.25     1.95      1.90   1.93   1.98     1.98
# 1       0  ...      1.79 -0.25     2.02      1.83   2.04   1.87     2.09
# ..    ...  ...       ...   ...      ...       ...    ...    ...      ...
# 550     0  ...      1.59 -0.75     2.05      1.80   2.05   1.85     2.08
# 551     1  ...      1.87 -1.00     1.98      1.88   1.99   1.90     2.01
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       1.99     1.91     1.92
# 1       1.90     2.00     1.83
# ..       ...      ...      ...
# 550     1.89     2.01     1.82
# 551     1.96     1.96     1.86
#
# [552 rows x 107 columns]])

# %%
dict_historical_data['English Premier League']
# Out:
#     Div  season        Date   Time        HomeTeam     AwayTeam  FTHG  FTAG  \
# 0    E0      20  12/09/2020  12:30          Fulham      Arsenal     0     3
# 1    E0      20  12/09/2020  15:00  Crystal Palace  Southampton     1     0
# ..   ..     ...         ...    ...             ...          ...   ...   ...
# 378  E0      20  23/05/2021  16:00        West Ham  Southampton     3     0
# 379  E0      20  23/05/2021  16:00          Wolves   Man United     1     2
#
#     FTR  HTHG  ...  AvgC<2.5  AHCh B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  \
# 0     A     0  ...      1.84  0.75     2.01      1.89   2.02   1.91     2.13
# 1     H     1  ...      1.70  0.25     1.78      2.13   1.79   2.17     1.85
# ..   ..   ...  ...       ...   ...      ...       ...    ...    ...      ...
# 378   H     2  ...      2.14 -0.75     2.00      1.90   2.02   1.91     2.06
# 379   A     1  ...      1.62 -0.25     2.04      1.86   2.10   1.84     2.10
#
#      MaxCAHA  AvgCAHH  AvgCAHA
# 0       1.92     2.02     1.87
# 1       2.18     1.79     2.12
# ..       ...      ...      ...
# 378     2.01     1.99     1.89
# 379     1.94     2.00     1.88
#
# [380 rows x 107 columns]

# %%
df_laptops = pd.read_csv('laptop_price.csv', encoding='unicode_escape')

# %%
df_laptops.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00

# %%
df_laptops['Company'] == 'Apple'
# Out:
# 0        True
# 1        True
#         ...
# 1301    False
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
df_laptops[df_laptops['Company'] == 'Apple']
# Out:
#       laptop_ID Company      Product   TypeName  Inches  \
# 0             1   Apple  MacBook Pro  Ultrabook    13.3
# 1             2   Apple  Macbook Air  Ultrabook    13.3
# ...         ...     ...          ...        ...     ...
# 1210       1228   Apple  MacBook 12"  Ultrabook    12.0
# 1234       1252   Apple  MacBook Air  Ultrabook    11.6
#
#                         ScreenResolution                   Cpu  Ram  \
# 0     IPS Panel Retina Display 2560x1600  Intel Core i5 2.3GHz  8GB
# 1                               1440x900  Intel Core i5 1.8GHz  8GB
# ...                                  ...                   ...  ...
# 1210  IPS Panel Retina Display 2304x1440   Intel Core M 1.2GHz  8GB
# 1234                            1366x768  Intel Core i5 1.6GHz  4GB
#
#                    Memory                           Gpu     OpSys   Weight  \
# 0               128GB SSD  Intel Iris Plus Graphics 640     macOS   1.37kg
# 1     128GB Flash Storage        Intel HD Graphics 6000     macOS   1.34kg
# ...                   ...                           ...       ...      ...
# 1210  512GB Flash Storage         Intel HD Graphics 515  Mac OS X  0.920kg
# 1234  256GB Flash Storage        Intel HD Graphics 6000  Mac OS X   1.08kg
#
#       Price_euros
# 0         1339.69
# 1          898.94
# ...           ...
# 1210      1279.00
# 1234       959.00
#
# [21 rows x 13 columns]

# %%
df_laptops[df_laptops['Company'] == 'Apple'].value_counts('Company')
# Out:
# Company
# Apple    21
# Name: count, dtype: int64

# %%
df_laptops[df_laptops['Company'] != 'HP']
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# ...         ...     ...                                  ...        ...
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR   Notebook
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)   Notebook
#
#       Inches                    ScreenResolution  \
# 0       13.3  IPS Panel Retina Display 2560x1600
# 1       13.3                            1440x900
# ...      ...                                 ...
# 1300    14.0                            1366x768
# 1302    15.6                            1366x768
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz  8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz  8GB  128GB Flash Storage
# ...                                    ...  ...                  ...
# 1300  Intel Celeron Dual Core N3050 1.6GHz  2GB   64GB Flash Storage
# 1302  Intel Celeron Dual Core N3050 1.6GHz  4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# ...                            ...         ...     ...          ...
# 1300             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1029 rows x 13 columns]

# %%
df_laptops[df_laptops['Company'] != 'HP'].value_counts('Company')
# Out:
# Company
# Lenovo    297
# Dell      297
#          ...
# LG          3
# Huawei      2
# Name: count, Length: 18, dtype: int64

# %%
df_laptops[df_laptops['Price_euros'] > 2000].value_counts('Price_euros')
# Out:
# Price_euros
# 2299.00    6
# 2499.00    5
#           ..
# 2250.68    1
# 6099.00    1
# Name: count, Length: 108, dtype: int64

# %%
np.where(df_laptops['Price_euros'], 'Expensive', 'Cheap')
# Out:
# array(['Expensive', 'Expensive', 'Expensive', ..., 'Expensive',
#        'Expensive', 'Expensive'], shape=(1303,), dtype='<U9')

# %%
df_laptops['Price_tier'] = np.where(df_laptops['Price_euros'], 'Expensive', 'Cheap')

# %%
df_laptops.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Price_tier Screen Size
# 0      1339.69  Expensive       Small
# 1       898.94  Expensive       Small
# 2       575.00  Expensive         Big
# 3      2537.45  Expensive         Big
# 4      1803.60  Expensive       Small

# %%
df_laptops.value_counts('Price_tier')
# Out:
# Price_tier
# Expensive    1303
# Name: count, dtype: int64

# %%
df_laptops[df_laptops['Inches'] > 15]
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 2             3      HP                               250 G6   Notebook
# 3             4   Apple                          MacBook Pro  Ultrabook
# ...         ...     ...                                  ...        ...
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)   Notebook
#
#       Inches                    ScreenResolution  \
# 2       15.6                   Full HD 1920x1080
# 3       15.4  IPS Panel Retina Display 2880x1800
# ...      ...                                 ...
# 1301    15.6                            1366x768
# 1302    15.6                            1366x768
#
#                                        Cpu   Ram     Memory  \
# 2               Intel Core i5 7200U 2.5GHz   8GB  256GB SSD
# 3                     Intel Core i7 2.7GHz  16GB  512GB SSD
# ...                                    ...   ...        ...
# 1301            Intel Core i7 6500U 2.5GHz   6GB    1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB  500GB HDD
#
#                         Gpu       OpSys  Weight  Price_euros Price_tier
# 2     Intel HD Graphics 620       No OS  1.86kg       575.00  Expensive
# 3        AMD Radeon Pro 455       macOS  1.83kg      2537.45  Expensive
# ...                     ...         ...     ...          ...        ...
# 1301     AMD Radeon R5 M330  Windows 10  2.19kg       764.00  Expensive
# 1302      Intel HD Graphics  Windows 10   2.2kg       369.00  Expensive
#
# [835 rows x 14 columns]

# %%
np.where(df_laptops['Inches'] > 15, 'Big', 'Small')
# Out:
# array(['Small', 'Small', 'Big', ..., 'Small', 'Big', 'Big'],
#       shape=(1303,), dtype='<U5')

# %%
df_laptops['Screen Size'] = np.where(df_laptops['Inches'] > 15, 'Big', 'Small')

# %%
df_laptops.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Price_tier Screen Size
# 0      1339.69  Expensive       Small
# 1       898.94  Expensive       Small
# 2       575.00  Expensive         Big
# 3      2537.45  Expensive         Big
# 4      1803.60  Expensive       Small

# %%
df_laptops.value_counts('Screen Size')
# Out:
# Screen Size
# Big      835
# Small    468
# Name: count, dtype: int64

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# ...         ...     ...                                  ...        ...
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)   Notebook
#
#       Inches                    ScreenResolution  \
# 0       13.3  IPS Panel Retina Display 2560x1600
# 1       13.3                            1440x900
# ...      ...                                 ...
# 1301    15.6                            1366x768
# 1302    15.6                            1366x768
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz  8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz  8GB  128GB Flash Storage
# ...                                    ...  ...                  ...
# 1301            Intel Core i7 6500U 2.5GHz  6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz  4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# ...                            ...         ...     ...          ...
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
#      Price_tier Screen Size
# 0     Expensive       Small
# 1     Expensive       Small
# ...         ...         ...
# 1301  Expensive         Big
# 1302  Expensive         Big
#
# [1303 rows x 15 columns]

# %%
(df_laptops['Company'] == 'Apple') & (df_laptops['Price_euros'] > 2000)
# Out:
# 0       False
# 1       False
#         ...
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
df_laptops[(df_laptops['Company'] == 'Apple') & (df_laptops['Price_euros'] > 2000)]
# Out:
#      laptop_ID Company      Product   TypeName  Inches  \
# 3            4   Apple  MacBook Pro  Ultrabook    15.4
# 6            7   Apple  MacBook Pro  Ultrabook    15.4
# 12          13   Apple  MacBook Pro  Ultrabook    15.4
# 17          18   Apple  MacBook Pro  Ultrabook    15.4
# 249        254   Apple  MacBook Pro  Ultrabook    13.3
#
#                        ScreenResolution                   Cpu   Ram  \
# 3    IPS Panel Retina Display 2880x1800  Intel Core i7 2.7GHz  16GB
# 6    IPS Panel Retina Display 2880x1800  Intel Core i7 2.2GHz  16GB
# 12   IPS Panel Retina Display 2880x1800  Intel Core i7 2.8GHz  16GB
# 17   IPS Panel Retina Display 2880x1800  Intel Core i7 2.9GHz  16GB
# 249  IPS Panel Retina Display 2560x1600  Intel Core i5 3.1GHz   8GB
#
#                   Memory                           Gpu     OpSys  Weight  \
# 3              512GB SSD            AMD Radeon Pro 455     macOS  1.83kg
# 6    256GB Flash Storage       Intel Iris Pro Graphics  Mac OS X  2.04kg
# 12             256GB SSD            AMD Radeon Pro 555     macOS  1.83kg
# 17             512GB SSD            AMD Radeon Pro 560     macOS  1.83kg
# 249            512GB SSD  Intel Iris Plus Graphics 650     macOS  1.37kg
#
#      Price_euros Price_tier Screen Size
# 3        2537.45  Expensive         Big
# 6        2139.97  Expensive         Big
# 12       2439.97  Expensive         Big
# 17       2858.00  Expensive         Big
# 249      2040.00  Expensive       Small

# %%
(df_laptops['Company'] == 'Apple') | (df_laptops['Company'] == 'Dell')
# Out:
# 0        True
# 1        True
#         ...
# 1301    False
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
df_laptops[(df_laptops['Company']=='Apple')|(df_laptops['Company']=='Dell')]
# Out:
#       laptop_ID Company        Product   TypeName  Inches  \
# 0             1   Apple    MacBook Pro  Ultrabook    13.3
# 1             2   Apple    Macbook Air  Ultrabook    13.3
# ...         ...     ...            ...        ...     ...
# 1292       1310    Dell  Inspiron 3552   Notebook    15.6
# 1295       1313    Dell  Inspiron 3567   Notebook    15.6
#
#                         ScreenResolution  \
# 0     IPS Panel Retina Display 2560x1600
# 1                               1440x900
# ...                                  ...
# 1292                            1366x768
# 1295                            1366x768
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz  8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz  8GB  128GB Flash Storage
# ...                                    ...  ...                  ...
# 1292  Intel Celeron Dual Core N3050 1.6GHz  2GB            500GB HDD
# 1295            Intel Core i7 7500U 2.7GHz  8GB              1TB HDD
#
#                                Gpu       OpSys  Weight  Price_euros  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# ...                            ...         ...     ...          ...
# 1292             Intel HD Graphics  Windows 10  2.20kg       379.00
# 1295            AMD Radeon R5 M430       Linux   2.3kg       805.99
#
#      Price_tier Screen Size
# 0     Expensive       Small
# 1     Expensive       Small
# ...         ...         ...
# 1292  Expensive         Big
# 1295  Expensive         Big
#
# [318 rows x 15 columns]

# %%
df_laptops[(df_laptops['Company']=='Apple')|(df_laptops['Company']=='Dell')].value_counts('Company')
# Out:
# Company
# Dell     297
# Apple     21
# Name: count, dtype: int64

# %%
((df_laptops['Company']=='Apple')|(df_laptops['Company']=='Dell')) & (df_laptops['Price_euros']>2000)
# Out:
# 0       False
# 1       False
#         ...
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
df_laptops[((df_laptops['Company']=='Apple')|(df_laptops['Company']=='Dell')) & (df_laptops['Price_euros']>2000)].value_counts('Company')
# Out:
# Company
# Dell     34
# Apple     5
# Name: count, dtype: int64

# %%
conditions = [
    df_laptops['Price_euros']>3000,
    (df_laptops['Price_euros']>2000) & (df_laptops['Price_euros']<=3000),
    (df_laptops['Price_euros']>800) & (df_laptops['Price_euros']<=2000),
    df_laptops['Price_euros']<=800
]

values = ['Too Expensive', 'Expensive', 'Affordable', 'Cheap']

# %%
df_laptops['Price_tiers'] = np.select(conditions, values, default=np.array(np.nan, dtype=object))

# %%
df_laptops.head(5)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
# 3          4   Apple  MacBook Pro  Ultrabook    15.4
# 4          5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros Price_tier Screen Size Price_tiers
# 0      1339.69  Expensive       Small  Affordable
# 1       898.94  Expensive       Small  Affordable
# 2       575.00  Expensive         Big       Cheap
# 3      2537.45  Expensive         Big   Expensive
# 4      1803.60  Expensive       Small  Affordable

# %%
df_laptops['Price_tiers'].value_counts()
# Out:
# Price_tiers
# Affordable       655
# Cheap            511
# Expensive        118
# Too Expensive     19
# Name: count, dtype: int64

# %%
conditions= [
    df_laptops['Inches']>16,
    (df_laptops['Inches']>14) & (df_laptops['Inches']<= 16),
    (df_laptops['Inches']>12) & (df_laptops['Inches']<= 14),
    df_laptops['Inches']<=12
]

values = ['Too Big','Big','Small','Too Small']

# %%
df_laptops['Size_tiers']= np.select(conditions, values, default=np.array(np.nan, dtype=object))

# %%
df_laptops
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# ...         ...     ...                                  ...        ...
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)   Notebook
#
#       Inches                    ScreenResolution  \
# 0       13.3  IPS Panel Retina Display 2560x1600
# 1       13.3                            1440x900
# ...      ...                                 ...
# 1301    15.6                            1366x768
# 1302    15.6                            1366x768
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz  8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz  8GB  128GB Flash Storage
# ...                                    ...  ...                  ...
# 1301            Intel Core i7 6500U 2.5GHz  6GB              1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz  4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# ...                            ...         ...     ...          ...
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1302             Intel HD Graphics  Windows 10   2.2kg       369.00
#
#      Price_tier Screen Size Price_tiers Size_tiers
# 0     Expensive       Small  Affordable      Small
# 1     Expensive       Small  Affordable      Small
# ...         ...         ...         ...        ...
# 1301  Expensive         Big       Cheap        Big
# 1302  Expensive         Big       Cheap        Big
#
# [1303 rows x 17 columns]

# %%
df_laptops['Size_tiers'].value_counts()
# Out:
# Size_tiers
# Big          674
# Small        419
# Too Big      166
# Too Small     44
# Name: count, dtype: int64

# %%
df_laptops['Company'].isin(['Apple','HP'])
# Out:
# 0        True
# 1        True
#         ...
# 1301     True
# 1302    False
# Name: Company, Length: 1303, dtype: bool

# %%
df_laptops.head(3)
# Out:
#    laptop_ID Company      Product   TypeName  Inches  \
# 0          1   Apple  MacBook Pro  Ultrabook    13.3
# 1          2   Apple  Macbook Air  Ultrabook    13.3
# 2          3      HP       250 G6   Notebook    15.6
#
#                      ScreenResolution                         Cpu  Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz  8GB
# 1                            1440x900        Intel Core i5 1.8GHz  8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
#
#    Price_euros Price_tier Screen Size Price_tiers Size_tiers
# 0      1339.69  Expensive       Small  Affordable      Small
# 1       898.94  Expensive       Small  Affordable      Small
# 2       575.00  Expensive         Big       Cheap        Big

# %%
df_laptops[df_laptops['Company'].isin(['Apple','HP'])]
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# ...         ...     ...                                  ...        ...
# 1296       1314      HP                     Stream 11-Y000na    Netbook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution  \
# 0       13.3  IPS Panel Retina Display 2560x1600
# 1       13.3                            1440x900
# ...      ...                                 ...
# 1296    11.6                            1366x768
# 1301    15.6                            1366x768
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz  8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz  8GB  128GB Flash Storage
# ...                                    ...  ...                  ...
# 1296  Intel Celeron Dual Core N3060 1.6GHz  2GB   32GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz  6GB              1TB HDD
#
#                                Gpu       OpSys  Weight  Price_euros  \
# 0     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 1           Intel HD Graphics 6000       macOS  1.34kg       898.94
# ...                            ...         ...     ...          ...
# 1296         Intel HD Graphics 400  Windows 10  1.17kg       209.00
# 1301            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
#
#      Price_tier Screen Size Price_tiers Size_tiers
# 0     Expensive       Small  Affordable      Small
# 1     Expensive       Small  Affordable      Small
# ...         ...         ...         ...        ...
# 1296  Expensive       Small       Cheap  Too Small
# 1301  Expensive         Big       Cheap        Big
#
# [295 rows x 17 columns]

# %%
df_laptops[df_laptops['Company'].isin(['Apple','HP'])].value_counts('Company')
# Out:
# Company
# HP       274
# Apple     21
# Name: count, dtype: int64

# %%
filter1 = df_laptops['TypeName'].isin(['Notebook','Ultrabook'])
filter2 = df_laptops['Company'].isin(['Apple', 'HP'])

# %%
filter1 & filter2
# Out:
# 0        True
# 1        True
#         ...
# 1301     True
# 1302    False
# Length: 1303, dtype: bool

# %%
df_laptops[filter1 & filter2]
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 0             1   Apple                          MacBook Pro  Ultrabook
# 1             2   Apple                          Macbook Air  Ultrabook
# ...         ...     ...                                  ...        ...
# 1294       1312      HP                  Pavilion 15-AW003nv   Notebook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
#
#       Inches                    ScreenResolution                         Cpu  \
# 0       13.3  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz
# 1       13.3                            1440x900        Intel Core i5 1.8GHz
# ...      ...                                 ...                         ...
# 1294    15.6                   Full HD 1920x1080   AMD A9-Series 9410 2.9GHz
# 1301    15.6                            1366x768  Intel Core i7 6500U 2.5GHz
#
#       Ram               Memory                           Gpu       OpSys  \
# 0     8GB            128GB SSD  Intel Iris Plus Graphics 640       macOS
# 1     8GB  128GB Flash Storage        Intel HD Graphics 6000       macOS
# ...   ...                  ...                           ...         ...
# 1294  6GB         1.0TB Hybrid            AMD Radeon R7 M440  Windows 10
# 1301  6GB              1TB HDD            AMD Radeon R5 M330  Windows 10
#
#       Weight  Price_euros Price_tier Screen Size Price_tiers Size_tiers
# 0     1.37kg      1339.69  Expensive       Small  Affordable      Small
# 1     1.34kg       898.94  Expensive       Small  Affordable      Small
# ...      ...          ...        ...         ...         ...        ...
# 1294  2.04kg       549.99  Expensive         Big       Cheap        Big
# 1301  2.19kg       764.00  Expensive         Big       Cheap        Big
#
# [241 rows x 17 columns]

# %%
df_laptops.duplicated('laptop_ID')
# Out:
# 0       False
# 1       False
#         ...
# 1301    False
# 1302    False
# Length: 1303, dtype: bool

# %%
df_laptops[df_laptops.duplicated('laptop_ID')]
# Out:
# Empty DataFrame
# Columns: [laptop_ID, Company, Product, TypeName, Inches, ScreenResolution, Cpu, Ram, Memory, Gpu, OpSys, Weight, Price_euros, Price_tier, Screen Size, Price_tiers, Size_tiers]
# Index: []

# %%
df_laptops.duplicated(['Product', 'TypeName', 'Inches'])
# Out:
# 0       False
# 1       False
#         ...
# 1301     True
# 1302     True
# Length: 1303, dtype: bool

# %%
duplicated = df_laptops.duplicated(['Product', 'TypeName', 'Inches'])

# %%
df_laptops[duplicated].sort_values(['Product', 'TypeName'])
# Out:
#       laptop_ID Company                              Product   TypeName  \
# 1287       1305      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon   Notebook
# ...         ...     ...                                  ...        ...
# 1289       1307    Asus                 ZenBook UX305CA-UBM1  Ultrabook
# 676         684    Asus                            Zenbook 3  Ultrabook
#
#       Inches             ScreenResolution                         Cpu  Ram  \
# 1287    15.6                     1366x768  Intel Core i7 6500U 2.5GHz  6GB
# 1301    15.6                     1366x768  Intel Core i7 6500U 2.5GHz  6GB
# ...      ...                          ...                         ...  ...
# 1289    13.3  IPS Panel Full HD 1920x1080    Intel Core M 6Y30 0.9GHz  8GB
# 676     14.0            Full HD 1920x1080  Intel Core i5 7200U 2.5GHz  8GB
#
#          Memory                    Gpu       OpSys  Weight  Price_euros  \
# 1287    1TB HDD     AMD Radeon R5 M330  Windows 10  2.19kg        764.0
# 1301    1TB HDD     AMD Radeon R5 M330  Windows 10  2.19kg        764.0
# ...         ...                    ...         ...     ...          ...
# 1289  512GB SSD  Intel HD Graphics 515  Windows 10   1.2kg        729.0
# 676   256GB SSD  Intel HD Graphics 620  Windows 10   1.1kg       1135.0
#
#      Price_tier Screen Size Price_tiers Size_tiers
# 1287  Expensive         Big       Cheap        Big
# 1301  Expensive         Big       Cheap        Big
# ...         ...         ...         ...        ...
# 1289  Expensive       Small       Cheap      Small
# 676   Expensive       Small  Affordable      Small
#
# [620 rows x 17 columns]

# %%
df_laptops = df_laptops.sort_values(['Company', 'Price_euros'])

# %%
df_laptops
# Out:
#       laptop_ID Company                           Product  TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome   Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST  Notebook    15.6
# ...         ...     ...                               ...       ...     ...
# 184         188  Xiaomi                       Mi Notebook  Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook  Notebook    15.6
#
#                  ScreenResolution                                   Cpu   Ram  \
# 1215                     1366x768  Intel Celeron Dual Core 3205U 1.5GHz   2GB
# 290                      1366x768  Intel Celeron Dual Core 3205U 1.5GHz   2GB
# ...                           ...                                   ...   ...
# 184   IPS Panel Full HD 1920x1080            Intel Core i5 8250U 1.6GHz   8GB
# 514   IPS Panel Full HD 1920x1080            Intel Core i7 8550U 1.8GHz  16GB
#
#          Memory                   Gpu      OpSys  Weight  Price_euros  \
# 1215   32GB SSD     Intel HD Graphics  Chrome OS   1.3kg       174.00
# 290    16GB SSD     Intel HD Graphics  Chrome OS  2.19kg       199.00
# ...         ...                   ...        ...     ...          ...
# 184   256GB SSD  Nvidia GeForce MX150      No OS  1.95kg      1199.00
# 514   256GB SSD  Nvidia GeForce MX150      No OS  1.95kg      1399.95
#
#      Price_tier Screen Size Price_tiers Size_tiers
# 1215  Expensive       Small       Cheap  Too Small
# 290   Expensive         Big       Cheap        Big
# ...         ...         ...         ...        ...
# 184   Expensive         Big  Affordable        Big
# 514   Expensive         Big  Affordable        Big
#
# [1303 rows x 17 columns]

# %%
df_laptops.value_counts('Company')
# Out:
# Company
# Dell      297
# Lenovo    297
#          ...
# LG          3
# Huawei      2
# Name: count, Length: 19, dtype: int64

# %%
duplicated_first = df_laptops.duplicated('Company', keep='first')

# %%
df_laptops[~duplicated_first][['Company','Price_euros']]
# Out:
#      Company  Price_euros
# 1215    Acer       174.00
# 1      Apple       898.94
# ...      ...          ...
# 1120    Vero       196.00
# 877   Xiaomi       935.00
#
# [19 rows x 2 columns]

# %%
df_laptops[~duplicated_first].value_counts('Company')
# Out:
# Company
# Acer      1
# Lenovo    1
#          ..
# Asus      1
# Xiaomi    1
# Name: count, Length: 19, dtype: int64

# %%
duplicated_last = df_laptops.duplicated('Company', keep='last')

# %%
df_laptops[~duplicated_last][['Company','Price_euros']]
# Out:
#      Company  Price_euros
# 1189    Acer      2599.00
# 17     Apple      2858.00
# ...      ...          ...
# 191     Vero       260.00
# 514   Xiaomi      1399.95
#
# [19 rows x 2 columns]

# %%
duplicated_false = df_laptops.duplicated('Company', keep=False)

# %%
df_laptops[duplicated_false]
# Out:
#       laptop_ID Company                           Product  TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome   Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST  Notebook    15.6
# ...         ...     ...                               ...       ...     ...
# 184         188  Xiaomi                       Mi Notebook  Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook  Notebook    15.6
#
#                  ScreenResolution                                   Cpu   Ram  \
# 1215                     1366x768  Intel Celeron Dual Core 3205U 1.5GHz   2GB
# 290                      1366x768  Intel Celeron Dual Core 3205U 1.5GHz   2GB
# ...                           ...                                   ...   ...
# 184   IPS Panel Full HD 1920x1080            Intel Core i5 8250U 1.6GHz   8GB
# 514   IPS Panel Full HD 1920x1080            Intel Core i7 8550U 1.8GHz  16GB
#
#          Memory                   Gpu      OpSys  Weight  Price_euros  \
# 1215   32GB SSD     Intel HD Graphics  Chrome OS   1.3kg       174.00
# 290    16GB SSD     Intel HD Graphics  Chrome OS  2.19kg       199.00
# ...         ...                   ...        ...     ...          ...
# 184   256GB SSD  Nvidia GeForce MX150      No OS  1.95kg      1199.00
# 514   256GB SSD  Nvidia GeForce MX150      No OS  1.95kg      1399.95
#
#      Price_tier Screen Size Price_tiers Size_tiers
# 1215  Expensive       Small       Cheap  Too Small
# 290   Expensive         Big       Cheap        Big
# ...         ...         ...         ...        ...
# 184   Expensive         Big  Affordable        Big
# 514   Expensive         Big  Affordable        Big
#
# [1303 rows x 17 columns]

# %%
df_laptops.value_counts('Company')
# Out:
# Company
# Dell      297
# Lenovo    297
#          ...
# LG          3
# Huawei      2
# Name: count, Length: 19, dtype: int64

# %%
df_laptops.head(3)
# Out:
#       laptop_ID Company                           Product  TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome   Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST  Notebook    15.6
# 1102       1117    Acer                     Chromebook 15  Notebook    15.6
#
#      ScreenResolution                                   Cpu  Ram    Memory  \
# 1215         1366x768  Intel Celeron Dual Core 3205U 1.5GHz  2GB  32GB SSD
# 290          1366x768  Intel Celeron Dual Core 3205U 1.5GHz  2GB  16GB SSD
# 1102         1366x768  Intel Celeron Dual Core 3205U 1.5GHz  4GB  16GB SSD
#
#                     Gpu      OpSys  Weight  Price_euros Price_tier  \
# 1215  Intel HD Graphics  Chrome OS   1.3kg        174.0  Expensive
# 290   Intel HD Graphics  Chrome OS  2.19kg        199.0  Expensive
# 1102  Intel HD Graphics  Chrome OS  2.20kg        209.0  Expensive
#
#      Screen Size Price_tiers Size_tiers
# 1215       Small       Cheap  Too Small
# 290          Big       Cheap        Big
# 1102         Big       Cheap        Big

# %%
df_laptops.drop_duplicates(['Company'])[['Company','Price_euros']].value_counts('Company')
# Out:
# Company
# Acer      1
# Lenovo    1
#          ..
# Asus      1
# Xiaomi    1
# Name: count, Length: 19, dtype: int64

# %%
df_laptops.sort_values(['Company', 'Price_euros'])
# Out:
#       laptop_ID Company                           Product  TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome   Netbook    11.6
# 290         295    Acer              Chromebook C910-C2ST  Notebook    15.6
# ...         ...     ...                               ...       ...     ...
# 184         188  Xiaomi                       Mi Notebook  Notebook    15.6
# 514         521  Xiaomi                       Mi Notebook  Notebook    15.6
#
#                  ScreenResolution                                   Cpu   Ram  \
# 1215                     1366x768  Intel Celeron Dual Core 3205U 1.5GHz   2GB
# 290                      1366x768  Intel Celeron Dual Core 3205U 1.5GHz   2GB
# ...                           ...                                   ...   ...
# 184   IPS Panel Full HD 1920x1080            Intel Core i5 8250U 1.6GHz   8GB
# 514   IPS Panel Full HD 1920x1080            Intel Core i7 8550U 1.8GHz  16GB
#
#          Memory                   Gpu      OpSys  Weight  Price_euros  \
# 1215   32GB SSD     Intel HD Graphics  Chrome OS   1.3kg       174.00
# 290    16GB SSD     Intel HD Graphics  Chrome OS  2.19kg       199.00
# ...         ...                   ...        ...     ...          ...
# 184   256GB SSD  Nvidia GeForce MX150      No OS  1.95kg      1199.00
# 514   256GB SSD  Nvidia GeForce MX150      No OS  1.95kg      1399.95
#
#      Price_tier Screen Size Price_tiers Size_tiers
# 1215  Expensive       Small       Cheap  Too Small
# 290   Expensive         Big       Cheap        Big
# ...         ...         ...         ...        ...
# 184   Expensive         Big  Affordable        Big
# 514   Expensive         Big  Affordable        Big
#
# [1303 rows x 17 columns]

# %%
df_laptops.drop_duplicates(['Company'])
# Out:
#       laptop_ID Company                           Product   TypeName  Inches  \
# 1215       1233    Acer  C740-C9QX (3205U/2GB/32GB/Chrome    Netbook    11.6
# 1             2   Apple                       Macbook Air  Ultrabook    13.3
# ...         ...     ...                               ...        ...     ...
# 1120       1135    Vero  V131 (X5-Z8350/4GB/32GB/FHD/W10)   Notebook    13.3
# 877         888  Xiaomi                       Mi Notebook  Ultrabook    13.3
#
#                  ScreenResolution                                   Cpu  Ram  \
# 1215                     1366x768  Intel Celeron Dual Core 3205U 1.5GHz  2GB
# 1                        1440x900                  Intel Core i5 1.8GHz  8GB
# ...                           ...                                   ...  ...
# 1120            Full HD 1920x1080           Intel Atom X5-Z8350 1.44GHz  4GB
# 877   IPS Panel Full HD 1920x1080            Intel Core i5 6200U 2.3GHz  8GB
#
#                    Memory                     Gpu       OpSys  Weight  \
# 1215             32GB SSD       Intel HD Graphics   Chrome OS   1.3kg
# 1     128GB Flash Storage  Intel HD Graphics 6000       macOS  1.34kg
# ...                   ...                     ...         ...     ...
# 1120   32GB Flash Storage   Intel HD Graphics 400  Windows 10  1.35kg
# 877             256GB SSD    Nvidia GeForce 940MX  Windows 10  1.28kg
#
#       Price_euros Price_tier Screen Size Price_tiers Size_tiers
# 1215       174.00  Expensive       Small       Cheap  Too Small
# 1          898.94  Expensive       Small  Affordable      Small
# ...           ...        ...         ...         ...        ...
# 1120       196.00  Expensive       Small       Cheap      Small
# 877        935.00  Expensive       Small  Affordable      Small
#
# [19 rows x 17 columns]

# %%
df_laptops.drop_duplicates(['Company'], keep='last')[['Company', 'Price_euros']]
# Out:
#      Company  Price_euros
# 1189    Acer      2599.00
# 17     Apple      2858.00
# ...      ...          ...
# 191     Vero       260.00
# 514   Xiaomi      1399.95
#
# [19 rows x 2 columns]

# %%
df_values = df_laptops.sort_values(['Company','Inches'])

# %%
df_laptops.drop_duplicates(['Company'], keep='first')[['Company','Inches']]
# Out:
#      Company  Inches
# 1215    Acer    11.6
# 1      Apple    13.3
# ...      ...     ...
# 1120    Vero    13.3
# 877   Xiaomi    13.3
#
# [19 rows x 2 columns]

# %%
df_laptops.drop_duplicates(['Company'], keep='last')[['Company','Inches']]
# Out:
#      Company  Inches
# 1189    Acer    17.3
# 17     Apple    15.4
# ...      ...     ...
# 191     Vero    14.0
# 514   Xiaomi    15.6
#
# [19 rows x 2 columns]

# %%
df_laptops['Company'].unique()
# Out:
# array(['Acer', 'Apple', 'Asus', 'Chuwi', 'Dell', 'Fujitsu', 'Google',
#        'HP', 'Huawei', 'LG', 'Lenovo', 'MSI', 'Mediacom', 'Microsoft',
#        'Razer', 'Samsung', 'Toshiba', 'Vero', 'Xiaomi'], dtype=object)

# %%
df_laptops['Inches'].unique()
# Out:
# array([11.6, 15.6, 14. , 17.3, 13.3, 12. , 15.4, 14.1, 12.5, 12.3, 15. ,
#        17. , 13. , 10.1, 13.9, 11.3, 18.4, 13.5])

# %%
len(df_laptops['Inches'].unique())
# Out:
# 18

# %%
len(df_laptops['Company'].unique())
# Out:
# 19

# %%
df_laptops['Company'].nunique()
# Out:
# 19

# %%
df_laptops['Inches'].nunique()
# Out:
# 18

# %%
df = pd.read_csv('players_20.csv')

# %%
df
# Out:
#        sofifa_id                                         player_url  \
# 0         158023  https://sofifa.com/player/158023/lionel-messi/...
# 1          20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# ...          ...                                                ...
# 18276     251110  https://sofifa.com/player/251110/haijian-wang/...
# 18277     233449  https://sofifa.com/player/233449/ximing-pan/20...
#
#               short_name                            long_name  age  \
# 0               L. Messi       Lionel Andrés Messi Cuccittini   32
# 1      Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34
# ...                  ...                                  ...  ...
# 18276       Wang Haijian                                  汪海健   18
# 18277         Pan Ximing                                  潘喜明   26
#
#               dob  height_cm  weight_kg nationality  \
# 0      1987-06-24        170         72   Argentina
# 1      1985-02-05        187         83    Portugal
# ...           ...        ...        ...         ...
# 18276  2000-08-02        185         74    China PR
# 18277  1993-01-11        182         78    China PR
#
#                                 club  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 0                       FC Barcelona  ...  68+2  66+2  66+2  66+2  68+2  63+2
# 1                           Juventus  ...  65+3  61+3  61+3  61+3  65+3  61+3
# ...                              ...  ...   ...   ...   ...   ...   ...   ...
# 18276  Shanghai Greenland Shenhua FC  ...  48+2  48+2  48+2  48+2  48+2  48+2
# 18277         Hebei China Fortune FC  ...  48+2  49+2  49+2  49+2  48+2  48+2
#
#         lcb    cb   rcb    rb
# 0      52+2  52+2  52+2  63+2
# 1      53+3  53+3  53+3  61+3
# ...     ...   ...   ...   ...
# 18276  49+2  49+2  49+2  48+2
# 18277  50+2  50+2  50+2  48+2
#
# [18278 rows x 104 columns]

# %%
df.set_index('short_name', inplace=True)

# %%
df = df[['long_name','age','dob','height_cm','weight_kg','nationality','club']]

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...                                                ...  ...         ...
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df.loc['L. Messi']
# Out:
# long_name      Lionel Andrés Messi Cuccittini
# age                                        32
#                             ...
# nationality                         Argentina
# club                             FC Barcelona
# Name: L. Messi, Length: 7, dtype: object

# %%
df.loc['L. Messi', 'height_cm']
# Out:
# np.int64(170)

# %%
df.loc['Cristiano Ronaldo', 'weight_kg']
# Out:
# np.int64(83)

# %%
df.loc[:,'height_cm']
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
#                     ...
# Wang Haijian         185
# Pan Ximing           182
# Name: height_cm, Length: 18278, dtype: int64

# %%
df.loc['L. Messi', :]
# Out:
# long_name      Lionel Andrés Messi Cuccittini
# age                                        32
#                             ...
# nationality                         Argentina
# club                             FC Barcelona
# Name: L. Messi, Length: 7, dtype: object

# %%
df.loc[['L. Messi', 'Cristiano Ronaldo']]
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality          club
# short_name
# L. Messi                 170         72   Argentina  FC Barcelona
# Cristiano Ronaldo        187         83    Portugal      Juventus

# %%
df.loc[['L. Messi', 'Cristiano Ronaldo'], 'height_cm']
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Name: height_cm, dtype: int64

# %%
df.loc['L. Messi', ['weight_kg', 'height_cm']]
# Out:
# weight_kg     72
# height_cm    170
# Name: L. Messi, dtype: object

# %%
df.loc[['L. Messi', 'Cristiano Ronaldo'], ['height_cm', 'weight_kg']]
# Out:
#                    height_cm  weight_kg
# short_name
# L. Messi                 170         72
# Cristiano Ronaldo        187         83

# %%
players = ['L. Messi', 'Cristiano Ronaldo']
df.loc[players, 'age':'club']
# Out:
#                    age         dob  height_cm  weight_kg nationality  \
# short_name
# L. Messi            32  1987-06-24        170         72   Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
#
#                            club
# short_name
# L. Messi           FC Barcelona
# Cristiano Ronaldo      Juventus

# %%
columns = ['age', 'dob', 'height_cm', 'weight_kg', 'nationality', 'club']
df.index[:10]


df.loc['L. Messi':'M. Salah', columns]
# Out:
#                    age         dob  height_cm  weight_kg nationality  \
# short_name
# L. Messi            32  1987-06-24        170         72   Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
# ...                ...         ...        ...        ...         ...
# L. Modrić           33  1985-09-09        172         66     Croatia
# M. Salah            27  1992-06-15        175         71       Egypt
#
#                            club
# short_name
# L. Messi           FC Barcelona
# Cristiano Ronaldo      Juventus
# ...                         ...
# L. Modrić           Real Madrid
# M. Salah              Liverpool
#
# [10 rows x 6 columns]

# %%
df.loc[df['height_cm']> 180, columns]
# Out:
#                    age         dob  height_cm  weight_kg nationality  \
# short_name
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
# J. Oblak            26  1993-01-07        188         87    Slovenia
# ...                ...         ...        ...        ...         ...
# Wang Haijian        18  2000-08-02        185         74    China PR
# Pan Ximing          26  1993-01-11        182         78    China PR
#
#                                             club
# short_name
# Cristiano Ronaldo                       Juventus
# J. Oblak                         Atlético Madrid
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [9744 rows x 6 columns]

# %%
df.loc[(df['height_cm'] > 180) & (df['nationality'] == 'Argentina'), :]
# Out:
#                                   long_name  age         dob  height_cm  \
# short_name
# M. Icardi       Mauro Emanuel Icardi Rivero   26  1993-02-19        181
# G. Higuaín          Gonzalo Gerardo Higuaín   31  1987-12-10        186
# ...                                     ...  ...         ...        ...
# L. Finochietto          Leandro Finochietto   22  1997-04-25        186
# N. Forastiero            Nicolás Forastiero   20  1998-07-16        182
#
#                 weight_kg nationality                club
# short_name
# M. Icardi              75   Argentina               Inter
# G. Higuaín             89   Argentina            Juventus
# ...                   ...         ...                 ...
# L. Finochietto         77   Argentina  Argentinos Juniors
# N. Forastiero          79   Argentina  Argentinos Juniors
#
# [350 rows x 7 columns]

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...                                                ...  ...         ...
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df.iloc[0]
# Out:
# long_name      Lionel Andrés Messi Cuccittini
# age                                        32
#                             ...
# nationality                         Argentina
# club                             FC Barcelona
# Name: L. Messi, Length: 7, dtype: object

# %%
df.iloc[0,3]
# Out:
# np.int64(170)

# %%
df.iloc[1]
# Out:
# long_name      Cristiano Ronaldo dos Santos Aveiro
# age                                             34
#                               ...
# nationality                               Portugal
# club                                      Juventus
# Name: Cristiano Ronaldo, Length: 7, dtype: object

# %%
df.iloc[1,4]
# Out:
# np.int64(83)

# %%
df.iloc[:, 3]
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
#                     ...
# Wang Haijian         185
# Pan Ximing           182
# Name: height_cm, Length: 18278, dtype: int64

# %%
df.iloc[0, :]
# Out:
# long_name      Lionel Andrés Messi Cuccittini
# age                                        32
#                             ...
# nationality                         Argentina
# club                             FC Barcelona
# Name: L. Messi, Length: 7, dtype: object

# %%
df.iloc[[0, 1]]
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
#
#                    height_cm  weight_kg nationality          club
# short_name
# L. Messi                 170         72   Argentina  FC Barcelona
# Cristiano Ronaldo        187         83    Portugal      Juventus

# %%
df.iloc[[0,1],3]
# Out:
# short_name
# L. Messi             170
# Cristiano Ronaldo    187
# Name: height_cm, dtype: int64

# %%
df.iloc[0, [3, 4]]
# Out:
# height_cm    170
# weight_kg     72
# Name: L. Messi, dtype: object

# %%
df.iloc[[0, 1],[3,4]]
# Out:
#                    height_cm  weight_kg
# short_name
# L. Messi                 170         72
# Cristiano Ronaldo        187         83

# %%
players = [0, 1]
df.iloc[players, 1:7]
# Out:
#                    age         dob  height_cm  weight_kg nationality  \
# short_name
# L. Messi            32  1987-06-24        170         72   Argentina
# Cristiano Ronaldo   34  1985-02-05        187         83    Portugal
#
#                            club
# short_name
# L. Messi           FC Barcelona
# Cristiano Ronaldo      Juventus

# %%
columns = [1,2,3,4]
df.iloc[0:10, columns]
# Out:
#                    age         dob  height_cm  weight_kg
# short_name
# L. Messi            32  1987-06-24        170         72
# Cristiano Ronaldo   34  1985-02-05        187         83
# ...                ...         ...        ...        ...
# L. Modrić           33  1985-09-09        172         66
# M. Salah            27  1992-06-15        175         71
#
# [10 rows x 4 columns]

# %%
df.iloc[list(df['height_cm']>180), columns]
# Out:
#                    age         dob  height_cm  weight_kg
# short_name
# Cristiano Ronaldo   34  1985-02-05        187         83
# J. Oblak            26  1993-01-07        188         87
# ...                ...         ...        ...        ...
# Wang Haijian        18  2000-08-02        185         74
# Pan Ximing          26  1993-01-11        182         78
#
# [9744 rows x 4 columns]

# %%
df.iloc[list((df['height_cm']>180) & (df['nationality'] == 'Argentina')), :]
# Out:
#                                   long_name  age         dob  height_cm  \
# short_name
# M. Icardi       Mauro Emanuel Icardi Rivero   26  1993-02-19        181
# G. Higuaín          Gonzalo Gerardo Higuaín   31  1987-12-10        186
# ...                                     ...  ...         ...        ...
# L. Finochietto          Leandro Finochietto   22  1997-04-25        186
# N. Forastiero            Nicolás Forastiero   20  1998-07-16        182
#
#                 weight_kg nationality                club
# short_name
# M. Icardi              75   Argentina               Inter
# G. Higuaín             89   Argentina            Juventus
# ...                   ...         ...                 ...
# L. Finochietto         77   Argentina  Argentinos Juniors
# N. Forastiero          79   Argentina  Argentinos Juniors
#
# [350 rows x 7 columns]

# %%
df.loc['L. Messi', 'height_cm'] = 175

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...                                                ...  ...         ...
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 175         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df.loc[:, 'height_cm'] = 190

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...                                                ...  ...         ...
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 190         72   Argentina
# Cristiano Ronaldo        190         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             190         74    China PR
# Pan Ximing               190         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df.iloc[-1, :]
# Out:
# long_name                         潘喜明
# age                                26
#                         ...
# nationality                  China PR
# club           Hebei China Fortune FC
# Name: Pan Ximing, Length: 7, dtype: object

# %%
df.iloc[-1, :] = np.nan

# %%
df
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# ...                                                ...   ...         ...
# Wang Haijian                                       汪海健  18.0  2000-08-02
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi               190.0       72.0   Argentina
# Cristiano Ronaldo      190.0       83.0    Portugal
# ...                      ...        ...         ...
# Wang Haijian           190.0       74.0    China PR
# Pan Ximing               NaN        NaN         NaN
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                                   NaN
#
# [18278 rows x 7 columns]

# %%
df.loc[['L. Messi', 'Cristiano Ronaldo'], ['height_cm']]
# Out:
#                    height_cm
# short_name
# L. Messi               175.0
# Cristiano Ronaldo      175.0

# %%
df
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# ...                                                ...   ...         ...
# Wang Haijian                                       汪海健  18.0  2000-08-02
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi               175.0       72.0   Argentina
# Cristiano Ronaldo      175.0       83.0    Portugal
# ...                      ...        ...         ...
# Wang Haijian           190.0       74.0    China PR
# Pan Ximing               NaN        NaN         NaN
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                                   NaN
#
# [18278 rows x 7 columns]

# %%
columns = ['age', 'dob' , 'height_cm', 'weight_kg']
df.loc[df['height_cm'] > 180, columns] = 0

# %%
df
# Out:
#                                              long_name   age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini  32.0  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro  34.0  1985-02-05
# ...                                                ...   ...         ...
# Wang Haijian                                       汪海健   0.0           0
# Pan Ximing                                         NaN   NaN         NaN
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi               175.0       72.0   Argentina
# Cristiano Ronaldo      175.0       83.0    Portugal
# ...                      ...        ...         ...
# Wang Haijian             0.0        0.0    China PR
# Pan Ximing               NaN        NaN         NaN
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                                   NaN
#
# [18278 rows x 7 columns]

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...                                                ...  ...         ...
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df.drop('L. Messi', axis=0)

df.drop(index=['L. Messi'])
# Out:
#                                              long_name  age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# ...                                                ...  ...         ...
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# Cristiano Ronaldo        187         83    Portugal
# Neymar Jr                175         68      Brazil
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# Cristiano Ronaldo                       Juventus
# Neymar Jr                    Paris Saint-Germain
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18277 rows x 7 columns]

# %%
df.drop(['L. Messi', 'Cristiano Ronaldo'], axis=0, inplace=True)

# %%
df
# Out:
#                                   long_name  age         dob  height_cm  \
# short_name
# Neymar Jr     Neymar da Silva Santos Junior   27  1992-02-05        175
# J. Oblak                          Jan Oblak   26  1993-01-07        188
# ...                                     ...  ...         ...        ...
# Wang Haijian                            汪海健   18  2000-08-02        185
# Pan Ximing                              潘喜明   26  1993-01-11        182
#
#               weight_kg nationality                           club
# short_name
# Neymar Jr            68      Brazil            Paris Saint-Germain
# J. Oblak             87    Slovenia                Atlético Madrid
# ...                 ...         ...                            ...
# Wang Haijian         74    China PR  Shanghai Greenland Shenhua FC
# Pan Ximing           78    China PR         Hebei China Fortune FC
#
# [18276 rows x 7 columns]

# %%
df.drop('long_name', axis=1)
# Out:
#               age         dob  height_cm  weight_kg nationality  \
# short_name
# Neymar Jr      27  1992-02-05        175         68      Brazil
# J. Oblak       26  1993-01-07        188         87    Slovenia
# ...           ...         ...        ...        ...         ...
# Wang Haijian   18  2000-08-02        185         74    China PR
# Pan Ximing     26  1993-01-11        182         78    China PR
#
#                                        club
# short_name
# Neymar Jr               Paris Saint-Germain
# J. Oblak                    Atlético Madrid
# ...                                     ...
# Wang Haijian  Shanghai Greenland Shenhua FC
# Pan Ximing           Hebei China Fortune FC
#
# [18276 rows x 6 columns]

# %%
df.drop(columns=['long_name'])
# Out:
#               age         dob  height_cm  weight_kg nationality  \
# short_name
# Neymar Jr      27  1992-02-05        175         68      Brazil
# J. Oblak       26  1993-01-07        188         87    Slovenia
# ...           ...         ...        ...        ...         ...
# Wang Haijian   18  2000-08-02        185         74    China PR
# Pan Ximing     26  1993-01-11        182         78    China PR
#
#                                        club
# short_name
# Neymar Jr               Paris Saint-Germain
# J. Oblak                    Atlético Madrid
# ...                                     ...
# Wang Haijian  Shanghai Greenland Shenhua FC
# Pan Ximing           Hebei China Fortune FC
#
# [18276 rows x 6 columns]

# %%
df.drop(df.columns[[-1]], axis=1)
# Out:
#                                   long_name  age         dob  height_cm  \
# short_name
# Neymar Jr     Neymar da Silva Santos Junior   27  1992-02-05        175
# J. Oblak                          Jan Oblak   26  1993-01-07        188
# ...                                     ...  ...         ...        ...
# Wang Haijian                            汪海健   18  2000-08-02        185
# Pan Ximing                              潘喜明   26  1993-01-11        182
#
#               weight_kg nationality
# short_name
# Neymar Jr            68      Brazil
# J. Oblak             87    Slovenia
# ...                 ...         ...
# Wang Haijian         74    China PR
# Pan Ximing           78    China PR
#
# [18276 rows x 6 columns]

# %%
df.drop(['long_name', 'dob'], axis=1, inplace=True)

# %%
df
# Out:
#               age  height_cm  weight_kg nationality  \
# short_name
# Neymar Jr      27        175         68      Brazil
# J. Oblak       26        188         87    Slovenia
# ...           ...        ...        ...         ...
# Wang Haijian   18        185         74    China PR
# Pan Ximing     26        182         78    China PR
#
#                                        club
# short_name
# Neymar Jr               Paris Saint-Germain
# J. Oblak                    Atlético Madrid
# ...                                     ...
# Wang Haijian  Shanghai Greenland Shenhua FC
# Pan Ximing           Hebei China Fortune FC
#
# [18276 rows x 5 columns]

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...                                                ...  ...         ...
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df['nationality'].sample(10, random_state=1)
# Out:
# short_name
# D. Cvetinović      Serbia
# M. Silva          Uruguay
#                    ...
# He Chao          China PR
# P. Ruffaut         France
# Name: nationality, Length: 10, dtype: object

# %%
df.sample(frac=0.2, random_state=12)
# Out:
#                         long_name  age         dob  height_cm  weight_kg  \
# short_name
# Y. Thoelen        Yannick Thoelen   28  1990-07-18        188         89
# M. Nadé              Mickaël Nadé   20  1999-03-04        188         80
# ...                           ...  ...         ...        ...        ...
# H. Sakai                    酒井 宏樹   29  1990-04-12        183         70
# C. Keșerü   Claudiu Andrei Keșerü   32  1986-12-02        178         71
#
#            nationality                    club
# short_name
# Y. Thoelen     Belgium             KV Mechelen
# M. Nadé         France        AS Saint-Étienne
# ...                ...                     ...
# H. Sakai         Japan  Olympique de Marseille
# C. Keșerü      Romania                 Romania
#
# [3656 rows x 7 columns]

# %%
df.sample(frac=2, replace=True)
# Out:
#                  long_name  age         dob  height_cm  weight_kg nationality  \
# short_name
# Liu Yang                刘洋   24  1995-06-17        184         74    China PR
# M. Platt     Matthew Platt   21  1997-10-03        188         81     England
# ...                    ...  ...         ...        ...        ...         ...
# G. Thorne    George Thorne   26  1993-01-04        188         84     England
# N. Blandi   Nicolás Blandi   29  1990-01-13        181         76   Argentina
#
#                                   club
# short_name
# Liu Yang    Shandong Luneng TaiShan FC
# M. Platt              Blackburn Rovers
# ...                                ...
# G. Thorne                 Derby County
# N. Blandi       San Lorenzo de Almagro
#
# [36556 rows x 7 columns]

# %%
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...                                                ...  ...         ...
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df.query("age>34")
# Out:
#                                    long_name  age         dob  height_cm  \
# short_name
# Z. Ibrahimović            Zlatan Ibrahimović   37  1981-10-03        195
# Pepe            Képler Laveran Lima Ferreira   36  1983-02-26        188
# ...                                      ...  ...         ...        ...
# G. Maley                          Gary Maley   36  1982-08-03        188
# Zhou Ting                                 周挺   40  1979-02-05        182
#
#                 weight_kg nationality              club
# short_name
# Z. Ibrahimović         95      Sweden         LA Galaxy
# Pepe                   81    Portugal          FC Porto
# ...                   ...         ...               ...
# G. Maley               90    Scotland     Livingston FC
# Zhou Ting              73    China PR  Dalian YiFang FC
#
# [603 rows x 7 columns]

# %%
df[df['age']>34]
# Out:
#                                    long_name  age         dob  height_cm  \
# short_name
# Z. Ibrahimović            Zlatan Ibrahimović   37  1981-10-03        195
# Pepe            Képler Laveran Lima Ferreira   36  1983-02-26        188
# ...                                      ...  ...         ...        ...
# G. Maley                          Gary Maley   36  1982-08-03        188
# Zhou Ting                                 周挺   40  1979-02-05        182
#
#                 weight_kg nationality              club
# short_name
# Z. Ibrahimović         95      Sweden         LA Galaxy
# Pepe                   81    Portugal          FC Porto
# ...                   ...         ...               ...
# G. Maley               90    Scotland     Livingston FC
# Zhou Ting              73    China PR  Dalian YiFang FC
#
# [603 rows x 7 columns]

# %%
df.query("age>34 & nationality=='Italy'")
# Out:
#                           long_name  age         dob  height_cm  weight_kg  \
# short_name
# G. Buffon          Gianluigi Buffon   41  1978-01-28        192         92
# F. Quagliarella  Fabio Quagliarella   36  1983-01-31        180         79
# ...                             ...  ...         ...        ...        ...
# P. Gori          Pier Graziano Gori   39  1980-05-10        189         83
# S. Farelli           Simone Farelli   36  1983-02-19        186         82
#
#                 nationality       club
# short_name
# G. Buffon             Italy   Juventus
# F. Quagliarella       Italy  Sampdoria
# ...                     ...        ...
# P. Gori               Italy  Benevento
# S. Farelli            Italy    Pescara
#
# [34 rows x 7 columns]

# %%
df.query("~(age>34)")
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# ...                                                ...  ...         ...
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [17675 rows x 7 columns]

# %%
df.query("height_cm/100 > 1.8")
# Out:
#                                              long_name  age         dob  \
# short_name
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# ...                                                ...  ...         ...
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# Cristiano Ronaldo        187         83    Portugal
# J. Oblak                 188         87    Slovenia
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# Cristiano Ronaldo                       Juventus
# J. Oblak                         Atlético Madrid
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [9744 rows x 7 columns]

# %%
df.dtypes
# Out:
# long_name      object
# age             int64
#                 ...
# nationality    object
# club           object
# Length: 7, dtype: object

# %%
df['dob'] = df['dob'].astype('datetime64[ns]')

# %%
df
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# ...                                                ...  ...        ...
# Wang Haijian                                       汪海健   18 2000-08-02
# Pan Ximing                                         潘喜明   26 1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df['dob'].dt.year
# Out:
# short_name
# L. Messi             1987
# Cristiano Ronaldo    1985
#                      ...
# Wang Haijian         2000
# Pan Ximing           1993
# Name: dob, Length: 18278, dtype: int32

# %%
df.query("dob.dt.year > 1990")
# Out:
#                                   long_name  age        dob  height_cm  \
# short_name
# Neymar Jr     Neymar da Silva Santos Junior   27 1992-02-05        175
# J. Oblak                          Jan Oblak   26 1993-01-07        188
# ...                                     ...  ...        ...        ...
# Wang Haijian                            汪海健   18 2000-08-02        185
# Pan Ximing                              潘喜明   26 1993-01-11        182
#
#               weight_kg nationality                           club
# short_name
# Neymar Jr            68      Brazil            Paris Saint-Germain
# J. Oblak             87    Slovenia                Atlético Madrid
# ...                 ...         ...                            ...
# Wang Haijian         74    China PR  Shanghai Greenland Shenhua FC
# Pan Ximing           78    China PR         Hebei China Fortune FC
#
# [13140 rows x 7 columns]

# %%
df['age'].apply(np.sqrt)
# Out:
# short_name
# L. Messi             5.656854
# Cristiano Ronaldo    5.830952
#                        ...
# Wang Haijian         4.242641
# Pan Ximing           5.099020
# Name: age, Length: 18278, dtype: float64

# %%
def calculate_bmi(row):
    return row['weight_kg']/(row['height_cm']/100)**2

# %%
df.apply(calculate_bmi, axis=1)
# Out:
# short_name
# L. Messi             24.913495
# Cristiano Ronaldo    23.735308
#                        ...
# Wang Haijian         21.621622
# Pan Ximing           23.547881
# Length: 18278, dtype: float64

# %%
def sum_values(a,b):
    x = a+b
    return x

# %%
sum_values(2,3)
# Out:
# 5

# %%
sum_values_lambda = lambda a,b: a+b

# %%
sum_values_lambda(1,2)
# Out:
# 3

# %%
df['height_cm'].apply(lambda x:x/100)
# Out:
# short_name
# L. Messi             1.70
# Cristiano Ronaldo    1.87
#                      ...
# Wang Haijian         1.85
# Pan Ximing           1.82
# Name: height_cm, Length: 18278, dtype: float64

# %%
df['height_cm']/100
# Out:
# short_name
# L. Messi             1.70
# Cristiano Ronaldo    1.87
#                      ...
# Wang Haijian         1.85
# Pan Ximing           1.82
# Name: height_cm, Length: 18278, dtype: float64

# %%
df['long_name'].apply(lambda x: x.upper())
# Out:
# short_name
# L. Messi                  LIONEL ANDRÉS MESSI CUCCITTINI
# Cristiano Ronaldo    CRISTIANO RONALDO DOS SANTOS AVEIRO
#                                     ...
# Wang Haijian                                         汪海健
# Pan Ximing                                           潘喜明
# Name: long_name, Length: 18278, dtype: object

# %%
df['long_name'].str.upper()
# Out:
# short_name
# L. Messi                  LIONEL ANDRÉS MESSI CUCCITTINI
# Cristiano Ronaldo    CRISTIANO RONALDO DOS SANTOS AVEIRO
#                                     ...
# Wang Haijian                                         汪海健
# Pan Ximing                                           潘喜明
# Name: long_name, Length: 18278, dtype: object

# %%
df.dtypes
# Out:
# long_name      object
# age             int64
#                 ...
# nationality    object
# club           object
# Length: 7, dtype: object

# %%
df['dob'] = df['dob'].astype('datetime64[ns]')

# %%
df['dob'].apply(lambda x:x.year)
# Out:
# short_name
# L. Messi             1987
# Cristiano Ronaldo    1985
#                      ...
# Wang Haijian         2000
# Pan Ximing           1993
# Name: dob, Length: 18278, dtype: int64

# %%
df['dob'].dt.year
# Out:
# short_name
# L. Messi             1987
# Cristiano Ronaldo    1985
#                      ...
# Wang Haijian         2000
# Pan Ximing           1993
# Name: dob, Length: 18278, dtype: int32

# %%
df.apply(lambda x:x['weight_kg'] / ((x['height_cm']/100)**2), axis=1)
# Out:
# short_name
# L. Messi             24.913495
# Cristiano Ronaldo    23.735308
#                        ...
# Wang Haijian         21.621622
# Pan Ximing           23.547881
# Length: 18278, dtype: float64

# %%
df_copy = df.copy()

# %%
df.loc['L. Messi', 'height_cm'] = 180

# %%
df
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# ...                                                ...  ...        ...
# Wang Haijian                                       汪海健   18 2000-08-02
# Pan Ximing                                         潘喜明   26 1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 180         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df_copy
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# ...                                                ...  ...        ...
# Wang Haijian                                       汪海健   18 2000-08-02
# Pan Ximing                                         潘喜明   26 1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df_shallow_copy = df.copy(deep=False)

# %%
df.loc['Cristiano Ronaldo', 'height_cm'] = 200

# %%
df
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# ...                                                ...  ...        ...
# Wang Haijian                                       汪海健   18 2000-08-02
# Pan Ximing                                         潘喜明   26 1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 180         72   Argentina
# Cristiano Ronaldo        200         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df_copy
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# ...                                                ...  ...        ...
# Wang Haijian                                       汪海健   18 2000-08-02
# Pan Ximing                                         潘喜明   26 1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 170         72   Argentina
# Cristiano Ronaldo        187         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df_shallow_copy
# Out:
#                                              long_name  age        dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32 1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34 1985-02-05
# ...                                                ...  ...        ...
# Wang Haijian                                       汪海健   18 2000-08-02
# Pan Ximing                                         潘喜明   26 1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# L. Messi                 180         72   Argentina
# Cristiano Ronaldo        200         83    Portugal
# ...                      ...        ...         ...
# Wang Haijian             185         74    China PR
# Pan Ximing               182         78    China PR
#
#                                             club
# short_name
# L. Messi                            FC Barcelona
# Cristiano Ronaldo                       Juventus
# ...                                          ...
# Wang Haijian       Shanghai Greenland Shenhua FC
# Pan Ximing                Hebei China Fortune FC
#
# [18278 rows x 7 columns]

# %%
df_new_copy = df

# %%
df.loc['Neymar Jr', 'height_cm'] = 190

# %%
df.loc['Neymar Jr', 'height_cm']
# Out:
# np.int64(190)

# %%
df_gdp = pd.read_csv('gdp.csv', encoding='unicode escape')

# %%
df_gdp.pivot(index='year', columns='country', values='gdppc')
# Out:
# country  Afghanistan    Albania      Algeria      Angola  Argentina  \
# year
# 1880       585.46509   522.0000    819.18604   533.66669   1731.500
# 1890       635.93024   598.0000    923.37207   567.33331   2152.000
# ...              ...        ...          ...         ...        ...
# 2000       565.00000  5470.0176  10211.10400  3831.00000  14924.374
# 2010      1662.80350  9927.1758  12898.29600  6492.17680  18794.270
#
# country    Armenia  Australia    Austria      Bahrain  Bangladesh  ...  \
# year                                                               ...
# 1880     1041.0000   4285.000   2079.000    811.76746   566.66669  ...
# 1890     1139.0000   4458.000   2443.000    881.53491   587.33331  ...
# ...            ...        ...        ...          ...         ...  ...
# 2000     2918.5576  35244.504  38812.051  44791.52000  1645.71730  ...
# 2010     6507.9146  41363.215  43174.977  39912.69500  2451.30520  ...
#
# country    Ukraine  United Arab Emirates  United Kingdom  United States  \
# year
# 1880     1041.0000             811.76746        3477.000       3184.000
# 1890     1139.0000             881.53491        4009.000       3392.000
# ...            ...                   ...             ...            ...
# 2000     4797.3804          107206.46000       32961.527      45986.051
# 2010     7824.4985           57406.73800       36195.867      49372.832
#
# country    Uruguay  Venezuela     Vietnam       Yemen      Zambia    Zimbabwe
# year
# 1880      2082.000    653.000   556.62793   811.76746   533.66669   533.66669
# 1890      2147.000    737.000   608.25580   881.53491   567.33331   567.33331
# ...            ...        ...         ...         ...         ...         ...
# 2000     12874.776  14417.104  2649.71950  3911.21970  2092.25510  2521.34740
# 2010     17082.410  16563.396  4486.26120  4481.55470  3263.39480  1388.97300
#
# [14 rows x 149 columns]

# %%
df_sales = pd.read_excel('supermarket_sales.xlsx')

# %%
df_sales.pivot_table(index='Gender', values='Total', aggfunc='sum')
# Out:
#              Total
# Gender
# Female  167882.925
# Male    155083.824

# %%
df_sales.pivot_table(index='Gender', values=['Quantity', 'Total'], aggfunc='sum')
# Out:
#         Quantity       Total
# Gender
# Female      2869  167882.925
# Male        2641  155083.824

# %%
df_sales.pivot_table(index='Gender', values='Total', columns='Product line', aggfunc='sum')
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  \
# Gender
# Female                    27102.0225            30437.400          33170.9175
# Male                      27235.5090            23868.495          22973.9265
#
# Product line  Health and beauty  Home and lifestyle  Sports and travel
# Gender
# Female               18560.9865          30036.8775         28574.7210
# Male                 30632.7525          23825.0355         26548.1055

# %%
df_population_raw = pd.read_csv('population_total.csv')

# %%
df_population_raw
# Out:
#      country    year    population
# 0      China  2020.0  1.439324e+09
# 1      China  2019.0  1.433784e+09
# ...      ...     ...           ...
# 4183   India  1960.0  4.505477e+08
# 4184   India  1955.0  4.098806e+08
#
# [4185 rows x 3 columns]

# %%
df_population_raw.dropna(inplace=True)

# %%
df_pivot = df_population_raw.pivot(index='year', columns='country', values='population')

# %%
df_pivot = df_pivot[['United States', 'India', 'China', 'Indonesia', 'Brazil']]

# %%
df_pivot.plot(kind='line', xlabel='Year', ylabel='Population', title='Population (1955-2020)', figsize=(8,4))
# Out:
# <Axes: title={'center': 'Population (1955-2020)'}, xlabel='Year', ylabel='Population'>

# %%
df_pivot_2020 = df_pivot[df_pivot.index.isin([2020])]

# %%
df_pivot_2020 = df_pivot_2020.T

# %%
df_pivot_2020.plot(kind='bar', color='orange', xlabel='year', ylabel='population', title='population 2020')
# Out:
# <Axes: title={'center': 'population 2020'}, xlabel='year', ylabel='population'>

# %%
df_pivot_sample = df_pivot[df_pivot.index.isin([1980,1990,2000, 2010,2020])]

# %%
df_pivot_sample
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 1980.0     229476354.0  6.989528e+08  1.000089e+09  147447836.0  120694009.0
# 1990.0     252120309.0  8.732778e+08  1.176884e+09  181413402.0  149003223.0
# 2000.0     281710909.0  1.056576e+09  1.290551e+09  211513823.0  174790340.0
# 2010.0     309011475.0  1.234281e+09  1.368811e+09  241834215.0  195713635.0
# 2020.0     331002651.0  1.380004e+09  1.439324e+09  273523615.0  212559417.0

# %%
df_pivot_sample.plot(kind='bar')
# Out:
# <Axes: xlabel='year'>

# %%
df_pivot_2020.rename(columns={2020: '2020'}, inplace=True)

# %%
df_pivot_2020.plot(kind='pie', y='2020', title='population in 2020')
# Out:
# <Axes: title={'center': 'population in 2020'}, ylabel='2020'>

# %%
df_pivot['United States'].plot(kind='box', color='green', ylabel='Population')
# Out:
# <Axes: ylabel='Population'>

# %%
df_pivot.plot(kind='box', color='green', ylabel='population')
# Out:
# <Axes: ylabel='population'>

# %%
df_pivot[['Indonesia', 'United States']].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df_sample = df_population_raw[df_population_raw['country'].isin(['United States', 'India', ' China', 'Brazil'])]

# %%
df_sample
# Out:
#      country    year   population
# 3883  Brazil  2020.0  212559417.0
# 3884  Brazil  2019.0  211049527.0
# ...      ...     ...          ...
# 4183   India  1960.0  450547679.0
# 4184   India  1955.0  409880595.0
#
# [54 rows x 3 columns]

# %%
df_sample.plot(kind='scatter', x='year', y='population', s=80,)
# Out:
# <Axes: xlabel='year', ylabel='population'>

# %%
import matplotlib.pyplot as plt

# %%
df_pivot.plot(kind='line', xlabel='Years', ylabel='Population', title='Population (1955-2020)', figsize=(8,4))

plt.savefig('my_test.png')

plt.show()

# %%
df_pivot.to_excel('pivot_table.xlsx')

# %%
# !pip install plotly
# !pip install cufflinks

# %%
import cufflinks as cf
from IPython.display import display, HTML

cf.set_config_file(sharing='public', theme='ggplot', offline=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.1.0.min"</script>

# %%
df_population_raw.dropna(inplace=True)
df_pivot=df_population_raw.pivot(index='year', columns='country', values='population')
df_pivot = df_pivot[['United States', 'India', 'China', 'Indonesia', 'Brazil']]
df_pivot
# Out:
# country  United States         India         China    Indonesia       Brazil
# year
# 1955.0     171685336.0  4.098806e+08  6.122416e+08   77273425.0   62533919.0
# 1960.0     186720571.0  4.505477e+08  6.604081e+08   87751068.0   72179226.0
# ...                ...           ...           ...          ...          ...
# 2019.0     329064917.0  1.366418e+09  1.433784e+09  270625568.0  211049527.0
# 2020.0     331002651.0  1.380004e+09  1.439324e+09  273523615.0  212559417.0
#
# [18 rows x 5 columns]

# %%
df_pivot.iplot(kind='line', xTitle='Years', yTitle='Population', title='Population (1955-2020)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[832], line 1
# ----> 1 df_pivot.iplot(kind='line', xTitle='Years', yTitle='Population', title='Population (1955-2020)')
#
# File /opt/anaconda3/lib/python3.13/site-packages/cufflinks/plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
#     838 		text=self[text].values
# --> 839 data=df.to_iplot(colors=colors,colorscale=colorscale,kind=kind,interpolation=interpolation,fill=fill,width=width,dash=dash,sortbars=sortbars,keys=keys,
#     840 		bestfit=bestfit,bestfit_colors=bestfit_colors,mean=mean,mean_colors=mean_colors,asDates=asDates,mode=mode,symbol=symbol,size=size,
#     841 		text=text,**kwargs)
#     842 trace_kw=check_kwargs(kwargs,TRACE_KWARGS)
#     843 for trace in data:
#
# File /opt/anaconda3/lib/python3.13/site-packages/cufflinks/plotlytools.py:161, in _to_iplot(self, colors, colorscale, kind, mode, interpolation, symbol, size, fill, width, dash, sortbars, keys, bestfit, bestfit_colors, opacity, mean, mean_colors, asDates, asTimestamp, text, **kwargs)
#     159 	lines_plotly=[Bar(lines[key]).to_plotly_json() for key in keys]
#     160 else:
# --> 161 	lines_plotly=[Scatter(lines[key]).to_plotly_json() for key in keys]
#     162 for trace in lines_plotly:
#     163 	if isinstance(trace['name'],pd.Timestamp):
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/_scatter.py:2703, in Scatter.__init__(self, arg, alignmentgroup, cliponaxis, connectgaps, customdata, customdatasrc, dx, dy, error_x, error_y, fill, fillcolor, fillgradient, fillpattern, groupnorm, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, marker, meta, metasrc, mode, name, offsetgroup, opacity, orientation, selected, selectedpoints, showlegend, stackgaps, stackgroup, stream, text, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    2701 self._set_property("legendrank", arg, legendrank)
#    2702 self._set_property("legendwidth", arg, legendwidth)
# -> 2703 self._set_property("line", arg, line)
#    2704 self._set_property("marker", arg, marker)
#    2705 self._set_property("meta", arg, meta)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4924, in BasePlotlyType.__setitem__(self, prop, value)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
# -> 4924     self._set_compound_prop(prop, value)
#    4926 # ### Handle compound array property ###
#    4927 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5335, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5332 # Import value
#    5333 # ------------
#    5334 validator = self._get_validator(prop)
# -> 5335 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5337 # Save deep copies of current and new states
#    5338 # ------------------------------------------
#    5339 curr_val = self._compound_props.get(prop, None)
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:2425, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2422     v = self.data_class()
#    2424 elif isinstance(v, dict):
# -> 2425     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2427 elif isinstance(v, self.data_class):
#    2428     # Copy object
#    2429     v = self.data_class(v)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/scatter/_line.py:303, in Line.__init__(self, arg, backoff, backoffsrc, color, dash, shape, simplify, smoothing, width, **kwargs)
#     301 self._set_property("backoff", arg, backoff)
#     302 self._set_property("backoffsrc", arg, backoffsrc)
# --> 303 self._set_property("color", arg, color)
#     304 self._set_property("dash", arg, dash)
#     305 self._set_property("shape", arg, shape)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4932, in BasePlotlyType.__setitem__(self, prop, value)
#    4928         self._set_array_prop(prop, value)
#    4930     # ### Handle simple property ###
#    4931     else:
# -> 4932         self._set_prop(prop, value)
#    4933 else:
#    4934     # Make sure properties dict is initialized
#    4935     self._init_props()
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5276, in BasePlotlyType._set_prop(self, prop, val)
#    5274         return
#    5275     else:
# -> 5276         raise err
#    5278 # val is None
#    5279 # -----------
#    5280 if val is None:
#    5281     # Check if we should send null update
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5271, in BasePlotlyType._set_prop(self, prop, val)
#    5268 validator = self._get_validator(prop)
#    5270 try:
# -> 5271     val = validator.validate_coerce(val)
#    5272 except ValueError as err:
#    5273     if self._skip_invalid:
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:1374, in ColorValidator.validate_coerce(self, v, should_raise)
#    1372     validated_v = self.vc_scalar(v)
#    1373     if validated_v is None and should_raise:
# -> 1374         self.raise_invalid_val(v)
#    1376     v = validated_v
#    1378 return v
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:298, in BaseValidator.raise_invalid_val(self, v, inds)
#     295             for i in inds:
#     296                 name += "[" + str(i) + "]"
# --> 298         raise ValueError(
#     299             """
#     300     Invalid value of type {typ} received for the '{name}' property of {pname}
#     301         Received value: {v}
#     302
#     303 {valid_clr_desc}""".format(
#     304                 name=name,
#     305                 pname=self.parent_name,
#     306                 typ=type_str(v),
#     307                 v=repr(v),
#     308                 valid_clr_desc=self.description(),
#     309             )
#     310         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of scatter.line
#         Received value: 'rgba(226, 74, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color: see https://plotly.com/python/css-colors/ for a list

# %%
df_pivot_2020 = df_pivot[df_pivot.index.isin([2020])]
df_pivot_2020 = df_pivot_2020.T

# %%
df_pivot_2020.iplot(kind='bar', color='lightgreen', xTitle='Years', yTitle='Population')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[835], line 1
# ----> 1 df_pivot_2020.iplot(kind='bar', color='lightgreen', xTitle='Years', yTitle='Population')
#
# File /opt/anaconda3/lib/python3.13/site-packages/cufflinks/plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
#     838 		text=self[text].values
# --> 839 data=df.to_iplot(colors=colors,colorscale=colorscale,kind=kind,interpolation=interpolation,fill=fill,width=width,dash=dash,sortbars=sortbars,keys=keys,
#     840 		bestfit=bestfit,bestfit_colors=bestfit_colors,mean=mean,mean_colors=mean_colors,asDates=asDates,mode=mode,symbol=symbol,size=size,
#     841 		text=text,**kwargs)
#     842 trace_kw=check_kwargs(kwargs,TRACE_KWARGS)
#     843 for trace in data:
#
# File /opt/anaconda3/lib/python3.13/site-packages/cufflinks/plotlytools.py:159, in _to_iplot(self, colors, colorscale, kind, mode, interpolation, symbol, size, fill, width, dash, sortbars, keys, bestfit, bestfit_colors, opacity, mean, mean_colors, asDates, asTimestamp, text, **kwargs)
#     157 			lines[key]["fillcolor"]=to_rgba(colors[key],kwargs['opacity'] if 'opacity' in kwargs else .3		)
#     158 if 'bar' in kind:
# --> 159 	lines_plotly=[Bar(lines[key]).to_plotly_json() for key in keys]
#     160 else:
#     161 	lines_plotly=[Scatter(lines[key]).to_plotly_json() for key in keys]
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/_bar.py:2547, in Bar.__init__(self, arg, alignmentgroup, base, basesrc, cliponaxis, constraintext, customdata, customdatasrc, dx, dy, error_x, error_y, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, insidetextanchor, insidetextfont, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, marker, meta, metasrc, name, offset, offsetgroup, offsetsrc, opacity, orientation, outsidetextfont, selected, selectedpoints, showlegend, stream, text, textangle, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, width, widthsrc, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    2545 self._set_property("legendrank", arg, legendrank)
#    2546 self._set_property("legendwidth", arg, legendwidth)
# -> 2547 self._set_property("marker", arg, marker)
#    2548 self._set_property("meta", arg, meta)
#    2549 self._set_property("metasrc", arg, metasrc)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4924, in BasePlotlyType.__setitem__(self, prop, value)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
# -> 4924     self._set_compound_prop(prop, value)
#    4926 # ### Handle compound array property ###
#    4927 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5335, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5332 # Import value
#    5333 # ------------
#    5334 validator = self._get_validator(prop)
# -> 5335 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5337 # Save deep copies of current and new states
#    5338 # ------------------------------------------
#    5339 curr_val = self._compound_props.get(prop, None)
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:2425, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2422     v = self.data_class()
#    2424 elif isinstance(v, dict):
# -> 2425     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2427 elif isinstance(v, self.data_class):
#    2428     # Copy object
#    2429     v = self.data_class(v)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/bar/_marker.py:678, in Marker.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorbar, colorscale, colorsrc, cornerradius, line, opacity, opacitysrc, pattern, reversescale, showscale, **kwargs)
#     676 self._set_property("colorsrc", arg, colorsrc)
#     677 self._set_property("cornerradius", arg, cornerradius)
# --> 678 self._set_property("line", arg, line)
#     679 self._set_property("opacity", arg, opacity)
#     680 self._set_property("opacitysrc", arg, opacitysrc)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4924, in BasePlotlyType.__setitem__(self, prop, value)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
# -> 4924     self._set_compound_prop(prop, value)
#    4926 # ### Handle compound array property ###
#    4927 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5335, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5332 # Import value
#    5333 # ------------
#    5334 validator = self._get_validator(prop)
# -> 5335 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5337 # Save deep copies of current and new states
#    5338 # ------------------------------------------
#    5339 curr_val = self._compound_props.get(prop, None)
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:2425, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2422     v = self.data_class()
#    2424 elif isinstance(v, dict):
# -> 2425     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2427 elif isinstance(v, self.data_class):
#    2428     # Copy object
#    2429     v = self.data_class(v)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/bar/marker/_line.py:538, in Line.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorscale, colorsrc, reversescale, width, widthsrc, **kwargs)
#     536 self._set_property("cmid", arg, cmid)
#     537 self._set_property("cmin", arg, cmin)
# --> 538 self._set_property("color", arg, color)
#     539 self._set_property("coloraxis", arg, coloraxis)
#     540 self._set_property("colorscale", arg, colorscale)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4932, in BasePlotlyType.__setitem__(self, prop, value)
#    4928         self._set_array_prop(prop, value)
#    4930     # ### Handle simple property ###
#    4931     else:
# -> 4932         self._set_prop(prop, value)
#    4933 else:
#    4934     # Make sure properties dict is initialized
#    4935     self._init_props()
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5276, in BasePlotlyType._set_prop(self, prop, val)
#    5274         return
#    5275     else:
# -> 5276         raise err
#    5278 # val is None
#    5279 # -----------
#    5280 if val is None:
#    5281     # Check if we should send null update
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5271, in BasePlotlyType._set_prop(self, prop, val)
#    5268 validator = self._get_validator(prop)
#    5270 try:
# -> 5271     val = validator.validate_coerce(val)
#    5272 except ValueError as err:
#    5273     if self._skip_invalid:
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:1374, in ColorValidator.validate_coerce(self, v, should_raise)
#    1372     validated_v = self.vc_scalar(v)
#    1373     if validated_v is None and should_raise:
# -> 1374         self.raise_invalid_val(v)
#    1376     v = validated_v
#    1378 return v
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:298, in BaseValidator.raise_invalid_val(self, v, inds)
#     295             for i in inds:
#     296                 name += "[" + str(i) + "]"
# --> 298         raise ValueError(
#     299             """
#     300     Invalid value of type {typ} received for the '{name}' property of {pname}
#     301         Received value: {v}
#     302
#     303 {valid_clr_desc}""".format(
#     304                 name=name,
#     305                 pname=self.parent_name,
#     306                 typ=type_str(v),
#     307                 v=repr(v),
#     308                 valid_clr_desc=self.description(),
#     309             )
#     310         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of bar.marker.line
#         Received value: 'rgba(144, 238, 144, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color: see https://plotly.com/python/css-colors/ for a list
#       - A number that will be interpreted as a color
#         according to bar.marker.line.colorscale
#       - A list or array of any of the above

# %%
df_pivot_sample = df_pivot[df_pivot.index.isin([1980, 1990, 2000, 2010, 2020])]

# %%
df_pivot_sample.iplot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[838], line 1
# ----> 1 df_pivot_sample.iplot(kind='bar')
#
# File /opt/anaconda3/lib/python3.13/site-packages/cufflinks/plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
#     838 		text=self[text].values
# --> 839 data=df.to_iplot(colors=colors,colorscale=colorscale,kind=kind,interpolation=interpolation,fill=fill,width=width,dash=dash,sortbars=sortbars,keys=keys,
#     840 		bestfit=bestfit,bestfit_colors=bestfit_colors,mean=mean,mean_colors=mean_colors,asDates=asDates,mode=mode,symbol=symbol,size=size,
#     841 		text=text,**kwargs)
#     842 trace_kw=check_kwargs(kwargs,TRACE_KWARGS)
#     843 for trace in data:
#
# File /opt/anaconda3/lib/python3.13/site-packages/cufflinks/plotlytools.py:159, in _to_iplot(self, colors, colorscale, kind, mode, interpolation, symbol, size, fill, width, dash, sortbars, keys, bestfit, bestfit_colors, opacity, mean, mean_colors, asDates, asTimestamp, text, **kwargs)
#     157 			lines[key]["fillcolor"]=to_rgba(colors[key],kwargs['opacity'] if 'opacity' in kwargs else .3		)
#     158 if 'bar' in kind:
# --> 159 	lines_plotly=[Bar(lines[key]).to_plotly_json() for key in keys]
#     160 else:
#     161 	lines_plotly=[Scatter(lines[key]).to_plotly_json() for key in keys]
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/_bar.py:2547, in Bar.__init__(self, arg, alignmentgroup, base, basesrc, cliponaxis, constraintext, customdata, customdatasrc, dx, dy, error_x, error_y, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, insidetextanchor, insidetextfont, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, marker, meta, metasrc, name, offset, offsetgroup, offsetsrc, opacity, orientation, outsidetextfont, selected, selectedpoints, showlegend, stream, text, textangle, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, width, widthsrc, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    2545 self._set_property("legendrank", arg, legendrank)
#    2546 self._set_property("legendwidth", arg, legendwidth)
# -> 2547 self._set_property("marker", arg, marker)
#    2548 self._set_property("meta", arg, meta)
#    2549 self._set_property("metasrc", arg, metasrc)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4924, in BasePlotlyType.__setitem__(self, prop, value)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
# -> 4924     self._set_compound_prop(prop, value)
#    4926 # ### Handle compound array property ###
#    4927 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5335, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5332 # Import value
#    5333 # ------------
#    5334 validator = self._get_validator(prop)
# -> 5335 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5337 # Save deep copies of current and new states
#    5338 # ------------------------------------------
#    5339 curr_val = self._compound_props.get(prop, None)
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:2425, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2422     v = self.data_class()
#    2424 elif isinstance(v, dict):
# -> 2425     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2427 elif isinstance(v, self.data_class):
#    2428     # Copy object
#    2429     v = self.data_class(v)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/bar/_marker.py:678, in Marker.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorbar, colorscale, colorsrc, cornerradius, line, opacity, opacitysrc, pattern, reversescale, showscale, **kwargs)
#     676 self._set_property("colorsrc", arg, colorsrc)
#     677 self._set_property("cornerradius", arg, cornerradius)
# --> 678 self._set_property("line", arg, line)
#     679 self._set_property("opacity", arg, opacity)
#     680 self._set_property("opacitysrc", arg, opacitysrc)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4924, in BasePlotlyType.__setitem__(self, prop, value)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
# -> 4924     self._set_compound_prop(prop, value)
#    4926 # ### Handle compound array property ###
#    4927 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5335, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5332 # Import value
#    5333 # ------------
#    5334 validator = self._get_validator(prop)
# -> 5335 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5337 # Save deep copies of current and new states
#    5338 # ------------------------------------------
#    5339 curr_val = self._compound_props.get(prop, None)
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:2425, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2422     v = self.data_class()
#    2424 elif isinstance(v, dict):
# -> 2425     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2427 elif isinstance(v, self.data_class):
#    2428     # Copy object
#    2429     v = self.data_class(v)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/bar/marker/_line.py:538, in Line.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorscale, colorsrc, reversescale, width, widthsrc, **kwargs)
#     536 self._set_property("cmid", arg, cmid)
#     537 self._set_property("cmin", arg, cmin)
# --> 538 self._set_property("color", arg, color)
#     539 self._set_property("coloraxis", arg, coloraxis)
#     540 self._set_property("colorscale", arg, colorscale)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4932, in BasePlotlyType.__setitem__(self, prop, value)
#    4928         self._set_array_prop(prop, value)
#    4930     # ### Handle simple property ###
#    4931     else:
# -> 4932         self._set_prop(prop, value)
#    4933 else:
#    4934     # Make sure properties dict is initialized
#    4935     self._init_props()
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5276, in BasePlotlyType._set_prop(self, prop, val)
#    5274         return
#    5275     else:
# -> 5276         raise err
#    5278 # val is None
#    5279 # -----------
#    5280 if val is None:
#    5281     # Check if we should send null update
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5271, in BasePlotlyType._set_prop(self, prop, val)
#    5268 validator = self._get_validator(prop)
#    5270 try:
# -> 5271     val = validator.validate_coerce(val)
#    5272 except ValueError as err:
#    5273     if self._skip_invalid:
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:1374, in ColorValidator.validate_coerce(self, v, should_raise)
#    1372     validated_v = self.vc_scalar(v)
#    1373     if validated_v is None and should_raise:
# -> 1374         self.raise_invalid_val(v)
#    1376     v = validated_v
#    1378 return v
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:298, in BaseValidator.raise_invalid_val(self, v, inds)
#     295             for i in inds:
#     296                 name += "[" + str(i) + "]"
# --> 298         raise ValueError(
#     299             """
#     300     Invalid value of type {typ} received for the '{name}' property of {pname}
#     301         Received value: {v}
#     302
#     303 {valid_clr_desc}""".format(
#     304                 name=name,
#     305                 pname=self.parent_name,
#     306                 typ=type_str(v),
#     307                 v=repr(v),
#     308                 valid_clr_desc=self.description(),
#     309             )
#     310         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of bar.marker.line
#         Received value: 'rgba(226, 74, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color: see https://plotly.com/python/css-colors/ for a list
#       - A number that will be interpreted as a color
#         according to bar.marker.line.colorscale
#       - A list or array of any of the above

# %%
df_pivot_2020 = df_pivot_2020.reset_index()

# %%
df_pivot_2020.iplot(kind='pie', values=2020, labels='country')

# %%
df_pivot['United States'].iplot(kind='box', color='green')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[845], line 1
# ----> 1 df_pivot['United States'].iplot(kind='box', color='green')
#
# File /opt/anaconda3/lib/python3.13/site-packages/cufflinks/plotlytools.py:911, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     909 for _ in columns:
#     910 	if kind=='box':
# --> 911 		__=Box(y=df[_].values.tolist(),marker=dict(color=clrs[_]),name=_,
#     912 				line=dict(width=width),boxpoints=boxpoints)
#     913 		# 114 - Horizontal Box
#     914 		__['orientation']=orientation
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/_box.py:2989, in Box.__init__(self, arg, alignmentgroup, boxmean, boxpoints, customdata, customdatasrc, dx, dy, fillcolor, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, jitter, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, lowerfence, lowerfencesrc, marker, mean, meansrc, median, mediansrc, meta, metasrc, name, notched, notchspan, notchspansrc, notchwidth, offsetgroup, opacity, orientation, pointpos, q1, q1src, q3, q3src, quartilemethod, sd, sdmultiple, sdsrc, selected, selectedpoints, showlegend, showwhiskers, sizemode, stream, text, textsrc, uid, uirevision, unselected, upperfence, upperfencesrc, visible, whiskerwidth, width, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    2987 self._set_property("lowerfence", arg, lowerfence)
#    2988 self._set_property("lowerfencesrc", arg, lowerfencesrc)
# -> 2989 self._set_property("marker", arg, marker)
#    2990 self._set_property("mean", arg, mean)
#    2991 self._set_property("meansrc", arg, meansrc)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4924, in BasePlotlyType.__setitem__(self, prop, value)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
# -> 4924     self._set_compound_prop(prop, value)
#    4926 # ### Handle compound array property ###
#    4927 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5335, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5332 # Import value
#    5333 # ------------
#    5334 validator = self._get_validator(prop)
# -> 5335 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5337 # Save deep copies of current and new states
#    5338 # ------------------------------------------
#    5339 curr_val = self._compound_props.get(prop, None)
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:2425, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2422     v = self.data_class()
#    2424 elif isinstance(v, dict):
# -> 2425     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2427 elif isinstance(v, self.data_class):
#    2428     # Copy object
#    2429     v = self.data_class(v)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/box/_marker.py:350, in Marker.__init__(self, arg, angle, color, line, opacity, outliercolor, size, symbol, **kwargs)
#     347 self._validate = kwargs.pop("_validate", True)
#     349 self._set_property("angle", arg, angle)
# --> 350 self._set_property("color", arg, color)
#     351 self._set_property("line", arg, line)
#     352 self._set_property("opacity", arg, opacity)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4932, in BasePlotlyType.__setitem__(self, prop, value)
#    4928         self._set_array_prop(prop, value)
#    4930     # ### Handle simple property ###
#    4931     else:
# -> 4932         self._set_prop(prop, value)
#    4933 else:
#    4934     # Make sure properties dict is initialized
#    4935     self._init_props()
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5276, in BasePlotlyType._set_prop(self, prop, val)
#    5274         return
#    5275     else:
# -> 5276         raise err
#    5278 # val is None
#    5279 # -----------
#    5280 if val is None:
#    5281     # Check if we should send null update
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5271, in BasePlotlyType._set_prop(self, prop, val)
#    5268 validator = self._get_validator(prop)
#    5270 try:
# -> 5271     val = validator.validate_coerce(val)
#    5272 except ValueError as err:
#    5273     if self._skip_invalid:
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:1374, in ColorValidator.validate_coerce(self, v, should_raise)
#    1372     validated_v = self.vc_scalar(v)
#    1373     if validated_v is None and should_raise:
# -> 1374         self.raise_invalid_val(v)
#    1376     v = validated_v
#    1378 return v
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:298, in BaseValidator.raise_invalid_val(self, v, inds)
#     295             for i in inds:
#     296                 name += "[" + str(i) + "]"
# --> 298         raise ValueError(
#     299             """
#     300     Invalid value of type {typ} received for the '{name}' property of {pname}
#     301         Received value: {v}
#     302
#     303 {valid_clr_desc}""".format(
#     304                 name=name,
#     305                 pname=self.parent_name,
#     306                 typ=type_str(v),
#     307                 v=repr(v),
#     308                 valid_clr_desc=self.description(),
#     309             )
#     310         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of box.marker
#         Received value: 'rgba(0, 128, 0, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color: see https://plotly.com/python/css-colors/ for a list

# %%
df_pivot.iplot(kind='box', yTitle = 'Population')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[847], line 1
# ----> 1 df_pivot.iplot(kind='box', yTitle = 'Population')
#
# File /opt/anaconda3/lib/python3.13/site-packages/cufflinks/plotlytools.py:911, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     909 for _ in columns:
#     910 	if kind=='box':
# --> 911 		__=Box(y=df[_].values.tolist(),marker=dict(color=clrs[_]),name=_,
#     912 				line=dict(width=width),boxpoints=boxpoints)
#     913 		# 114 - Horizontal Box
#     914 		__['orientation']=orientation
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/_box.py:2989, in Box.__init__(self, arg, alignmentgroup, boxmean, boxpoints, customdata, customdatasrc, dx, dy, fillcolor, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, jitter, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, lowerfence, lowerfencesrc, marker, mean, meansrc, median, mediansrc, meta, metasrc, name, notched, notchspan, notchspansrc, notchwidth, offsetgroup, opacity, orientation, pointpos, q1, q1src, q3, q3src, quartilemethod, sd, sdmultiple, sdsrc, selected, selectedpoints, showlegend, showwhiskers, sizemode, stream, text, textsrc, uid, uirevision, unselected, upperfence, upperfencesrc, visible, whiskerwidth, width, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    2987 self._set_property("lowerfence", arg, lowerfence)
#    2988 self._set_property("lowerfencesrc", arg, lowerfencesrc)
# -> 2989 self._set_property("marker", arg, marker)
#    2990 self._set_property("mean", arg, mean)
#    2991 self._set_property("meansrc", arg, meansrc)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4924, in BasePlotlyType.__setitem__(self, prop, value)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
# -> 4924     self._set_compound_prop(prop, value)
#    4926 # ### Handle compound array property ###
#    4927 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5335, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5332 # Import value
#    5333 # ------------
#    5334 validator = self._get_validator(prop)
# -> 5335 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5337 # Save deep copies of current and new states
#    5338 # ------------------------------------------
#    5339 curr_val = self._compound_props.get(prop, None)
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:2425, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2422     v = self.data_class()
#    2424 elif isinstance(v, dict):
# -> 2425     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2427 elif isinstance(v, self.data_class):
#    2428     # Copy object
#    2429     v = self.data_class(v)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/box/_marker.py:350, in Marker.__init__(self, arg, angle, color, line, opacity, outliercolor, size, symbol, **kwargs)
#     347 self._validate = kwargs.pop("_validate", True)
#     349 self._set_property("angle", arg, angle)
# --> 350 self._set_property("color", arg, color)
#     351 self._set_property("line", arg, line)
#     352 self._set_property("opacity", arg, opacity)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4932, in BasePlotlyType.__setitem__(self, prop, value)
#    4928         self._set_array_prop(prop, value)
#    4930     # ### Handle simple property ###
#    4931     else:
# -> 4932         self._set_prop(prop, value)
#    4933 else:
#    4934     # Make sure properties dict is initialized
#    4935     self._init_props()
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5276, in BasePlotlyType._set_prop(self, prop, val)
#    5274         return
#    5275     else:
# -> 5276         raise err
#    5278 # val is None
#    5279 # -----------
#    5280 if val is None:
#    5281     # Check if we should send null update
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5271, in BasePlotlyType._set_prop(self, prop, val)
#    5268 validator = self._get_validator(prop)
#    5270 try:
# -> 5271     val = validator.validate_coerce(val)
#    5272 except ValueError as err:
#    5273     if self._skip_invalid:
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:1374, in ColorValidator.validate_coerce(self, v, should_raise)
#    1372     validated_v = self.vc_scalar(v)
#    1373     if validated_v is None and should_raise:
# -> 1374         self.raise_invalid_val(v)
#    1376     v = validated_v
#    1378 return v
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:298, in BaseValidator.raise_invalid_val(self, v, inds)
#     295             for i in inds:
#     296                 name += "[" + str(i) + "]"
# --> 298         raise ValueError(
#     299             """
#     300     Invalid value of type {typ} received for the '{name}' property of {pname}
#     301         Received value: {v}
#     302
#     303 {valid_clr_desc}""".format(
#     304                 name=name,
#     305                 pname=self.parent_name,
#     306                 typ=type_str(v),
#     307                 v=repr(v),
#     308                 valid_clr_desc=self.description(),
#     309             )
#     310         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of box.marker
#         Received value: 'rgba(226, 74, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color: see https://plotly.com/python/css-colors/ for a list

# %%
df_pivot[['Indonesia', 'United States']].iplot(kind='hist', xTitle='Population', bins=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[850], line 1
# ----> 1 df_pivot[['Indonesia', 'United States']].iplot(kind='hist', xTitle='Population', bins=5)
#
# File /opt/anaconda3/lib/python3.13/site-packages/cufflinks/plotlytools.py:930, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     928 	__['y']=__['x']
#     929 	del __['x']
# --> 930 __ = Histogram(__)
#     931 if bins:
#     932 	if type(bins) in (tuple,list):
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/_histogram.py:2378, in Histogram.__init__(self, arg, alignmentgroup, autobinx, autobiny, bingroup, cliponaxis, constraintext, cumulative, customdata, customdatasrc, error_x, error_y, histfunc, histnorm, hoverinfo, hoverinfosrc, hoverlabel, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, insidetextanchor, insidetextfont, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, marker, meta, metasrc, name, nbinsx, nbinsy, offsetgroup, opacity, orientation, outsidetextfont, selected, selectedpoints, showlegend, stream, text, textangle, textfont, textposition, textsrc, texttemplate, uid, uirevision, unselected, visible, x, xaxis, xbins, xcalendar, xhoverformat, xsrc, y, yaxis, ybins, ycalendar, yhoverformat, ysrc, zorder, **kwargs)
#    2376 self._set_property("legendrank", arg, legendrank)
#    2377 self._set_property("legendwidth", arg, legendwidth)
# -> 2378 self._set_property("marker", arg, marker)
#    2379 self._set_property("meta", arg, meta)
#    2380 self._set_property("metasrc", arg, metasrc)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4924, in BasePlotlyType.__setitem__(self, prop, value)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
# -> 4924     self._set_compound_prop(prop, value)
#    4926 # ### Handle compound array property ###
#    4927 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5335, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5332 # Import value
#    5333 # ------------
#    5334 validator = self._get_validator(prop)
# -> 5335 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5337 # Save deep copies of current and new states
#    5338 # ------------------------------------------
#    5339 curr_val = self._compound_props.get(prop, None)
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:2425, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2422     v = self.data_class()
#    2424 elif isinstance(v, dict):
# -> 2425     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2427 elif isinstance(v, self.data_class):
#    2428     # Copy object
#    2429     v = self.data_class(v)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/histogram/_marker.py:673, in Marker.__init__(self, arg, autocolorscale, cauto, cmax, cmid, cmin, color, coloraxis, colorbar, colorscale, colorsrc, cornerradius, line, opacity, opacitysrc, pattern, reversescale, showscale, **kwargs)
#     671 self._set_property("cmid", arg, cmid)
#     672 self._set_property("cmin", arg, cmin)
# --> 673 self._set_property("color", arg, color)
#     674 self._set_property("coloraxis", arg, coloraxis)
#     675 self._set_property("colorbar", arg, colorbar)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4932, in BasePlotlyType.__setitem__(self, prop, value)
#    4928         self._set_array_prop(prop, value)
#    4930     # ### Handle simple property ###
#    4931     else:
# -> 4932         self._set_prop(prop, value)
#    4933 else:
#    4934     # Make sure properties dict is initialized
#    4935     self._init_props()
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5276, in BasePlotlyType._set_prop(self, prop, val)
#    5274         return
#    5275     else:
# -> 5276         raise err
#    5278 # val is None
#    5279 # -----------
#    5280 if val is None:
#    5281     # Check if we should send null update
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5271, in BasePlotlyType._set_prop(self, prop, val)
#    5268 validator = self._get_validator(prop)
#    5270 try:
# -> 5271     val = validator.validate_coerce(val)
#    5272 except ValueError as err:
#    5273     if self._skip_invalid:
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:1374, in ColorValidator.validate_coerce(self, v, should_raise)
#    1372     validated_v = self.vc_scalar(v)
#    1373     if validated_v is None and should_raise:
# -> 1374         self.raise_invalid_val(v)
#    1376     v = validated_v
#    1378 return v
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:298, in BaseValidator.raise_invalid_val(self, v, inds)
#     295             for i in inds:
#     296                 name += "[" + str(i) + "]"
# --> 298         raise ValueError(
#     299             """
#     300     Invalid value of type {typ} received for the '{name}' property of {pname}
#     301         Received value: {v}
#     302
#     303 {valid_clr_desc}""".format(
#     304                 name=name,
#     305                 pname=self.parent_name,
#     306                 typ=type_str(v),
#     307                 v=repr(v),
#     308                 valid_clr_desc=self.description(),
#     309             )
#     310         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of histogram.marker
#         Received value: 'rgba(226, 74, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color: see https://plotly.com/python/css-colors/ for a list
#       - A number that will be interpreted as a color
#         according to histogram.marker.colorscale
#       - A list or array of any of the above

# %%
df_pivot.iplot(kind='scatter', mode='marker')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[851], line 1
# ----> 1 df_pivot.iplot(kind='scatter', mode='marker')
#
# File /opt/anaconda3/lib/python3.13/site-packages/cufflinks/plotlytools.py:839, in _iplot(self, kind, data, layout, filename, sharing, title, xTitle, yTitle, zTitle, theme, colors, colorscale, fill, width, dash, mode, interpolation, symbol, size, barmode, sortbars, bargap, bargroupgap, bins, histnorm, histfunc, orientation, boxpoints, annotations, keys, bestfit, bestfit_colors, mean, mean_colors, categories, x, y, z, text, gridcolor, zerolinecolor, margin, labels, values, secondary_y, secondary_y_title, subplots, shape, error_x, error_y, error_type, locations, lon, lat, asFrame, asDates, asFigure, asImage, dimensions, asPlot, asUrl, online, **kwargs)
#     837 	if not isinstance(text,list):
#     838 		text=self[text].values
# --> 839 data=df.to_iplot(colors=colors,colorscale=colorscale,kind=kind,interpolation=interpolation,fill=fill,width=width,dash=dash,sortbars=sortbars,keys=keys,
#     840 		bestfit=bestfit,bestfit_colors=bestfit_colors,mean=mean,mean_colors=mean_colors,asDates=asDates,mode=mode,symbol=symbol,size=size,
#     841 		text=text,**kwargs)
#     842 trace_kw=check_kwargs(kwargs,TRACE_KWARGS)
#     843 for trace in data:
#
# File /opt/anaconda3/lib/python3.13/site-packages/cufflinks/plotlytools.py:161, in _to_iplot(self, colors, colorscale, kind, mode, interpolation, symbol, size, fill, width, dash, sortbars, keys, bestfit, bestfit_colors, opacity, mean, mean_colors, asDates, asTimestamp, text, **kwargs)
#     159 	lines_plotly=[Bar(lines[key]).to_plotly_json() for key in keys]
#     160 else:
# --> 161 	lines_plotly=[Scatter(lines[key]).to_plotly_json() for key in keys]
#     162 for trace in lines_plotly:
#     163 	if isinstance(trace['name'],pd.Timestamp):
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/_scatter.py:2703, in Scatter.__init__(self, arg, alignmentgroup, cliponaxis, connectgaps, customdata, customdatasrc, dx, dy, error_x, error_y, fill, fillcolor, fillgradient, fillpattern, groupnorm, hoverinfo, hoverinfosrc, hoverlabel, hoveron, hovertemplate, hovertemplatesrc, hovertext, hovertextsrc, ids, idssrc, legend, legendgroup, legendgrouptitle, legendrank, legendwidth, line, marker, meta, metasrc, mode, name, offsetgroup, opacity, orientation, selected, selectedpoints, showlegend, stackgaps, stackgroup, stream, text, textfont, textposition, textpositionsrc, textsrc, texttemplate, texttemplatesrc, uid, uirevision, unselected, visible, x, x0, xaxis, xcalendar, xhoverformat, xperiod, xperiod0, xperiodalignment, xsrc, y, y0, yaxis, ycalendar, yhoverformat, yperiod, yperiod0, yperiodalignment, ysrc, zorder, **kwargs)
#    2701 self._set_property("legendrank", arg, legendrank)
#    2702 self._set_property("legendwidth", arg, legendwidth)
# -> 2703 self._set_property("line", arg, line)
#    2704 self._set_property("marker", arg, marker)
#    2705 self._set_property("meta", arg, meta)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4924, in BasePlotlyType.__setitem__(self, prop, value)
#    4922 # ### Handle compound property ###
#    4923 if isinstance(validator, CompoundValidator):
# -> 4924     self._set_compound_prop(prop, value)
#    4926 # ### Handle compound array property ###
#    4927 elif isinstance(validator, (CompoundArrayValidator, BaseDataValidator)):
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5335, in BasePlotlyType._set_compound_prop(self, prop, val)
#    5332 # Import value
#    5333 # ------------
#    5334 validator = self._get_validator(prop)
# -> 5335 val = validator.validate_coerce(val, skip_invalid=self._skip_invalid)
#    5337 # Save deep copies of current and new states
#    5338 # ------------------------------------------
#    5339 curr_val = self._compound_props.get(prop, None)
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:2425, in CompoundValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2422     v = self.data_class()
#    2424 elif isinstance(v, dict):
# -> 2425     v = self.data_class(v, skip_invalid=skip_invalid, _validate=_validate)
#    2427 elif isinstance(v, self.data_class):
#    2428     # Copy object
#    2429     v = self.data_class(v)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/graph_objs/scatter/_line.py:303, in Line.__init__(self, arg, backoff, backoffsrc, color, dash, shape, simplify, smoothing, width, **kwargs)
#     301 self._set_property("backoff", arg, backoff)
#     302 self._set_property("backoffsrc", arg, backoffsrc)
# --> 303 self._set_property("color", arg, color)
#     304 self._set_property("dash", arg, dash)
#     305 self._set_property("shape", arg, shape)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4403, in BasePlotlyType._set_property(self, name, arg, provided)
#    4397 def _set_property(self, name, arg, provided):
#    4398     """
#    4399     Initialize a property of this object using the provided value
#    4400     or a value popped from the arguments dictionary. If neither
#    4401     is available, do not set the property.
#    4402     """
# -> 4403     _set_property_provided_value(self, name, arg, provided)
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:398, in _set_property_provided_value(obj, name, arg, provided)
#     396 val = provided if provided is not None else val
#     397 if val is not None:
# --> 398     obj[name] = val
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:4932, in BasePlotlyType.__setitem__(self, prop, value)
#    4928         self._set_array_prop(prop, value)
#    4930     # ### Handle simple property ###
#    4931     else:
# -> 4932         self._set_prop(prop, value)
#    4933 else:
#    4934     # Make sure properties dict is initialized
#    4935     self._init_props()
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5276, in BasePlotlyType._set_prop(self, prop, val)
#    5274         return
#    5275     else:
# -> 5276         raise err
#    5278 # val is None
#    5279 # -----------
#    5280 if val is None:
#    5281     # Check if we should send null update
#
# File /opt/anaconda3/lib/python3.13/site-packages/plotly/basedatatypes.py:5271, in BasePlotlyType._set_prop(self, prop, val)
#    5268 validator = self._get_validator(prop)
#    5270 try:
# -> 5271     val = validator.validate_coerce(val)
#    5272 except ValueError as err:
#    5273     if self._skip_invalid:
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:1374, in ColorValidator.validate_coerce(self, v, should_raise)
#    1372     validated_v = self.vc_scalar(v)
#    1373     if validated_v is None and should_raise:
# -> 1374         self.raise_invalid_val(v)
#    1376     v = validated_v
#    1378 return v
#
# File /opt/anaconda3/lib/python3.13/site-packages/_plotly_utils/basevalidators.py:298, in BaseValidator.raise_invalid_val(self, v, inds)
#     295             for i in inds:
#     296                 name += "[" + str(i) + "]"
# --> 298         raise ValueError(
#     299             """
#     300     Invalid value of type {typ} received for the '{name}' property of {pname}
#     301         Received value: {v}
#     302
#     303 {valid_clr_desc}""".format(
#     304                 name=name,
#     305                 pname=self.parent_name,
#     306                 typ=type_str(v),
#     307                 v=repr(v),
#     308                 valid_clr_desc=self.description(),
#     309             )
#     310         )
#
# ValueError:
#     Invalid value of type 'builtins.str' received for the 'color' property of scatter.line
#         Received value: 'rgba(226, 74, 51, np.float64(1.0))'
#
#     The 'color' property is a color and may be specified as:
#       - A hex string (e.g. '#ff0000')
#       - An rgb/rgba string (e.g. 'rgb(255,0,0)')
#       - An hsl/hsla string (e.g. 'hsl(0,100%,50%)')
#       - An hsv/hsva string (e.g. 'hsv(0,100%,100%)')
#       - A named CSS color: see https://plotly.com/python/css-colors/ for a list

# %%
df_cars = pd.read_csv('Car_Sales.csv')

# %%
df_cars = df_cars[['Manufacturer', 'Sales_in_thousands', 'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower', 'Fuel_capacity']]

# %%
df_cars.nunique()
# Out:
# Manufacturer           30
# Sales_in_thousands    157
#                      ...
# Horsepower             66
# Fuel_capacity          55
# Length: 7, dtype: int64

# %%
df_cars.agg('sum')
# Out:
# Manufacturer          AcuraAcuraAcuraAcuraAudiAudiAudiBMWBMWBMWBuick...
# Sales_in_thousands                                             8320.698
#                                             ...
# Horsepower                                                      29008.0
# Fuel_capacity                                                    2800.5
# Length: 7, dtype: object

# %%
df_cars.agg('mean')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[860], line 1
# ----> 1 df_cars.agg('mean')
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:10176, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#   10173 axis = self._get_axis_number(axis)
#   10175 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# > 10176 result = op.agg()
#   10177 result = reconstruct_and_relabel_result(result, func, **kwargs)
#   10178 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:928, in FrameApply.agg(self)
#     926 result = None
#     927 try:
# --> 928     result = super().agg()
#     929 finally:
#     930     self.obj = obj
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:187, in Apply.agg(self)
#     184 kwargs = self.kwargs
#     186 if isinstance(func, str):
# --> 187     return self.apply_str()
#     189 if is_dict_like(func):
#     190     return self.agg_dict_like()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:1131, in FrameApply.apply_str(self)
#    1129     value = obj.shape[self.axis]
#    1130     return obj._constructor_sliced(value, index=self.agg_axis)
# -> 1131 return super().apply_str()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:603, in Apply.apply_str(self)
#     601         else:
#     602             self.kwargs["axis"] = self.axis
# --> 603 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:693, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     691 f = getattr(obj, func)
#     692 if callable(f):
# --> 693     return f(*args, **kwargs)
#     695 # people may aggregate on a non-callable attribute
#     696 # but don't let them think they can pass args to it
#     697 assert len(args) == 0
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:11720, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11712 @doc(make_doc("mean", ndim=2))
#   11713 def mean(
#   11714     self,
#    (...)  11718     **kwargs,
#   11719 ):
# > 11720     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11721     if isinstance(result, Series):
#   11722         result = result.__finalize__(self, method="mean")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/internals/managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/internals/blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:11508, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11506         return np.array([result])
#   11507 else:
# > 11508     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/nanops.py:1686, in _ensure_numeric(x)
#    1683 inferred = lib.infer_dtype(x)
#    1684 if inferred in ["string", "mixed"]:
#    1685     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1686     raise TypeError(f"Could not convert {x} to numeric")
#    1687 try:
#    1688     x = x.astype(np.complex128)
#
# TypeError: Could not convert ['...-BMercedes-BMercedes-BMercedes-BMercedes-BMercedes-BMercedes-BMercedes-BMercedes-'
#  '...'] to numeric

# %%
df_cars.agg(['mean','count'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[863], line 1
# ----> 1 df_cars.agg(['mean','count'])
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:10176, in DataFrame.aggregate(self, func, axis, *args, **kwargs)
#   10173 axis = self._get_axis_number(axis)
#   10175 op = frame_apply(self, func=func, axis=axis, args=args, kwargs=kwargs)
# > 10176 result = op.agg()
#   10177 result = reconstruct_and_relabel_result(result, func, **kwargs)
#   10178 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:928, in FrameApply.agg(self)
#     926 result = None
#     927 try:
# --> 928     result = super().agg()
#     929 finally:
#     930     self.obj = obj
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# --> 193     return self.agg_list_like()
#     195 if callable(func):
#     196     f = com.get_cython_func(func)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:326, in Apply.agg_list_like(self)
#     318 def agg_list_like(self) -> DataFrame | Series:
#     319     """
#     320     Compute aggregation in the case of a list-like argument.
#     321
#    (...)    324     Result of aggregation.
#     325     """
# --> 326     return self.agg_or_apply_list_like(op_name="agg")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:744, in NDFrameApply.agg_or_apply_list_like(self, op_name)
#     741 if getattr(obj, "axis", 0) == 1:
#     742     raise NotImplementedError("axis other than 0 is not supported")
# --> 744 keys, results = self.compute_list_like(op_name, obj, kwargs)
#     745 result = self.wrap_results_list_like(keys, results)
#     746 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:385, in Apply.compute_list_like(self, op_name, selected_obj, kwargs)
#     379 colg = obj._gotitem(col, ndim=1, subset=selected_obj.iloc[:, index])
#     380 args = (
#     381     [self.axis, *self.args]
#     382     if include_axis(op_name, colg)
#     383     else self.args
#     384 )
# --> 385 new_res = getattr(colg, op_name)(func, *args, **kwargs)
#     386 results.append(new_res)
#     387 indices.append(index)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:4785, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4782     func = dict(kwargs.items())
#    4784 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4785 result = op.agg()
#    4786 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:1425, in SeriesApply.agg(self)
#    1424 def agg(self):
# -> 1425     result = super().agg()
#    1426     if result is None:
#    1427         obj = self.obj
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:193, in Apply.agg(self)
#     190     return self.agg_dict_like()
#     191 elif is_list_like(func):
#     192     # we require a list, but not a 'str'
# --> 193     return self.agg_list_like()
#     195 if callable(func):
#     196     f = com.get_cython_func(func)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:326, in Apply.agg_list_like(self)
#     318 def agg_list_like(self) -> DataFrame | Series:
#     319     """
#     320     Compute aggregation in the case of a list-like argument.
#     321
#    (...)    324     Result of aggregation.
#     325     """
# --> 326     return self.agg_or_apply_list_like(op_name="agg")
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:744, in NDFrameApply.agg_or_apply_list_like(self, op_name)
#     741 if getattr(obj, "axis", 0) == 1:
#     742     raise NotImplementedError("axis other than 0 is not supported")
# --> 744 keys, results = self.compute_list_like(op_name, obj, kwargs)
#     745 result = self.wrap_results_list_like(keys, results)
#     746 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:369, in Apply.compute_list_like(self, op_name, selected_obj, kwargs)
#     363 colg = obj._gotitem(selected_obj.name, ndim=1, subset=selected_obj)
#     364 args = (
#     365     [self.axis, *self.args]
#     366     if include_axis(op_name, colg)
#     367     else self.args
#     368 )
# --> 369 new_res = getattr(colg, op_name)(a, *args, **kwargs)
#     370 results.append(new_res)
#     372 # make sure we find a good name
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:4785, in Series.aggregate(self, func, axis, *args, **kwargs)
#    4782     func = dict(kwargs.items())
#    4784 op = SeriesApply(self, func, args=args, kwargs=kwargs)
# -> 4785 result = op.agg()
#    4786 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:1425, in SeriesApply.agg(self)
#    1424 def agg(self):
# -> 1425     result = super().agg()
#    1426     if result is None:
#    1427         obj = self.obj
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:187, in Apply.agg(self)
#     184 kwargs = self.kwargs
#     186 if isinstance(func, str):
# --> 187     return self.apply_str()
#     189 if is_dict_like(func):
#     190     return self.agg_dict_like()
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:603, in Apply.apply_str(self)
#     601         else:
#     602             self.kwargs["axis"] = self.axis
# --> 603 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/apply.py:693, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     691 f = getattr(obj, func)
#     692 if callable(f):
# --> 693     return f(*args, **kwargs)
#     695 # people may aggregate on a non-callable attribute
#     696 # but don't let them think they can pass args to it
#     697 assert len(args) == 0
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:6570, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6562 @doc(make_doc("mean", ndim=1))
#    6563 def mean(
#    6564     self,
#    (...)   6568     **kwargs,
#    6569 ):
# -> 6570     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py:12485, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12478 def mean(
#   12479     self,
#   12480     axis: Axis | None = 0,
#    (...)  12483     **kwargs,
#   12484 ) -> Series | float:
# > 12485     return self._stat_function(
#   12486         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12487     )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/generic.py:12442, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12438 nv.validate_func(name, (), kwargs)
#   12440 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12442 return self._reduce(
#   12443     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12444 )
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/series.py:6478, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6473     # GH#47500 - change to TypeError to match other methods
#    6474     raise TypeError(
#    6475         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6476         "with non-numeric dtypes."
#    6477     )
# -> 6478 return op(delegate, skipna=skipna, **kwds)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     718 count = _get_counts(values.shape, mask, axis, dtype=dtype_count)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#     723     count = cast(np.ndarray, count)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/core/nanops.py:1701, in _ensure_numeric(x)
#    1698 elif not (is_float(x) or is_integer(x) or is_complex(x)):
#    1699     if isinstance(x, str):
#    1700         # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701         raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702     try:
#    1703         x = float(x)
#
# TypeError: Could not convert string '...-BMercedes-BMercedes-BMercedes-BMercedes-BMercedes-BMercedes-BMercedes-BMercedes-' to numeric

# %%
df_cars.agg({'Sales_in_thousands': ['sum', 'mean'], 'Price_in_thousands':['sum', 'max']})
# Out:
#       Sales_in_thousands  Price_in_thousands
# sum          8320.698000            4245.567
# mean           52.998076                 NaN
# max                  NaN              85.500

# %%
df_cars[['Sales_in_thousands', 'Price_in_thousands']].agg('sum', axis=1)
# Out:
# 0      38.419
# 1      67.784
#         ...
# 155    48.993
# 156    54.969
# Length: 157, dtype: float64

# %%
df_cars.agg( x = ('Sales_in_thousands', 'sum' ), y = ('Price_in_thousands', 'sum' ))
# Out:
#    Sales_in_thousands  Price_in_thousands
# x            8320.698                 NaN
# y                 NaN            4245.567

# %%
df_cars['Vehicle_type'].value_counts()
# Out:
# Vehicle_type
# Passenger    116
# Car           41
# Name: count, dtype: int64
